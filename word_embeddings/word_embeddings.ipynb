# %%
import json
from konlpy.tag import Kkma
from konlpy.utils import pprint
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC,LinearSVC,SVR
from sklearn.metrics import accuracy_score,mean_squared_error,roc_auc_score
import numpy as np
from sklearn.linear_model import LogisticRegression,SGDClassifier

# %%
REVIEWS = "all_reviews"

# %%
# f = open("" + REVIEWS + ".txt","r",encoding="utf-8").readlines()
# #print each sentence in a line
# with open("" + REVIEWS+"_sentences_in_lines.txt","w",encoding="utf-8") as out:
#     for line in f:
#         course = json.loads(line)
#         review_text = course["review_text"].strip()
#         out.write(review_text + "\n")

# %%
import numpy as np
import tensorflow as tf
import collections
from konlpy.tag import Okt
import argparse
import re
import math
import random

# %%
class Map(dict):
    """
    Example:
    m = Map({'first_name': 'Eduardo'}, last_name='Pool', age=24, sports=['Soccer'])
    """
    def __init__(self, *args, **kwargs):
        super(Map, self).__init__(*args, **kwargs)
        for arg in args:
            if isinstance(arg, dict):
                for k, v in arg.iteritems():
                    self[k] = v

        if kwargs:
            for k, v in kwargs.iteritems():
                self[k] = v

    def __getattr__(self, attr):
        return self.get(attr)

    def __setattr__(self, key, value):
        self.__setitem__(key, value)

    def __setitem__(self, key, value):
        super(Map, self).__setitem__(key, value)
        self.__dict__.update({key: value})

    def __delattr__(self, item):
        self.__delitem__(item)

    def __delitem__(self, key):
        super(Map, self).__delitem__(key)
        del self.__dict__[key]

# %%
'''
    Step 1 : Parse Arguments.
'''
# parser = argparse.ArgumentParser()
# parser.add_argument("input", type=str, help="input text file for training: one sentence per line")
# parser.add_argument("--embedding_size", type=int, help="embedding vector size (default=150)", default=150)
# parser.add_argument("--window_size", type=int, help="window size (default=5)", default=5)
# parser.add_argument("--min_count", type=int, help="minimal number of word occurences (default=5)", default=5)
# parser.add_argument("--num_sampled", type=int, help="number of negatives sampled (default=50)", default=50)
# parser.add_argument("--learning_rate", type=float, help="learning rate (default=1.0)", default=1.0)
# parser.add_argument("--sampling_rate", type=int, help="rate for subsampling frequent words (default=0.0001)", default=0.0001)
# parser.add_argument("--epochs", type=int, help="number of epochs (default=3)", default=3)
# parser.add_argument("--batch_size", type=int, help="batch size (default=150)", default=150)

# args = parser.parse_args()
args = Map()
args.input = REVIEWS + ".txt"
args.embedding_size = 150
args.window_size = 5
args.min_count = 5
args.num_sampled = 50
args.learning_rate = 1.0
args.sampling_rate = 0.0001
args.epochs = 3
args.batch_size = 150

# %%
'''
    Step 2 : Pre-process Data.
'''

def build_dataset(train_text, min_count, sampling_rate):
    words = list()
    with open(train_text, 'r',encoding="utf-8") as f:
        lines = f.readlines()
        for line in lines:
            sentence = re.sub(r"[^ㄱ-힣a-zA-Z0-9]+", ' ', line).strip().split()
            if sentence:
                words.append(sentence)

    word_counter = [['UNK', -1]]
    word_counter.extend(collections.Counter([word for sentence in words for word in sentence]).most_common())
    word_counter = [item for item in word_counter if item[1] >= min_count or item[0] == 'UNK']

    word_dict = dict()
    for word, count in word_counter:
        word_dict[word] = len(word_dict)
    word_reverse_dict = dict(zip(word_dict.values(), word_dict.keys()))

    word_to_pos_li = dict()
    pos_list = list()
    okt = Okt()
    for w in word_dict:
        w_pos_li = list()
        for pos in okt.pos(w, norm=True):
            w_pos_li.append(pos)

        word_to_pos_li[word_dict[w]] = w_pos_li
        pos_list += w_pos_li

    pos_counter = collections.Counter(pos_list).most_common()

    pos_dict = dict()
    for pos, _ in pos_counter:
        pos_dict[pos] = len(pos_dict)

    pos_reverse_dict = dict(zip(pos_dict.values(), pos_dict.keys()))

    word_to_pos_dict = dict()

    for word_id, pos_li in word_to_pos_li.items():
        pos_id_li = list()
        for pos in pos_li:
            pos_id_li.append(pos_dict[pos])
        word_to_pos_dict[word_id] = pos_id_li

    data = list()
    unk_count = 0
    for sentence in words:
        s = list()
        for word in sentence:
            if word in word_dict:
                index = word_dict[word]
            else:
                index = word_dict['UNK']
                unk_count += 1
            s.append(index)
        data.append(s)
    word_counter[0][1] = max(1, unk_count)

    data = sub_sampling(data, word_counter, word_dict, sampling_rate)

    return data, word_dict, word_reverse_dict, pos_dict, pos_reverse_dict, word_to_pos_dict


# Sub-sampling frequent words according to sampling_rate
def sub_sampling(data, word_counter, word_dict, sampling_rate):
    total_words = sum([len(sentence) for sentence in data])
    prob_dict = dict()
    for word, count in word_counter:
        f = count / total_words
        p = max(0, 1 - math.sqrt(sampling_rate / f))
        prob_dict[word_dict[word]] = p

    new_data = list()
    for sentence in data:
        s = list()
        for word in sentence:
            prob = prob_dict[word]
            if random.random() > prob:
                s.append(word)
        new_data.append(s)

    return new_data

# %%
data, word_dict, word_reverse_dict, pos_dict, pos_reverse_dict, word_to_pos_dict \
        = build_dataset(args.input, args.min_count, args.sampling_rate)

vocabulary_size = len(word_dict)
pos_size = len(pos_dict)
num_sentences = len(data)

print("number of sentences :", num_sentences)
print("vocabulary size :", vocabulary_size)
print("pos size :", pos_size)

pos_li = []
for key in sorted(pos_reverse_dict):
    pos_li.append(pos_reverse_dict[key])
# Out:
# number of sentences : 5434
# vocabulary size : 9886
# pos size : 6058

# %%
'''
    Step 3 : Function to generate a training batch
'''

window_size = args.window_size
batch_size = args.batch_size


def generate_input_output_list(data, window_size):
    input_li = list()
    output_li = list()
    for sentence in data:
        for i in range(len(sentence)):
            for j in range(max(0, i - window_size), min(len(sentence), i + window_size + 1)):
                if i != j:
                    if sentence[i]!=word_dict['UNK'] and sentence[j]!=word_dict['UNK']:
                        input_li.append(sentence[i])
                        output_li.append(sentence[j])
    return input_li, output_li

input_li, output_li = generate_input_output_list(data, window_size)
input_li_size = len(input_li)


def generate_batch(iter, batch_size):
    # print(input_li_size)
    # print(batch_size)
    index = (iter % (input_li_size//batch_size)) * batch_size
    batch_input = input_li[index:index+batch_size]
    batch_output_li = output_li[index:index+batch_size]
    batch_output = [[i] for i in batch_output_li]

    return np.array(batch_input), np.array(batch_output)

# %%
'''
    Step 4 : Build a model.
'''

embedding_size = args.embedding_size
num_sampled = args.num_sampled
learning_rate = args.learning_rate

valid_size = 20     # Random set of words to evaluate similarity on.
valid_window = 200  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)

graph = tf.Graph()

with graph.as_default():
    # Input data
    train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    words_matrix = [tf.placeholder(tf.int32, shape=None) for _ in range(batch_size)]
    vocabulary_matrix = [tf.placeholder(tf.int32, shape=(None)) for _ in range(vocabulary_size)]
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    with tf.device('/cpu:0'):
        pos_embeddings = tf.Variable(tf.random_uniform([pos_size, embedding_size], -1.0, 1.0), name='pos_embeddings')

        word_vec_list = []
        for i in range(batch_size):
            word_vec = tf.reduce_sum(tf.nn.embedding_lookup(pos_embeddings, words_matrix[i]), 0)
            word_vec_list.append(word_vec)
        word_embeddings = tf.stack(word_vec_list)

        nce_weights = tf.Variable(
            tf.truncated_normal([vocabulary_size, embedding_size], stddev=1.0 / math.sqrt(embedding_size)), name='nce_weights'
        )
        nce_biases = tf.Variable(tf.zeros([vocabulary_size]), name='nce_biases')

    loss = tf.reduce_mean(
        tf.nn.nce_loss(weights=nce_weights,
                       biases=nce_biases,
                       labels=train_labels,
                       inputs=word_embeddings,
                       num_sampled=num_sampled,
                       num_classes=vocabulary_size))

    optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss)
    init = tf.global_variables_initializer()

    # Compute the cosine similarity between minibatch exaples and all embeddings.
    norm = tf.sqrt(tf.reduce_sum(tf.square(pos_embeddings), 1, keepdims=True))
    normalized_embeddings = pos_embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, normalized_embeddings, transpose_b=True)


# Function to save vectors.
def save_model(pos_list, embeddings, file_name):
    with open(file_name, 'w',encoding="utf-8") as f:
        f.write(str(len(pos_list)))
        f.write(" ")
        f.write(str(embedding_size))
        f.write("\n")
        for i in range(len(pos_list)):
            pos = pos_list[i]
            f.write(str(pos).replace("', '", "','") + " ")
            f.write(' '.join(map(str, embeddings[i])))
            f.write("\n")

# %%
'''
    Step 5 : Train a model.
'''

num_iterations = input_li_size // batch_size
print("number of iterations for each epoch :", num_iterations)
epochs = args.epochs
num_steps = num_iterations * epochs + 1

with tf.Session(graph=graph) as session:
    init.run()
    print("Initialized - Tensorflow")

    average_loss = 0
    for step in range(num_steps):
        batch_inputs, batch_labels = generate_batch(step, batch_size)

        word_list = []
        for word in batch_inputs:
            word_list.append(word_to_pos_dict[word])

        feed_dict = {}
        for i in range(batch_size):
            feed_dict[words_matrix[i]] = word_list[i]
        feed_dict[train_inputs] = batch_inputs
        feed_dict[train_labels] = batch_labels

        _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += loss_val

        if step % 2000 == 0:
            if step > 0:
                average_loss /= 2000
            print("Average loss at step ", step, ": ", average_loss)
            average_loss = 0

        if step % 20000 == 0:
            pos_embed = pos_embeddings.eval()

            # Print nearest words
            sim = similarity.eval()
            for i in range(valid_size):
                valid_pos = pos_reverse_dict[valid_examples[i]]
                top_k = 8
                nearest = (-sim[i, :]).argsort()[1:top_k + 1]
                log_str = 'Nearest to %s:' % str(valid_pos)
                for k in range(top_k):
                    close_word = pos_reverse_dict[nearest[k]]
                    log_str = '%s %s,' % (log_str, str(close_word))
                print(log_str)

    # Save vectors
    save_model(pos_li, pos_embeddings.eval(), "pos.vec")
# Out:
# number of iterations for each epoch : 13243
# Initialized - Tensorflow
# Average loss at step  0 :  199.8607635498047
# Nearest to ('했습니다', 'Verb'): ('간간히', 'Adverb'), ('ㅠㅠ', 'KoreanParticle'), ('걱정', 'Noun'), ('안타까운', 'Adjective'), ('모양', 'Noun'), ('들에', 'Verb'), ('김훈', 'Noun'), ('True', 'Alpha'),
# Nearest to ('작성', 'Noun'): ('나오더군요', 'Verb'), ('일본', 'Noun'), ('합성', 'Noun'), ('단', 'Noun'), ('시대', 'Noun'), ('아는대로', 'Verb'), ('텍스트', 'Noun'), ('편안하게', 'Adjective'),
# Nearest to ('보면', 'Verb'): ('따라잡기', 'Verb'), ('TF', 'Alpha'), ('숨겨진', 'Verb'), ('과의', 'Josa'), ('권합니다', 'Verb'), ('넘어가서', 'Verb'), ('140', 'Number'), ('들을', 'Verb'),
# Nearest to ('주시', 'Noun'): ('신철', 'Noun'), ('24', 'Number'), ('Psychology', 'Alpha'), ('current', 'Alpha'), ('for', 'Alpha'), ('you', 'Alpha'), ('개강', 'Noun'), ('포인트', 'Noun'),
# Nearest to ('기말고사', 'Noun'): ('뽑아서', 'Verb'), ('기출', 'Noun'), ('D', 'Alpha'), ('않았을', 'Verb'), ('주셔서', 'Verb'), ('홍승우', 'Noun'), ('지옥', 'Noun'), ('황', 'Noun'),
# Nearest to ('이상', 'Noun'): ('나오더군요', 'Verb'), ('그러므로', 'Conjunction'), ('계시는데', 'Adjective'), ('역학', 'Noun'), ('아랫', 'Modifier'), ('바뇌', 'Noun'), ('235', 'Number'), ('들에', 'Verb'),
# Nearest to ('연습', 'Noun'): ('망했습니다', 'Adjective'), ('오지', 'Noun'), ('안타까운', 'Adjective'), ('느껴지는', 'Verb'), ('전프구', 'Noun'), ('않을까요', 'Verb'), ('의식', 'Noun'), ('조병', 'Noun'),
# Nearest to ('부터', 'Josa'): ('있어', 'Adjective'), ('들음', 'Verb'), ('명확한', 'Adjective'), ('그마', 'Foreign'), ('않더라도', 'Verb'), ('해줍니다', 'Verb'), ('였던', 'Verb'), ('선형대수학', 'Noun'),
# Nearest to ('해서', 'Verb'): ('내의', 'Noun'), ('는', 'Josa'), ('NMR', 'Alpha'), ('있으므로', 'Adjective'), ('반정', 'Noun'), ('가령', 'Noun'), ('똑똑한', 'Adjective'), ('충실하면', 'Adjective'),
# Nearest to ('에게', 'Josa'): ('하기는', 'Verb'), ('부족하다고', 'Adjective'), ('각', 'Noun'), ('반도', 'Noun'), ('순', 'Modifier'), ('261', 'Number'), ('꼼꼼하게', 'Adjective'), ('알았습니다', 'Verb'),
# Nearest to ('로드', 'Noun'): ('무', 'Noun'), ('뿌듯합니다', 'Adjective'), ('갈립니다', 'Verb'), ('적으시면', 'Verb'), ('않게', 'Verb'), ('성', 'Modifier'), ('441', 'Number'), ('25', 'Number'),
# Nearest to ('가지', 'Noun'): ('일단', 'Noun'), ('라도', 'Josa'), ('배려', 'Noun'), ('떄', 'Noun'), ('있거든요', 'Adjective'), ('재미있어요', 'Adjective'), ('올려주십니다', 'Verb'), ('애', 'Noun'),
# Nearest to ('다', 'Josa'): ('개요', 'Noun'), ('걸린', 'Verb'), ('하위', 'Noun'), ('플러스', 'Noun'), ('받았네요', 'Verb'), ('155', 'Number'), ('사실', 'Noun'), ('문학', 'Noun'),
# Nearest to ('학생', 'Noun'): ('방금', 'Noun'), ('a', 'Alpha'), ('빼면', 'Verb'), ('재밌다', 'Adjective'), ('생겨서', 'Verb'), ('않는듯', 'Verb'), ('풀어오는', 'Verb'), ('제한', 'Noun'),
# Nearest to ('반', 'Noun'): ('걸쳐', 'Verb'), ('상당한', 'Adjective'), ('6시간', 'Number'), ('높음', 'Adjective'), ('024', 'Number'), ('만큼', 'Noun'), ('가르치셨는데', 'Verb'), ('되었으면', 'Verb'),
# Nearest to ('MAS', 'Alpha'): ('칼', 'Noun'), ('스럽게', 'Josa'), ('양자', 'Noun'), ('김은경', 'Noun'), ('heat', 'Alpha'), ('좋다', 'Adjective'), ('203', 'Number'), ('나오는거', 'Verb'),
# Nearest to ('전', 'Noun'): ('되어있고', 'Verb'), ('등등', 'Noun'), ('바랍니다', 'Verb'), ('전후', 'Noun'), ('문학', 'Noun'), ('수', 'Noun'), ('위상수학', 'Noun'), ('많으므로', 'Adjective'),
# Nearest to ('면', 'Josa'): ('평범', 'Noun'), ('정확히는', 'Adjective'), ('정기훈', 'Noun'), ('문', 'Modifier'), ('자기학', 'Noun'), ('통해', 'Noun'), ('보시면서', 'Verb'), ('류승탁', 'Noun'),
# Nearest to ('를', 'Josa'): ('종종', 'Noun'), ('1회', 'Number'), ('테이', 'Noun'), ('치수', 'Noun'), ('따르면', 'Verb'), ('Special', 'Alpha'), ('에서도', 'Josa'), ('쌓을', 'Verb'),
# Nearest to ('자료', 'Noun'): ('미방', 'Noun'), ('쪽글', 'Noun'), ('하면', 'Verb'), ('특정', 'Noun'), ('받았다는', 'Verb'), ('순수하게', 'Adjective'), ('하시는거', 'Verb'), ('살', 'Noun'),
# Average loss at step  2000 :  42.290983496904374
# Average loss at step  4000 :  11.410585507631302
# Average loss at step  6000 :  7.4361487426757815
# Average loss at step  8000 :  6.540302585124969
# Average loss at step  10000 :  6.086639445543289
# Average loss at step  12000 :  5.828479601621628
# Average loss at step  14000 :  5.712541347980499
# Average loss at step  16000 :  5.485269476652145
# Average loss at step  18000 :  5.44519987308979
# Average loss at step  20000 :  5.425478927731514
# Nearest to ('했습니다', 'Verb'): ('내용', 'Noun'), ('없는', 'Adjective'), ('방사선', 'Noun'), ('수업', 'Noun'), ('받았다', 'Verb'), ('compactness', 'Alpha'), ('것', 'Noun'), ('통', 'Noun'),
# Nearest to ('작성', 'Noun'): ('나오더군요', 'Verb'), ('것', 'Noun'), ('일본', 'Noun'), ('중국어', 'Noun'), ('학점', 'Noun'), ('하든', 'Noun'), ('단', 'Noun'), ('아는대로', 'Verb'),
# Nearest to ('보면', 'Verb'): ('따라잡기', 'Verb'), ('최정아', 'Noun'), ('책', 'Noun'), ('들을', 'Verb'), ('명확한', 'Adjective'), ('compactness', 'Alpha'), ('부분', 'Noun'), ('수업', 'Noun'),
# Nearest to ('주시', 'Noun'): ('것', 'Noun'), ('학점', 'Noun'), ('합니다', 'Verb'), ('compactness', 'Alpha'), ('답사', 'Noun'), ('학생', 'Noun'), ('수업', 'Noun'), ('중간', 'Noun'),
# Nearest to ('기말고사', 'Noun'): ('숙제', 'Noun'), ('중간', 'Noun'), ('중간고사', 'Noun'), ('퀴즈', 'Noun'), ('디스', 'Noun'), ('문제', 'Noun'), ('교수', 'Noun'), ('과제', 'Noun'),
# Nearest to ('이상', 'Noun'): ('나오더군요', 'Verb'), ('중간', 'Noun'), ('디스', 'Noun'), ('방사선', 'Noun'), ('매주', 'Adverb'), ('것', 'Noun'), ('통', 'Noun'), ('정도', 'Noun'),
# Nearest to ('연습', 'Noun'): ('compactness', 'Alpha'), ('문제', 'Noun'), ('에는', 'Josa'), ('숙제', 'Noun'), ('Search', 'Alpha'), ('답사', 'Noun'), ('책', 'Noun'), ('한국인', 'Noun'),
# Nearest to ('부터', 'Josa'): ('들음', 'Verb'), ('있어', 'Adjective'), ('151', 'Number'), ('텐데', 'Eomi'), ('명확한', 'Adjective'), ('주셨습니다', 'Verb'), ('그마', 'Foreign'), ('박희성', 'Noun'),
# Nearest to ('해서', 'Verb'): ('것', 'Noun'), ('답사', 'Noun'), ('시간', 'Noun'), ('정도', 'Noun'), ('내용', 'Noun'), ('수업', 'Noun'), ('compactness', 'Alpha'), ('중간', 'Noun'),
# Nearest to ('에게', 'Josa'): ('핀', 'Noun'), ('261', 'Number'), ('알았습니다', 'Verb'), ('각', 'Noun'), ('좋겠죠', 'Adjective'), ('하기는', 'Verb'), ('483', 'Number'), ('않았다고', 'Verb'),
# Nearest to ('로드', 'Noun'): ('교수', 'Noun'), ('숙제', 'Noun'), ('중간', 'Noun'), ('학점', 'Noun'), ('수업', 'Noun'), ('답사', 'Noun'), ('과제', 'Noun'), ('미션', 'Noun'),
# Nearest to ('가지', 'Noun'): ('것', 'Noun'), ('일단', 'Noun'), ('학기', 'Noun'), ('정도', 'Noun'), ('있다', 'Adjective'), ('애', 'Noun'), ('답사', 'Noun'), ('김동주', 'Noun'),
# Nearest to ('다', 'Josa'): ('수업', 'Noun'), ('책', 'Noun'), ('풋살', 'Noun'), ('학생', 'Noun'), ('넘어가고', 'Verb'), ('쓰긴', 'Verb'), ('세우고', 'Verb'), ('학점', 'Noun'),
# Nearest to ('학생', 'Noun'): ('것', 'Noun'), ('compactness', 'Alpha'), ('수업', 'Noun'), ('분', 'Noun'), ('답사', 'Noun'), ('학점', 'Noun'), ('디스', 'Noun'), ('교수', 'Noun'),
# Nearest to ('반', 'Noun'): ('때', 'Noun'), ('수업', 'Noun'), ('것', 'Noun'), ('compactness', 'Alpha'), ('답사', 'Noun'), ('학점', 'Noun'), ('통', 'Noun'), ('수학', 'Noun'),
# Nearest to ('MAS', 'Alpha'): ('code', 'Alpha'), ('course', 'Alpha'), ('id', 'Alpha'), ('강의', 'Noun'), ('0', 'Number'), ('text', 'Alpha'), ('종합', 'Noun'), ('B', 'Alpha'),
# Nearest to ('전', 'Noun'): ('바랍니다', 'Verb'), ('것', 'Noun'), ('하게', 'Verb'), ('디스', 'Noun'), ('기말고사', 'Noun'), ('하든', 'Noun'), ('1', 'Number'), ('학기', 'Noun'),
# Nearest to ('면', 'Josa'): ('평범', 'Noun'), ('결과', 'Noun'), ('제출', 'Noun'), ('정해져', 'Verb'), ('정확히는', 'Adjective'), ('기대했던', 'Adjective'), ('리뷰', 'Noun'), ('곧잘', 'Noun'),
# Nearest to ('를', 'Josa'): ('을', 'Josa'), ('060', 'Number'), ('조건', 'Noun'), ('따로', 'Adverb'), ('뭐라고', 'Verb'), ('예술', 'Noun'), ('황강', 'Noun'), ('된다고', 'Verb'),
# Nearest to ('자료', 'Noun'): ('교수', 'Noun'), ('특히', 'Adverb'), ('쪽글', 'Noun'), ('저', 'Noun'), ('해서', 'Verb'), ('답사', 'Noun'), ('통', 'Noun'), ('디스', 'Noun'),
# Average loss at step  22000 :  5.411709210634232
# Average loss at step  24000 :  5.402863183259964
# Average loss at step  26000 :  5.331508691430092
# Average loss at step  28000 :  5.231827291965485
# Average loss at step  30000 :  5.1882776041626935
# Average loss at step  32000 :  5.1883875226974485
# Average loss at step  34000 :  5.155115318775177
# Average loss at step  36000 :  5.175597727894783
# Average loss at step  38000 :  5.128346175551415

# %%
# Out:
# Nearest to ㅇㅇㅇ: ('것', 'Noun'), ('학점', 'Noun'), ('합니다', 'Verb'), ('compactness', 'Alpha'), ('답사', 'Noun'), ('학생', 'Noun'), ('수업', 'Noun'), ('중간', 'Noun'),
