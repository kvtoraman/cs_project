# %%
import json
import numpy as np

# %%
REVIEWS = "cs_reviews"

f = open("../reviews_in_one_txt/" + REVIEWS + ".txt","r",encoding="utf-8").readlines()
g = open("../reviews_in_one_txt/" + REVIEWS + "_nouns.txt","r",encoding="utf-8").readlines()

# %%
len(f)
# Out:
# 696

# %%
len(g)
# Out:
# 696

# %%
mp = {}
lls = []
index = {}
rev_index = {}
CNT = 0
for i in range(len(f)):
    course = json.loads(f[i])
    nouns = g[i].split()
    if course["course_code"] not in index:
        index[course["course_code"]] = CNT
        rev_index[CNT] = course["course_code"]
        CNT += 1
        lls.append([])
    for n in nouns:
        lls[index[course["course_code"]]].append(n)
        
    if course["course_code"] not in mp:
        mp[course["course_code"]] = {}
    for w in nouns:
        if w not in mp[course["course_code"]]:
            mp[course["course_code"]][w] = 0
        mp[course["course_code"]][w] += 1

# %%
js = {}
for k,v in mp.items():
#     print(k,v)
    js[k] = [[a,b] for a,b in v.items()]

# %%
with open("word_cloud_data.json","w",encoding="utf-8") as out:
    json.dump(js,out,ensure_ascii=False)

# %%
import gensim.downloader as api
from gensim.models import TfidfModel
from gensim.corpora import Dictionary

# %%
lls
# Out:
# [['오랜만',
#   '한국어',
#   '강의',
#   '개설',
#   '학점',
#   '니',
#   '예상',
#   '만큼',
#   '전공',
#   '수준',
#   '손',
#   '숙제',
#   '프로그래밍',
#   '프로젝트',
#   '4',
#   '5',
#   '5개',
#   '개',
#   '코딩',
#   '플젝',
#   '스펙',
#   '자유로워',
#   '당황',
#   '수',
#   '채점',
#   '시험',
#   '공부',
#   '양',
#   '교수님',
#   '한국어강의여',
#   '여',
#   '집중',
#   '듣기',
#   '하면',
#   '이해도',
#   '수업',
#   '수업중',
#   '중',
#   '얘기',
#   '저',
#   '개인적',
#   '유익',
#   '호불호',
#   '듯',
#   '제가',
#   '듣기',
#   '최',
#   '최광무',
#   '광무',
#   '교수님',
#   '마지막',
#   '학부',
#   '강의',
#   '로드',
#   '예전',
#   '진도',
#   '학점',
#   '자체',
#   '표준',
#   '표준점수',
#   '점수',
#   '차',
#   '순서',
#   '경계',
#   '3',
#   '4',
#   '시험',
#   '오픈',
#   '오픈북',
#   '북',
#   '준비',
#   '느냐에',
#   '공부',
#   '했어도',
#   '성적',
#   '저',
#   '이상',
#   '케이스',
#   '운',
#   '필요',
#   '개인적',
#   '학생',
#   '관심',
#   '노력',
#   '2012',
#   '가을',
#   '홈페이지',
#   '자료',
#   '영상',
#   '세상',
#   '수업',
#   '오토',
#   '오토마타',
#   '마',
#   '타',
#   '이외',
#   '언어',
#   '언어이론',
#   '이론',
#   '지식',
#   '수',
#   '프로젝트',
#   '한글',
#   '오토마',
#   '구성',
#   '생각',
#   '시간',
#   '한국어',
#   '수업',
#   '설명',
#   '컴퓨터',
#   '기반',
#   '튜',
#   '튜링머신',
#   '링',
#   '머신',
#   '기초',
#   '나',
#   '전반적',
#   '이해',
#   '수',
#   '한글',
#   '오토',
#   '오토마타',
#   '마',
#   '타',
#   '조합',
#   '제작',
#   '경험',
#   '프로젝트',
#   '프로젝트량',
#   '량',
#   '등',
#   '수',
#   '플젝',
#   '6',
#   '6개',
#   '개',
#   '전산',
#   '전산과로',
#   '과로',
#   '로드',
#   '수',
#   '유명',
#   '대로',
#   '타자기',
#   '오토',
#   '오토마타',
#   '마',
#   '타',
#   '스타일',
#   '점수',
#   '인풋',
#   '테스트',
#   '면',
#   '채점',
#   '채점방식',
#   '방식',
#   '언어',
#   '언어선택',
#   '선택',
#   '파이',
#   '을',
#   '추천',
#   '저',
#   '프로그램',
#   '적용',
#   '5',
#   '5번째',
#   '번째',
#   '시험',
#   '오픈',
#   '오픈북',
#   '북',
#   '인덱싱',
#   '문제',
#   '단답형',
#   '계산',
#   '계산실수',
#   '실수',
#   '하면',
#   '부분',
#   '부분점수',
#   '1',
#   '1점',
#   '점',
#   '주의',
#   '거',
#   '학점',
#   '컴퓨터',
#   '수학적',
#   '구성',
#   '가에',
#   '대',
#   '교수님',
#   '수업',
#   '수업중',
#   '중',
#   '수식',
#   '강조',
#   '이해',
#   '1',
#   '2',
#   '주',
#   '간격',
#   '문제',
#   '필기',
#   '필기숙제',
#   '숙제',
#   '학기',
#   '전체적',
#   '6',
#   '6개',
#   '개',
#   '플젝',
#   '수업',
#   '수업내용',
#   '내용',
#   '수식',
#   '개념',
#   '개념설명',
#   '설명',
#   '진행',
#   '디테일',
#   '부분',
#   '생략',
#   '느낌',
#   '편',
#   '시험',
#   '오픈',
#   '오픈북',
#   '북',
#   '6개정도',
#   '정도',
#   '시험시간',
#   '시간',
#   '반정',
#   '반정도로',
#   '도로',
#   '공부',
#   '공부안',
#   '안',
#   '어디',
#   '뭐',
#   '책',
#   '숙지',
#   '학점',
#   '한글',
#   '오토',
#   '오토마타',
#   '마',
#   '타',
#   '차례',
#   '과제',
#   '그것',
#   '수업',
#   '수업시간',
#   '시간',
#   '뜬구름',
#   '소리',
#   '교수님',
#   '학생',
#   '무례',
#   '번',
#   '주제',
#   '최',
#   '최광무',
#   '광무',
#   '후회',
#   '과목',
#   '글',
#   '별개',
#   '매시간',
#   '손',
#   '시험',
#   '오픈',
#   '오픈북',
#   '북',
#   '학점',
#   '편',
#   '수업',
#   '널',
#   '로드',
#   '과제',
#   '1',
#   '1개',
#   '개',
#   '플젝',
#   '7',
#   '7개',
#   '전산',
#   '300',
#   '300번',
#   '번',
#   '강의',
#   '한글',
#   '내용',
#   '내용면',
#   '면',
#   '커버',
#   '얘기',
#   '이중',
#   '도움',
#   '과목',
#   '설명',
#   '촘스키',
#   '분류',
#   '언어',
#   '레',
#   '대로',
#   '최종적',
#   '연산',
#   '수',
#   '튜',
#   '튜링머신',
#   '링',
#   '머신',
#   '효용',
#   '요',
#   '사실',
#   '현업',
#   '하이',
#   '하이레벨',
#   '레벨',
#   '일',
#   '컴파일러',
#   '개념',
#   '법',
#   '유용',
#   '1',
#   '최',
#   '최광무',
#   '광무',
#   '교수님',
#   '분',
#   '강의',
#   '때',
#   '척',
#   '필자',
#   '첵',
#   '사진',
#   '퇴근',
#   '나중',
#   '숙제',
#   '문제',
#   '부분',
#   '내용',
#   '2',
#   '플젝',
#   '이것',
#   '저것',
#   '결국',
#   '-3',
#   '휴대',
#   '휴대폰',
#   '폰',
#   '한글',
#   '자판',
#   '마지막',
#   '생각',
#   '노',
#   '성의',
#   '코딩',
#   '코딩량',
#   '량',
#   '조심',
#   '한',
#   '입력',
#   '입력기',
#   '기',
#   '출력',
#   '지원',
#   '언어',
#   '처음',
#   '교수님',
#   '인성',
#   '문제',
#   '이거',
#   '바',
#   '자습',
#   '생각',
#   '알고리즘',
#   '개론',
#   '최',
#   '최성희',
#   '성희',
#   '열',
#   '열다섯배',
#   '다섯',
#   '배',
#   '정도',
#   '강의',
#   '평가',
#   '박',
#   '조교',
#   '친절',
#   '이거',
#   '오피스',
#   '워',
#   '가세',
#   'ㄹ',
#   'ㄹㅇ개꿀',
#   'ㅇ',
#   '개꿀',
#   '교수님',
#   '니들',
#   '줄',
#   '명언',
#   '교수님',
#   '제공',
#   '자료',
#   '수업',
#   '등등',
#   '컨텐츠',
#   '유감',
#   '자괴감',
#   '고',
#   '수준',
#   '과제',
#   '오토',
#   '오토마',
#   '마',
#   '자체',
#   '컴',
#   '공',
#   '공학과',
#   '학과',
#   '유익',
#   '내용',
#   '수강',
#   '수강신청',
#   '신청',
#   '자습',
#   '과목',
#   '전',
#   '전필',
#   '필',
#   '나',
#   '최',
#   '최광무',
#   '광무',
#   '교수님',
#   '저',
#   '수업',
#   '글',
#   '필기',
#   '자료',
#   '도움',
#   '내용',
#   '문제',
#   '풀이',
#   '과제',
#   '이해',
#   '정도',
#   '플젝으로',
#   '앞',
#   '분',
#   '설명',
#   '대로',
#   '3',
#   '4',
#   '키패드',
#   '오토',
#   '오토마타',
#   '마',
#   '타',
#   '6',
#   '6개',
#   '개',
#   '학점',
#   '미디안',
#   '미디안-5',
#   '-5',
#   '주시',
#   '만점',
#   '중간',
#   '평균',
#   '15',
#   '기말',
#   '20',
#   '과목',
#   '과제',
#   '교수님',
#   '아랫분',
#   '주신',
#   '이번',
#   '학기',
#   '2015',
#   '가을',
#   '내용',
#   '추가',
#   '오',
#   '오타도',
#   '타도',
#   '렉',
#   '자체',
#   '부실',
#   '데',
#   '숙제',
#   '출제',
#   '구',
#   '구글링',
#   '글',
#   '링',
#   '공부',
#   '강의',
#   '정신',
#   '진도',
#   '중구난방',
#   '수업',
#   '수업시간',
#   '시간',
#   '중간고사',
#   '시험',
#   '시험시간',
#   '이',
#   '이번',
#   '번',
#   '최',
#   '학생',
#   '예',
#   '바라면',
#   '안',
#   '학점',
#   '정리',
#   '요',
#   '46',
#   '평균',
#   '수업',
#   '질',
#   '편',
#   '동양',
#   '동양고전',
#   '고전',
#   '시사',
#   '이야기',
#   '강의',
#   '자료',
#   '페이지',
#   '한번',
#   '오',
#   '오타가',
#   '타가',
#   '데',
#   '상당',
#   '주의',
#   '필요',
#   '학생',
#   '레이저',
#   '눈',
#   '건강',
#   '개념',
#   '자습',
#   '가능',
#   '과제',
#   '한글',
#   '한글입력기',
#   '입력',
#   '기',
#   '제작',
#   '1',
#   '과제',
#   '수업',
#   '내용',
#   '바탕',
#   '홈',
#   '홈워크',
#   '워크',
#   '대부분',
#   '문제',
#   '기본적',
#   '자체',
#   '경우',
#   '플젝',
#   '6',
#   '6번',
#   '번',
#   '기억',
#   '초반',
#   '개',
#   '뒤',
#   '코드',
#   '거로',
#   '거로워',
#   '워',
#   '지시',
#   '지시사항',
#   '사항',
#   '시간',
#   '2',
#   '시험',
#   '시험오픈북',
#   '오픈',
#   '북',
#   '저',
#   '렉',
#   '노트',
#   '프린트',
#   '책',
#   '외',
#   '나',
#   '샘플',
#   '사실',
#   '뭐',
#   '준비',
#   '도움',
#   '개인적',
#   '생각',
#   '생각일지',
#   '일지',
#   '오토',
#   '오토마',
#   '마',
#   '이해도',
#   '중요',
#   '시험장',
#   '머리',
#   '답',
#   '무엇',
#   '밥',
#   '코',
#   '코바라',
#   '바라',
#   '3',
#   '강의',
#   '강의최광무',
#   '최',
#   '광무',
#   '교수님',
#   '동양',
#   '동양철학개론',
#   '철학',
#   '개론',
#   '최광무',
#   '독특',
#   '분',
#   '느낌',
#   '제가',
#   '보기',
#   '괴짜',
#   '천재',
#   '스타일',
#   '시고',
#   '한번',
#   '이해',
#   '4',
#   '학점',
#   '학점점수',
#   '점수',
#   '대',
#   '상위권',
#   '중',
#   '중상',
#   '중상위권',
#   '위권',
#   '기대',
#   '단계',
#   '위',
#   '수',
#   '수강',
#   '전',
#   '강의평가',
#   '평가',
#   '정도',
#   '각',
#   '레터',
#   '수정',
#   '주신',
#   '줄',
#   '아래',
#   '최종',
#   '최종성적표',
#   '성적',
#   '표',
#   '평균',
#   '평균점수',
#   '이거',
#   '거지',
#   '교수님',
#   '수업',
#   '자체',
#   '별',
#   '강의',
#   '말',
#   '수',
#   '혼자',
#   '공부',
#   '니',
#   '슬라이드',
#   '오',
#   '오타때문',
#   '타',
#   '때문',
#   '이해',
#   '시험',
#   '오픈',
#   '오픈북',
#   '북',
#   '도움',
#   '시험장',
#   '머리',
#   '수학',
#   '감각',
#   '사람',
#   '유리함',
#   '숙제',
#   '10',
#   '10개',
#   '개',
#   '플젝',
#   '6',
#   '6개',
#   '로드',
#   '빡',
#   '빡세요',
#   '세요',
#   '최소한',
#   '진도',
#   '점',
#   '장점',
#   '과목',
#   '학점',
#   '상위권',
#   '대',
#   '적용',
#   '이야기',
#   '하위권',
#   '이하',
#   '은',
#   '가차',
#   '후회',
#   '일',
#   '다섯',
#   '손가락',
#   '안',
#   '저번',
#   '저번학기',
#   '학기',
#   '오토',
#   '오토마타',
#   '마',
#   '타',
#   '재미',
#   '강의',
#   '학',
#   '학점도',
#   '점도',
#   '비율',
#   '2.6',
#   '2.7',
#   '4.7',
#   '정도',
#   '1',
#   '1점',
#   '점',
#   '차이나',
#   '중간기',
#   '중간기말',
#   '말',
#   '시험',
#   '0',
#   '누',
#   '학점',
#   '비율',
#   '2',
#   '3',
#   '4',
#   '1',
#   '1',
#   '로드',
#   '내용',
#   '처음',
#   '조금',
#   '수학',
#   '논리적',
#   '증명',
#   '수',
#   '2',
#   '학점',
#   '이번',
#   '절반',
#   '작년',
#   '3',
#   '최',
#   '최광무',
#   '광무',
#   '교수님',
#   '이해',
#   '분',
#   '학생',
#   '이상',
#   '거',
#   '본인',
#   '앞',
#   '책상',
#   '칠판',
#   '이름',
#   '사실',
#   '수업',
#   '수업',
#   '내용',
#   '타',
#   '전산',
#   '전산학부',
#   '학부',
#   '과목',
#   '느낌',
#   '수학',
#   '시험',
#   '문제',
#   '교수님',
#   '한글',
#   '물론',
#   '도중',
#   '얘기',
#   '이것을',
#   '학생',
#   '저',
#   '신경',
#   '진도',
#   '한글모아쓰기',
#   '모아',
#   '쓰기',
#   '기계',
#   '학기',
#   '프로젝트',
#   '스펙에',
#   '자유',
#   '힘',
#   '진',
#   '명시',
#   '스펙',
#   '이것',
#   '점수',
#   '출석',
#   '중요',
#   '시간',
#   '때',
#   '짓',
#   '뭐',
#   '상책',
#   '오픈',
#   '오픈북',
#   '북',
#   '개념',
#   '이해',
#   '위주',
#   '공부',
#   '추천',
#   '이후',
#   '컴파일러',
#   '때문',
#   '숙지',
#   '도움',
#   '예년',
#   '올해',
#   '성적'],
#  ['오트',
#   '교수님',
#   '원래',
#   '학점',
#   '1',
#   '1학점',
#   '정도',
#   '로드',
#   '숙제',
#   '3',
#   '3번',
#   '번',
#   '출석',
#   '출석체크',
#   '체크',
#   '학기',
#   '학기중',
#   '중',
#   '성적',
#   '반영',
#   '듯',
#   '사실',
#   '알고리즘',
#   '수업',
#   '수업때',
#   '때',
#   '내용',
#   '수학적',
#   '설명',
#   '증명',
#   '대',
#   '시험',
#   '기말',
#   '한번',
#   '관심',
#   '분',
#   '수'],
#  ['허',
#   '혁',
#   '교수님',
#   '키',
#   '키텍',
#   '텍',
#   '수업',
#   '흔',
#   '유명',
#   '등',
#   '개념',
#   '수',
#   '플젝',
#   '매',
#   '매학기',
#   '학기',
#   '프로젝트',
#   '이번',
#   '행렬',
#   '행렬곱셈',
#   '곱셈',
#   '최적화',
#   '이용',
#   '처리',
#   '속도',
#   '100',
#   '100배',
#   '배',
#   '광경',
#   '목격',
#   '말',
#   '제가',
#   '허',
#   '혁',
#   '교수님',
#   '키',
#   '키텍',
#   '텍',
#   '과목',
#   '최신',
#   '트렌드',
#   '최대한',
#   '반영',
#   '노력',
#   '그로',
#   '2012',
#   '가을',
#   '병렬',
#   '프로그래밍',
#   '과제',
#   '목표',
#   '등',
#   '실습',
#   '영어',
#   '하심',
#   '한국',
#   '학생',
#   '이해',
#   '부분',
#   '한글',
#   '설명',
#   '강',
#   '태',
#   '편',
#   '로드',
#   '적지',
#   '걱정',
#   '정도',
#   '학점',
#   '본인',
#   '만큼',
#   'ㅎ',
#   '전산',
#   '학생',
#   '한번쯤',
#   '법',
#   '허',
#   '키',
#   '최고',
#   '수업',
#   '과제',
#   '과제량',
#   '량',
#   '편',
#   '수',
#   '저',
#   '수업시간',
#   '시간',
#   '부분',
#   '유용',
#   '최신',
#   '정보',
#   '다양',
#   '지식',
#   '설명',
#   '전반적',
#   '이해',
#   '제가',
#   '학기',
#   '소문',
#   '로드',
#   '내용',
#   '허',
#   '키',
#   '전',
#   '전산',
#   '산',
#   '학생',
#   '하드웨어',
#   '포기',
#   '말',
#   '김',
#   '김순태',
#   '순',
#   '태',
#   '교수님',
#   '학점',
#   '주세',
#   '소문',
#   '허',
#   '허병렬',
#   '병렬',
#   '내용',
#   '플젝',
#   '등',
#   '개인적',
#   '플젝',
#   '하루',
#   '하루정도하면',
#   '정도',
#   '하면',
#   '거',
#   '4',
#   '4개',
#   '개',
#   '키',
#   '고',
#   '김',
#   '김동',
#   '동',
#   '교수님',
#   '교수님꺼',
#   '꺼',
#   '영어',
#   '집중',
#   '시험',
#   '시험문제',
#   '문제',
#   '비교',
#   '이스트',
#   '만족',
#   '안',
#   '수업',
#   '수업중하나',
#   '중',
#   '하나',
#   '프로젝트',
#   '시험',
#   '족보',
#   '편',
#   '교수님',
#   '전날',
#   '음주',
#   '수업',
#   '꿀',
#   '상황',
#   '내용',
#   '배우기',
#   '책',
#   '편이',
#   '소문',
#   '허',
#   '키',
#   '플젝',
#   '아키텍쳐',
#   '하나',
#   '구현',
#   '핀',
#   '핀토스식',
#   '토스',
#   '식',
#   '축적',
#   '플젝이었습니',
#   '교수님',
#   '중간',
#   '중간중간',
#   '수업',
#   '번',
#   '숙제',
#   '기말',
#   '기말고사',
#   '고사',
#   '기출',
#   '90',
#   '당황',
#   '기억',
#   '기초',
#   '설명',
#   '때문',
#   '걱정',
#   '학점',
#   '윤',
#   '윤현수',
#   '현수',
#   '교수님',
#   '키',
#   '공부',
#   '건',
#   '참',
#   '학점',
#   '신경',
#   '분',
#   '이것',
#   '족보',
#   '뭐',
#   '방법',
#   '수업',
#   '출석',
#   '안',
#   '강의',
#   'ㅜ',
#   '시스템',
#   '시스템쪽',
#   '쪽',
#   '강의',
#   '영어',
#   '유창',
#   '컴퓨터',
#   '아키텍쳐',
#   '개념',
#   '정도',
#   '동시',
#   '프로젝트',
#   '수업',
#   '수업시간',
#   '시간',
#   '내용',
#   '구현',
#   '방식',
#   '수업간',
#   '간',
#   '상호',
#   '시너지',
#   '난이도',
#   '학생',
#   '의견',
#   '반영',
#   '조절',
#   '신경',
#   '주신',
#   '느낌',
#   '성적',
#   '듯',
#   '학점',
#   '윤',
#   '키',
#   '건',
#   '허',
#   '키',
#   '하면',
#   '수업',
#   '플젝',
#   '거',
#   '유명',
#   '교수님',
#   '하나',
#   '하나만',
#   '만',
#   '가치',
#   '연구실',
#   '개인적',
#   '가도',
#   '친절',
#   '체감',
#   '난이도',
#   '생각',
#   '과목',
#   '정도',
#   '내용',
#   '플젝과',
#   '괴리',
#   '때',
#   '구현',
#   '느낌',
#   '검사',
#   '자동화',
#   '테스트',
#   '추천',
#   '눈',
#   '실제',
#   '채점',
#   '결과',
#   '1',
#   '개요',
#   '개요공강',
#   '공',
#   '강',
#   '학점',
#   '윤',
#   '키',
#   '강의',
#   '로드',
#   '당신',
#   '2',
#   '족보',
#   '축하',
#   '수',
#   '수업',
#   '한번',
#   '안',
#   '공부',
#   '과',
#   '과제도',
#   '제도',
#   '솔루션',
#   '배',
#   '학생',
#   '힘',
#   '성적',
#   '교수님',
#   '술',
#   '새',
#   '새부대',
#   '부대',
#   '명언',
#   '강의족족',
#   '족',
#   '사용',
#   '시험',
#   '책',
#   '생각',
#   '3',
#   '로드출석점수',
#   '출석',
#   '점수',
#   '실라',
#   '실라버스',
#   '버스',
#   '존재',
#   '간증',
#   '반영',
#   '애시당초',
#   '첵',
#   '조교',
#   '자기주',
#   '가능',
#   '안가',
#   '4',
#   '숙제',
#   '숙제솔루션',
#   '구',
#   '구글링',
#   '글',
#   '링',
#   '문제',
#   '제출',
#   '만점',
#   '경우',
#   '뿐',
#   '5',
#   '기타',
#   '기타족보',
#   '자기',
#   '의미',
#   '거',
#   '완벽',
#   '일치',
#   '때문',
#   '여담',
#   '자유도',
#   '지원',
#   '이상',
#   '이상적인',
#   '적인',
#   '1',
#   '교수님',
#   '강의',
#   '내용',
#   '교재',
#   '책',
#   '듯',
#   '2',
#   '플젝',
#   '각종',
#   '기능',
#   '시뮬레이션',
#   '재미',
#   '데',
#   '격',
#   '필자',
#   '당시',
#   '조교',
#   '코딩',
#   '솔루션',
#   '프로그램',
#   '버그',
#   '노',
#   '노답',
#   '답',
#   '구현',
#   '거',
#   '거여',
#   '여',
#   '플메',
#   '널',
#   '3',
#   '학점',
#   '소문',
#   '저',
#   '강의',
#   '중',
#   '허',
#   '혁',
#   '교수님',
#   '키',
#   '키강의',
#   '최고',
#   '영어',
#   '학생',
#   '친절',
#   '과제',
#   '과목',
#   '학점',
#   '보통',
#   '소문',
#   '올해',
#   '족보',
#   '2007',
#   '2007년도',
#   '년도',
#   '50',
#   '2015',
#   '2015년',
#   '년',
#   '20',
#   '30',
#   '자',
#   '철퇴',
#   '공부',
#   '했어도',
#   '키',
#   '자괴',
#   '자괴감',
#   '감',
#   '괴',
#   '워',
#   '사실',
#   '이',
#   '강의',
#   '평가',
#   '수업',
#   '후기',
#   '정',
#   '정도로',
#   '도로',
#   '작성',
#   '1',
#   '정말',
#   '로드',
#   '학기',
#   '숙제',
#   '4',
#   '4번',
#   '번',
#   '프로젝트',
#   '3',
#   '3번',
#   '3개중',
#   '개중',
#   '개',
#   '시뮬레이터',
#   '시뮬레이션',
#   '후',
#   '결과',
#   '보고서',
#   '이해도',
#   '이해도만',
#   '만',
#   '필요',
#   '마지막',
#   '2',
#   '2개',
#   '하나',
#   '시험',
#   '시험기간',
#   '기간',
#   '직전',
#   '2주',
#   '주',
#   '점',
#   '스트레스',
#   '만',
#   '하',
#   '상대',
#   '상대평가여',
#   '여',
#   '학생',
#   '구현',
#   '효율',
#   '순서',
#   '순서대',
#   '대',
#   '점수',
#   '주심',
#   '1주일',
#   '주일',
#   '누',
#   '시간',
#   '붑고',
#   '노력',
#   '본',
#   '내용',
#   '230',
#   '시스템',
#   '시스템프로그래밍',
#   '프로그래밍',
#   '과목',
#   '수강',
#   '부분',
#   '프로세서',
#   '디자인',
#   '정도',
#   '완전',
#   '외',
#   '거',
#   '생각',
#   '진도',
#   '하나하나',
#   '전',
#   '집중',
#   '잠',
#   '공책',
#   '노트테이킹',
#   '스타일',
#   '호불호',
#   '듯',
#   '출석',
#   '출석체크',
#   '체크',
#   '수금',
#   '오전',
#   '10.30',
#   '시작',
#   '때',
#   '확인',
#   '라이프',
#   '첵',
#   '첵점수',
#   '5',
#   '5점중',
#   '점',
#   '중',
#   '1개',
#   '개',
#   '차감',
#   '5번',
#   '번',
#   '이후',
#   '교과서',
#   '필수',
#   '렉',
#   '슬라이드',
#   '설명',
#   '설명위주',
#   '위주',
#   '다이어그램',
#   '교수님',
#   '단축',
#   '때문',
#   '나중',
#   '시험공부',
#   '공부',
#   '도움',
#   '6',
#   '질문',
#   '수업시간',
#   '강조',
#   '정확',
#   '무엇',
#   '문장',
#   '답',
#   '7',
#   '성적',
#   '편',
#   '김',
#   '키',
#   '로드',
#   '등에',
#   '허',
#   '윤',
#   '중간',
#   '널',
#   '숙제',
#   '4',
#   '4개',
#   '개',
#   '플젝',
#   '3',
#   '3개',
#   '교재',
#   '문제',
#   '풀기',
#   '어셈블리',
#   '프로그래밍',
#   '1',
#   '1개',
#   '사실',
#   '언어',
#   '코드',
#   '번역',
#   '거',
#   '시뮬레이터',
#   '보고서',
#   '작성',
#   '캐시',
#   '메모리',
#   '최적화',
#   '성적',
#   '공부',
#   '만큼',
#   '전산기',
#   '전산기조직',
#   '조직',
#   '명령어',
#   '처리',
#   '단순',
#   '구조',
#   '파이',
#   '파이프라이닝를',
#   '프라이',
#   '닝를',
#   '이후',
#   '캐시',
#   '등',
#   '김',
#   '김순태',
#   '순',
#   '태',
#   '교수님',
#   '수업',
#   '교과서',
#   '밀도',
#   '강의',
#   '때문',
#   '재미',
#   '로드',
#   '숙제',
#   '4',
#   '4번',
#   '번',
#   '플젝',
#   '연습',
#   '문제',
#   '풀기',
#   '어셈블리',
#   '어셈블리어로',
#   '어로',
#   '기와',
#   '밴',
#   '마크',
#   '성능',
#   '시험',
#   '학점',
#   '시간표',
#   '수',
#   '금',
#   '냄새',
#   '기억',
#   '수업',
#   '점',
#   '정신',
#   '강의',
#   '만',
#   '거랑',
#   '텍스트',
#   '텍스트북',
#   '북',
#   '예제',
#   '이론',
#   '과제',
#   '책',
#   '문제',
#   '거',
#   '플젝',
#   '벤치',
#   '벤치마크',
#   '마크',
#   '결과',
#   '분석',
#   '2',
#   '2개',
#   '개',
#   '새',
#   '캐시',
#   '정책',
#   '마지막',
#   '제외',
#   '나머지',
#   '시간',
#   '필요',
#   '널',
#   '사실',
#   '때',
#   '내용',
#   '해결',
#   '수',
#   '의심',
#   '막했',
#   '성적',
#   '중간',
#   '기말',
#   '점수',
#   '좌우',
#   '랜덤',
#   '랜덤학점',
#   '학점',
#   '학점교수님',
#   '교수님',
#   '랜덤학점봄학기',
#   '봄',
#   '학기',
#   '최종',
#   '성적',
#   '4',
#   '4일',
#   '일',
#   '전',
#   '중간고사',
#   '기말',
#   '기말고사',
#   '고사',
#   '기대',
#   '결국',
#   '업',
#   '업로드',
#   '로드',
#   '12',
#   '12시간',
#   '시간',
#   '시점',
#   '중간',
#   '중간기말',
#   '점수',
#   '수업',
#   '자유도',
#   '족보',
#   '의존도',
#   '유명',
#   '윤',
#   '키',
#   '전자',
#   '후자',
#   '절반',
#   '정도',
#   '처음',
#   '끝',
#   '주시',
#   '바람',
#   '자습',
#   '나중',
#   '사람',
#   '90',
#   '90명',
#   '명',
#   '학생',
#   '마음',
#   '때문',
#   '주실',
#   '때',
#   '출석',
#   '인원',
#   '양심',
#   '가책',
#   '핑계',
#   '수',
#   '교재',
#   '숙제',
#   '교과서',
#   '연습',
#   '연습문제',
#   '문제',
#   '개',
#   '설명',
#   '계열',
#   '주위',
#   '확신',
#   '소문',
#   '강의',
#   '1',
#   '2',
#   '출석',
#   '출석점수',
#   '점수',
#   '3',
#   '족보',
#   '위주',
#   '공부',
#   '시험',
#   '단',
#   '건',
#   '중간고사',
#   '얘기',
#   '기말',
#   '기말고사',
#   '고사',
#   '대신',
#   '대비',
#   '수업',
#   '렉',
#   '노트',
#   '추측',
#   '내용',
#   '문제',
#   '중',
#   '책',
#   '언급',
#   '중간',
#   '비중',
#   '때문',
#   '윤',
#   '교수님',
#   '키',
#   '학점',
#   '시간',
#   '투자',
#   '후기',
#   '번',
#   '보기',
#   '분포',
#   '공지',
#   '고',
#   '고득점자',
#   '득점자',
#   '점',
#   '숙지',
#   '중간고사',
#   '수업',
#   '중간',
#   '족보',
#   '기말',
#   '안',
#   '정도',
#   '공부',
#   '문제',
#   '완전',
#   'ㅠ',
#   'ㅠ중간',
#   '상위',
#   '10',
#   '10프로',
#   '프로',
#   '하위',
#   '30',
#   '30프로',
#   '학점',
#   '듯',
#   'ㅎ',
#   'ㅎㄷㄷ',
#   'ㄷ',
#   '무엇',
#   '강의',
#   '강의인가',
#   '인가',
#   '학점',
#   '주시',
#   '성적',
#   '중간고사',
#   '점수',
#   '기말',
#   '기말고사',
#   '고사',
#   '점대',
#   '얼마',
#   '수',
#   '제가',
#   '커트',
#   '커트라인',
#   '라인',
#   '등',
#   '중간',
#   '30',
#   '30등',
#   '등',
#   '10',
#   '10등',
#   '출석',
#   '체크',
#   '수업',
#   '부담',
#   '전',
#   '하면서',
#   '이후',
#   '이해도',
#   '안',
#   '안가면',
#   '가면',
#   '공부',
#   '가기',
#   '생각',
#   '책',
#   '이해',
#   '이해안',
#   '부분',
#   '교수님',
#   '설명',
#   '중요',
#   '시험',
#   '도움',
#   '족보',
#   '말',
#   '거',
#   '저',
#   '둘',
#   '참여',
#   '숙제',
#   '원래',
#   '단원',
#   '때',
#   '번',
#   '설명도',
#   '후회',
#   '수업',
#   '내용',
#   '교수님',
#   '설명',
#   '프로젝트',
#   '하려',
#   '기도',
#   '하',
#   '필기',
#   '필기숙제',
#   '숙제',
#   '번',
#   '공지',
#   '출석',
#   '필수',
#   '정도',
#   '여유',
#   '성적',
#   '100',
#   '디지털',
#   '직',
#   '구조',
#   '정도',
#   '심도',
#   '프로젝트',
#   '4',
#   '4개',
#   '개',
#   '1',
#   '2',
#   '2명',
#   '명',
#   '팀',
#   '팀프로젝트',
#   '내용',
#   '무엇',
#   '만',
#   '구현',
#   '구현자체',
#   '자체',
#   '공부',
#   '공부량',
#   '량',
#   '중간',
#   '기말',
#   '기말성적',
#   '성적',
#   '학점',
#   '평범',
#   '듯',
#   '허',
#   '허교수님',
#   '교수님',
#   '수업',
#   '전산',
#   '분위기',
#   '중',
#   '하나',
#   '생각',
#   '보충',
#   '보충설명',
#   '설명',
#   '질문',
#   '자유',
#   '때문',
#   '사소',
#   '오',
#   '오개념',
#   '개념',
#   '유용',
#   '지식',
#   '경우',
#   '첵',
#   '데',
#   '출석률',
#   '강의',
#   '키',
#   '독학',
#   '윤',
#   ...],
#  ['전산',
#   '숨',
#   '필',
#   '영어',
#   '수업',
#   '처음',
#   '자상',
#   '교수님',
#   '로드',
#   '프로젝트',
#   '연산',
#   '퀴즈',
#   '해결',
#   '번째',
#   '플젝',
#   '나머지',
#   '해석',
#   '폭탄',
#   '폭탄해체',
#   '해체',
#   '이용',
#   '구현',
#   '등',
#   '영어',
#   '교수님',
#   '수업',
#   '준비',
#   '플젝',
#   '과목',
#   '실습',
#   '1',
#   '2',
#   '3',
#   '4',
#   '5',
#   '6',
#   '추천',
#   '말',
#   '런지',
#   '플젝',
#   '한데',
#   '내용',
#   '폭탄',
#   '폭탄제거',
#   '제거',
#   '거',
#   '나름',
#   '도전',
#   '욕구',
#   '분',
#   '방학',
#   '때',
#   '윤',
#   '우의',
#   '프로그래밍',
#   '책',
#   '전산',
#   '처음',
#   '컴퓨터',
#   '조금',
#   '이해',
#   '과목',
#   '여기',
#   '개념',
#   '키',
#   '만큼',
#   '강추',
#   '키',
#   '허',
#   '이하',
#   '생략',
#   '플젝',
#   '교수님',
#   '점',
#   '수업',
#   '플젝',
#   '하나',
#   '앞',
#   '전산',
#   '난관',
#   '아무것',
#   '과목',
#   '과목자체',
#   '자체',
#   '빡',
#   '빡세요',
#   '세요',
#   '교수님',
#   '교재',
#   '플젝',
#   '중간고사',
#   '전',
#   '어셈블리',
#   '레지스터',
#   '스택',
#   '등',
#   '다루',
#   '다루고요',
#   '고요',
#   '후반부',
#   '프로세스',
#   '메모리',
#   '네트워크',
#   '다양',
#   '것들',
#   '공부',
#   '스타일',
#   '생물',
#   '시간',
#   '투자',
#   '하구',
#   '플젝들',
#   '경험',
#   '개',
#   '당',
#   '평균',
#   '5',
#   '5일정도',
#   '일',
#   '정도',
#   '6',
#   '6개',
#   '앞',
#   '3',
#   '3개',
#   '일종',
#   '퍼즐',
#   '퍼즐문제',
#   '문제',
#   '거',
#   '뒤',
#   '코딩',
#   '해당',
#   '내용',
#   '숙지',
#   '중요',
#   '만큼',
#   '생각',
#   '강의',
#   '때',
#   '이',
#   '프로젝트',
#   '사실',
#   '솔루션',
#   '구',
#   '구글링',
#   '글',
#   '링',
#   '가급적',
#   '해결',
#   '추천',
#   '시험',
#   '문제',
#   '수',
#   '수준',
#   '학점',
#   '편',
#   '코딩',
#   '오신',
#   '분',
#   '유리',
#   '안드로메다',
#   '강의',
#   '덕분',
#   '주저',
#   '드랍',
#   '수',
#   '상처',
#   '학점',
#   '학점수업',
#   '수업',
#   '널',
#   '널널',
#   '숙제',
#   '건',
#   '구드',
#   '럭',
#   '이번',
#   '이번학기',
#   '학기',
#   '플젝',
#   '3',
#   '3개',
#   '개',
#   '남',
#   '꿀',
#   '1',
#   '널',
#   '널널',
#   '헛수고',
#   '휴강',
#   '수업',
#   '귀',
#   '교수님',
#   '이',
#   '이티브',
#   '티브',
#   '영어',
#   '강의',
#   '질문',
#   '조교',
#   '상처',
#   '남',
#   '학점',
#   '청강',
#   '추천',
#   '플젝',
#   '7',
#   '7개',
#   '개',
#   '교수님',
#   '수업',
#   '밑',
#   '님',
#   '말씀',
#   '오신',
#   '중간',
#   '휴강',
#   '번',
#   '수업진행',
#   '진행',
#   '어려움',
#   '조교',
#   '일',
#   '일처리',
#   '처리',
#   '여',
#   '가지',
#   '만큼',
#   '학점',
#   '얘기',
#   '줄',
#   '평균',
#   '평균정도',
#   '정도',
#   '사실',
#   '기말',
#   '전주',
#   '조교',
#   '답장',
#   '이후',
#   '잠수',
#   '첵',
#   '교수님',
#   '강의',
#   '편',
#   '학점',
#   '저',
#   '거',
#   '플젝',
#   '교수님',
#   '강의',
#   '문제',
#   '조',
#   '조교가',
#   '교가',
#   '플젝하',
#   '도움',
#   '주고',
#   '기말',
#   '기말고사',
#   '고사',
#   '성적',
#   '학점',
#   '듯',
#   '학기',
#   '만큼',
#   '학점',
#   '플젝',
#   '7',
#   '7개',
#   '개',
#   '로드',
#   '감당',
#   '과목',
#   '존',
#   '각오',
#   '할거',
#   '학점',
#   '편',
#   '생각',
#   '중간',
#   '평균',
#   '기말',
#   '언저리',
#   '이번',
#   '이번학기',
#   '학기',
#   '수강생',
#   '학점상승',
#   '상승',
#   '이유',
#   '플젝',
#   '시험',
#   '으',
#   '분',
#   '조',
#   '조교',
#   '교',
#   '별로',
#   '도움',
#   '과제',
#   '특성',
#   '특성상의',
#   '상의',
#   '문제',
#   '정도',
#   '교수님',
#   '강의',
#   '영어',
#   '설명',
#   '표정',
#   '한글',
#   '1',
#   '기말',
#   '기말고사',
#   '고사',
#   '성적',
#   '줌',
#   '2',
#   '상위권',
#   '듯',
#   '안주',
#   '3',
#   '플젝',
#   '7',
#   '7개',
#   '개',
#   '하나',
#   '해결',
#   '딜레이',
#   '다음',
#   '다음과제',
#   '과제',
#   '부담',
#   '학기',
#   '4',
#   '강의',
#   '수준',
#   '거',
#   '지금',
#   '강의중',
#   '중',
#   '최고',
#   '평소',
#   '플젝',
#   '시험',
#   '시험기간',
#   '기간',
#   '널',
#   '프로젝트',
#   '난이도',
#   '편',
#   '외',
#   '저',
#   '학점',
#   '분',
#   '개인적',
#   '수업',
#   '15',
#   '15분',
#   '분',
#   '수업진도',
#   '진도',
#   '조절',
#   '실패',
#   '나중',
#   '하루',
#   '교수님',
#   '불성실',
#   '눈',
#   '플젝',
#   '7',
#   '7개',
#   '개',
#   '플젝들입니다',
#   '처음',
#   '입장',
#   '학점',
#   '안주',
#   '전산',
#   '전산학부',
#   '학부',
#   '2',
#   '2학년',
#   '학년',
#   '진',
#   '전',
#   '전필',
#   '필',
#   '수업',
#   '커리큘림',
#   '사전',
#   '느낌',
#   '영어',
#   '강의',
#   '문제',
#   '진도',
#   '속도',
#   '조절',
#   '실패',
#   '기말',
#   '직전',
#   '내용',
#   '폭풍',
#   '커버',
#   '플젝',
#   '7',
#   '7개',
#   '개',
#   '로드',
#   '개인적',
#   '플젝들',
#   '들',
#   '학기',
#   '추천',
#   '때',
#   '거',
#   '하면서',
#   '때문',
#   '시험',
#   '응용',
#   '난이도',
#   '애초',
#   '개념',
#   '과목',
#   '처음',
#   '랩',
#   '총',
#   '7',
#   '7개',
#   '개',
#   '그거',
#   '학점',
#   '생각',
#   '시험',
#   '결과',
#   '성적',
#   '결정',
#   '숙제',
#   '2',
#   '2학년',
#   '학년',
#   '정상적',
#   '수업',
#   '다루',
#   '내용',
#   '전산',
#   '전반적',
#   '교수님',
#   '차이',
#   '저',
#   '가을',
#   '매',
#   '시간',
#   '진도',
#   '느낌',
#   '수업',
#   '과제',
#   '로',
#   '로우레벨',
#   '우',
#   '레벨',
#   '지식',
#   '수',
#   '나중',
#   '키나',
#   '임',
#   '임베디드',
#   '베',
#   '디드',
#   '등',
#   '과목',
#   '수강',
#   '때',
#   '도움',
#   '강의',
#   '내용',
#   '외',
#   '궁금증',
#   '100',
#   '확률',
#   '만족',
#   '남',
#   '답변',
#   '총',
#   '4',
#   '4개',
#   '개',
#   '허',
#   '교수님',
#   '가능',
#   '추천',
#   '퀴즈',
#   '4',
#   '4번',
#   '번',
#   '플젝',
#   '4개',
#   '개',
#   '중간',
#   '기말',
#   '학',
#   '학기초',
#   '기초',
#   '중간고사',
#   '고사',
#   '전',
#   '3',
#   '3개',
#   '이후',
#   '결국',
#   '하나',
#   '덕분',
#   '저',
#   '피해',
#   '3번째',
#   '번째',
#   '구현',
#   '기말고사',
#   '족보',
#   '거',
#   '다',
#   '꿀',
#   '라',
#   '말',
#   '사실',
#   '수업',
#   '편',
#   '앞',
#   '재미',
#   '질문',
#   '친절',
#   '답변',
#   '학점',
#   '소문',
#   '학점',
#   '강의',
#   '첨',
#   '듣기',
#   '웟',
#   '데',
#   '과제',
#   '플젝',
#   '개',
#   '하루',
#   '허',
#   '존',
#   '김',
#   '김대영',
#   '대영',
#   '교수님',
#   '레',
#   '꿀',
#   '학점',
#   '봄',
#   '사랑',
#   '김',
#   '김대영',
#   '대영',
#   '교수님',
#   '저희',
#   '실라',
#   '실라버스',
#   '버스',
#   '기적',
#   '번',
#   '수업',
#   '시간',
#   '10',
#   '10분',
#   '분',
#   '정도',
#   '퀴즈',
#   '대체',
#   '이',
#   '난이도',
#   '때',
#   '고생',
#   '걱정',
#   '분',
#   '생각',
#   '제가',
#   '저',
#   '가을',
#   '바',
#   '만족',
#   '강의',
#   '예전',
#   '플젝',
#   '편',
#   '퀴즈',
#   '4',
#   '4개',
#   '개',
#   '완전',
#   '널',
#   '널하다',
#   '하다',
#   '느낌',
#   '안드로메다',
#   '강',
#   '강의지',
#   '의지',
#   '그',
#   '문제',
#   '족보',
#   '50',
#   '사람',
#   '공부',
#   '공부량',
#   '량',
#   '과',
#   '관계',
#   '제가',
#   '중간',
#   '고사',
#   '시험',
#   '전자',
#   '평균',
#   '기말',
#   'ㅂ',
#   'ㅂㄷㅂㄷ',
#   'ㄷ',
#   '성적',
#   '올해',
#   '예상',
#   '그레이드',
#   '소문',
#   '요약',
#   '품',
#   '불평등',
#   '학점',
#   '테러',
#   '내용',
#   '최악',
#   '학점',
#   '로드',
#   '가을',
#   '뭐',
#   '수업',
#   '거',
#   '대부분',
#   '갓',
#   '내기',
#   '학점',
#   '내서',
#   '관철',
#   '제가',
#   '장',
#   '손가락',
#   '성적',
#   '아지',
#   '수업',
#   '과제',
#   '양심',
#   '정도',
#   '시간',
#   '숙제',
#   '숙제점수',
#   '점수',
#   '시험',
#   '편',
#   '생각',
#   '예제',
#   '거기',
#   '추천',
#   '응용',
#   '문제',
#   '때문',
#   '공부',
#   '도움',
#   '한가지',
#   '점',
#   '허',
#   '허교수님',
#   '교수님',
#   '속도',
#   '처음',
#   '사람',
#   '입장',
#   '친절',
#   '질문',
#   '답변',
#   '평상시',
#   '예습',
#   '복습',
#   '수',
#   '저',
#   '예습복습',
#   '책',
#   '산과',
#   '강의',
#   '과목',
#   '방',
#   '통계',
#   '때',
#   '숙제',
#   '랩',
#   '당',
#   '20',
#   '30',
#   '30시간',
#   '시간',
#   '6',
#   '7',
#   '7개',
#   '개',
#   '유익',
#   '앞',
#   '일',
#   '컴퓨터',
#   '관련',
#   '절대',
#   '수업',
#   '수업시간',
#   '시간',
#   '언급',
#   '내용',
#   '예습',
#   '가지',
#   '랩',
#   '수강생',
#   '평균적',
#   '하나',
#   '하나당',
#   '당',
#   '20',
#   '20시간',
#   '시간',
#   '정도',
#   '투자',
#   '시험',
#   '당황',
#   '개인적',
#   '문제',
#   '풀기',
#   '만큼',
#   '학점',
#   '허',
#   '혁',
#   '교수님',
#   '친절',
#   '최고',
#   '1',
#   '로드',
#   '학기',
#   '학기동안',
#   '동안',
#   '과제',
#   '7',
#   '7개',
#   '개',
#   '하나',
#   '다음',
#   '수업',
#   '내용',
#   '바탕',
#   '뒤',
#   '진도',
#   '페이스',
#   '나중',
#   '듀',
#   '야',
#   '관련',
#   '때',
#   '독학',
#   '이해',
#   '난이도',
#   '편',
#   '공부',
#   '나',
#   '시간',
#   '이번',
#   '일정',
#   '촉박',
#   '마지막',
#   '취소',
#   '강의',
#   '일',
#   '조정',
#   '생각',
#   '2',
#   '시험',
#   '시험이번',
#   '기반',
#   '문제',
#   '출제',
#   '이전',
#   '기출',
#   '비중',
#   '물론',
#   '코드',
#   '구현',
#   '방식',
#   '식',
#   '점수',
#   '공지',
#   '치팅',
#   '경우',
#   '0',
#   '0점',
#   '점',
#   '처리',
#   '문구',
#   '사람',
#   '정도',
#   '모양',
#   '정의',
#   '철퇴',
#   '예상',
#   '추측',
#   '제',
#   '성적',
#   '답지',
#   '조금',
#   '조교',
#   '최대한',
#   '채점',
#   '이상',
#   '뭐',
#   '3',
#   '학점',
#   '학점과제',
#   '4',
#   '강',
#   '수',
#   '중',
#   '질문',
#   '답변',
#   '하면',
#   '끝',
#   '덕분',
#   '교수님',
#   '영어',
#   '저',
#   '자습',
#   '해결',
#   '편',
#   '책',
#   '내용',
#   '방대',
#   '이해',
#   '고통',
#   '후반부',
#   '가면',
#   '아무것',
#   '랩',
#   '로드',
#   '진도',
#   '듀',
#   '2',
#   '2주일',
#   '주일',
#   '실질적',
#   '3',
#   '3일인적',
#   '일',
#   '인적',
#   '뭐',
#   '분',
#   '시간',
#   '일주일',
#   '수업',
#   '주위',
#   '말',
#   '제가',
#   '귀',
#   '중간',
#   '중간평균',
#   '평균',
#   '15',
#   '기말',
#   '기말평균',
#   '-10',
#   '비제',
#   '학점',
#   '주시',
#   '건',
#   '보통',
#   '보통보통',
#   '시스템',
#   '프로그래밍',
#   '허',
#   '혁',
#   '교수님',
#   '강의',
#   '때',
#   '수강',
#   '추천',
#   '로드',
#   '운영',
#   '운영체제',
#   '체제',
#   '네트워크',
#   '등등',
#   '시프',
#   '도움',
#   '과목',
#   '1',
#   '학점',
#   '학점학점',
#   '과제',
#   '마지막',
#   '나머지',
#   '80',
#   '95',
#   '중간',
#   '평균',
#   '기말',
#   '씨그마',
#   '2',
#   '수업',
#   '내용',
#   '진도',
#   '저',
#   '이',
#   '분위기',
#   '랩',
#   '예습',
#   '조금',
#   '숙제',
#   '기간',
#   '1주',
#   '주',
#   '때',
#   '이해',
#   '진전',
#   '3',
#   '자신',
#   '무지',
#   '스트레스',
#   '3일',
#   '일',
#   '일주일',
#   '여러번',
#   '치팅',
#   '예전',
#   '프로그램',
#   '체계적',
#   '이번',
#   '강화',
#   '조',
#   '조교',
#   '교',
#   '잘',
#   '애용',
#   '애용합시다',
#   '합',
#   '시다',
#   '곳',
#   '허',
#   '혁',
#   '교수님',
#   '강의',
#   '분',
#   '학생',
#   '모두',
#   '동의',
#   '내용',
#   '성적',
#   '본인',
#   '노력',
#   '여하',
#   '생각',
#   '로드',
#   '널',
#   '하',
#   '프로젝트',
#   '중요',
#   '과목',
#   '수학적',
#   '실무적',
#   '수',
#   '수강',
#   '이후',
#   '보람',
#   '사실',
#   '피',
#   '여러분',
#   '후회',
#   '일',
#   '성적',
#   '상대',
#   '상대평가',
#   '평가',
#   '중간',
#   '기말',
#   '결정',
#   '느낌',
#   '내용',
#   '컴퓨터',
#   '시스템',
#   '전반적',
#   '이진수',
#   '표시',
#   '어셈블리',
#   '나중',
#   '인터넷',
#   '과제',
#   ...],
#  ['무',
#   '나',
#   '판서',
#   '수업',
#   '진행',
#   '숙제',
#   '약간',
#   '부담',
#   '전산',
#   '과제',
#   '시험',
#   '학점',
#   '출석',
#   '출석체크',
#   '체크',
#   '지각',
#   '첵',
#   '날',
#   '가면',
#   '얼굴',
#   '사람',
#   '학점',
#   '절대',
#   '절대평가',
#   '평가',
#   '거',
#   '수업',
#   '수업시간',
#   '시간',
#   '알짜',
#   '내용',
#   '분',
#   '하면서',
#   '강조',
#   '질문',
#   '이해',
#   '때',
#   '설명',
#   '감사',
#   '플젝',
#   '편',
#   '번째',
#   '자비',
#   '수업',
#   '편이',
#   '편이시고',
#   '시고',
#   '숙제',
#   'ㅇ',
#   'ㅇㅇ',
#   '음',
#   '한글',
#   '한글수업',
#   '수업',
#   '숙제',
#   '구',
#   '구글',
#   '글',
#   '검색',
#   '수',
#   '시험',
#   '문제',
#   '기말',
#   '기말고사',
#   '고사',
#   '치',
#   '치팅페이퍼',
#   '팅',
#   '페이퍼',
#   '1',
#   '1장',
#   '장',
#   '허용',
#   '평점',
#   '난해',
#   '데이터',
#   '데이터구조',
#   '구조',
#   '이산',
#   '이산구조',
#   '개',
#   '오트',
#   '교수님',
#   '수업',
#   '지금',
#   '수업중',
#   '중',
#   '오트교수님',
#   '시험',
#   '특성',
#   '문제',
#   '중요',
#   '개념',
#   '이해',
#   '확인',
#   '성적',
#   '다음날',
#   '초',
#   '초스피드',
#   '스피드',
#   '첵',
#   '학생',
#   '특단',
#   '조치',
#   '이상한',
#   '문자열',
#   '인터넷',
#   '번호',
#   '입력',
#   '출석',
#   '출석체크',
#   '체크',
#   '방법',
#   '사용',
#   '학점',
#   '수업',
#   '시험',
#   '시험문제',
#   '문제',
#   '오트',
#   '오트프리드',
#   '프리드',
#   '교수님',
#   '오트',
#   '오트교수님',
#   '교수님',
#   '수업',
#   '필기',
#   '수업내용',
#   '내용',
#   '복기',
#   '수',
#   '학점',
#   '편',
#   '수업',
#   '칠판',
#   '필기',
#   '질문',
#   '학점',
#   '주신',
#   '거로',
#   'ㅋ',
#   '알고리즘',
#   '처음',
#   '사람',
#   '수',
#   '주시',
#   '만족',
#   '수업',
#   '영어',
#   '사용',
#   '때',
#   '이해',
#   '숙제',
#   '나',
#   '전산',
#   '학점',
#   '교수님',
#   '최고',
#   '수업',
#   '기대',
#   '듀',
#   '듀3',
#   '3',
#   '조교',
#   '수업',
#   '로드',
#   '숙제',
#   '10',
#   '10번정도',
#   '번',
#   '정도',
#   '프로그래밍',
#   '2',
#   '2번',
#   '마지막',
#   '제외',
#   '난이도',
#   '시험',
#   '이해',
#   '해결',
#   '수',
#   '문제',
#   '부담',
#   '중간고사',
#   '기말',
#   '25',
#   '에이',
#   '배우기',
#   '혼자',
#   '책',
#   '공부',
#   '공부하심',
#   '하심',
#   '뭐',
#   '우리',
#   '학교',
#   '교수님',
#   '개',
#   '최',
#   '최모',
#   '모',
#   '듯',
#   '듯ㅇㅇ',
#   'ㅇ',
#   '최고',
#   '수업',
#   '교수님',
#   '조지',
#   '조지아텍',
#   '아텍',
#   '학기',
#   '시작',
#   '소',
#   '정신',
#   'ㄷ',
#   'ㄷㄷㄷ',
#   '비고',
#   '교수님',
#   '진',
#   '널',
#   '수업',
#   '수업시간',
#   '시간',
#   '점심시간',
#   '중',
#   '그날',
#   '내용',
#   '수',
#   '정',
#   '정도로',
#   '도로',
#   '과제',
#   '데',
#   '걸리',
#   '프로그래밍',
#   '2',
#   '2개',
#   '개',
#   '하나',
#   '학점',
#   '평',
#   '기대',
#   '평범',
#   '주신',
#   '거',
#   '중간',
#   '기말',
#   '모두',
#   '1',
#   '1시그마',
#   '시그마',
#   '개인적',
#   '수학',
#   '걱정',
#   '생각',
#   '과목',
#   '교수님',
#   '영어',
#   '편',
#   '집중',
#   '수업',
#   '내용',
#   '이해',
#   '중간',
#   '중간중간',
#   '질문',
#   '한국어',
#   '설명',
#   '로드',
#   '4',
#   '4문제',
#   '문제',
#   '정도',
#   '프로그래밍',
#   '숙제',
#   '2',
#   '2개',
#   '개',
#   '하나',
#   '시험',
#   '난이도',
#   '개념',
#   '만',
#   '수준',
#   '학점',
#   '듯',
#   '교수님',
#   '수업',
#   '학점',
#   '편',
#   '데',
#   '모름',
#   '말',
#   '면',
#   '중간',
#   '중간기말',
#   '기말',
#   '비율',
#   '예',
#   '80',
#   '라',
#   '하면',
#   '30',
#   '50',
#   '수',
#   '35',
#   '반영',
#   '절대',
#   '절대평가임',
#   '평가',
#   '임',
#   '기준',
#   '중간기말중',
#   '중',
#   '거',
#   '강의',
#   '교수님',
#   '영어',
#   '전달',
#   '한글',
#   '수업',
#   '게다',
#   '이해',
#   '이해안',
#   '안',
#   '규칙',
#   '개',
#   '개있음',
#   '있음',
#   '출석',
#   '출석체크',
#   '체크',
#   '사진',
#   '이틀',
#   '뒤',
#   '댓',
#   '댓글',
#   '글',
#   '시간',
#   '안달',
#   '안달면',
#   '결석',
#   '처리',
#   '안받음',
#   '딜레이',
#   '패널',
#   '패널티',
#   '티',
#   '100',
#   '내용',
#   '듯',
#   '정렬',
#   '최적화',
#   '문제',
#   '이론',
#   '이론쪽',
#   '쪽',
#   '알고리즘',
#   '보고',
#   '마지막',
#   '개인적',
#   '교과서',
#   '피',
#   '피피티',
#   '숙제',
#   '6',
#   '6개',
#   '2',
#   '2개정도',
#   '정도',
#   '널',
#   '윤',
#   '키',
#   '전통적',
#   '알고리즘',
#   '수',
#   '숙제',
#   '자기',
#   '손',
#   '기억',
#   '2',
#   '2개',
#   '개',
#   '퀴즈',
#   '신경',
#   '학점',
#   '442',
#   '442정도',
#   '정도',
#   '강의',
#   '전달',
#   '강의',
#   '개선',
#   '노력',
#   '사람',
#   '교수님',
#   '말씀',
#   '귀',
#   '이해',
#   '하면',
#   '컨텐츠',
#   '역시나',
#   '점',
#   '수업',
#   '생각',
#   '널',
#   '널널',
#   '편',
#   '개꿀',
#   '조금',
#   '빡',
#   '정도',
#   '이산',
#   '이산구조',
#   '구조',
#   '오라',
#   '약간',
#   '시너지',
#   '기대',
#   '수',
#   '저',
#   '과목',
#   '동시',
#   '거',
#   '성적',
#   '0',
#   '듯',
#   '수업',
#   '책',
#   '슬라이드',
#   '수준',
#   '흥미',
#   '기본적',
#   '알고리즘',
#   '과제',
#   '실습',
#   '수',
#   '저',
#   '시험',
#   '기억',
#   '교수님',
#   '학생',
#   '전체적',
#   '학점',
#   '학점',
#   '보통',
#   '평균',
#   '평균평균',
#   '0',
#   '미디',
#   '미디언미디언',
#   '언',
#   '주변',
#   '이하',
#   '이산',
#   '이산구조',
#   '구조',
#   '조금',
#   '공부',
#   '중간고사',
#   '때',
#   '수업',
#   '수업때',
#   '수도',
#   '수도코드',
#   '코드',
#   '가시길',
#   '거기',
#   '응용',
#   '기말',
#   '치',
#   '치팅페이퍼',
#   '팅',
#   '페이퍼',
#   '교수님',
#   '질문',
#   '당황',
#   '전달',
#   '수업',
#   '개선',
#   '의지',
#   '책',
#   '자체',
#   '알고리즘',
#   '알고리즘계의',
#   '계의',
#   '바이블',
#   '컨텐츠',
#   '수업때',
#   '때',
#   '영어',
#   '영어실력',
#   '실력',
#   '널',
#   '널널',
#   '학점',
#   '이',
#   '분',
#   '교수님',
#   '수업',
#   '노력',
#   '최',
#   '최성희',
#   '성희',
#   '교수님',
#   '여론',
#   '전',
#   '수업',
#   '후기',
#   '압도적',
#   '요',
#   '교수님',
#   '영어',
#   '노력',
#   '말씀',
#   '전달',
#   '수업',
#   '준비',
#   '질적',
#   '우수',
#   '이유',
#   '강의',
#   '폄하',
#   '앞',
#   '개',
#   '분',
#   '소문',
#   '편견',
#   '수',
#   '이산',
#   '이산구조',
#   '구조',
#   '미',
#   '미수강자',
#   '수강자',
#   '수업',
#   '주위',
#   '알고리즘',
#   '친구',
#   '문제',
#   '문제해결기법',
#   '해결',
#   '기법',
#   '202',
#   '강의',
#   'ㅠ',
#   '개가',
#   '널',
#   '강의일지도',
#   '일',
#   '지도',
#   '참고',
#   '수강',
#   '주의',
#   '관련',
#   '분',
#   '리뷰',
#   '정확',
#   '학점',
#   '저',
#   '생각',
#   '상위권',
#   '학생',
#   '불만',
#   '이번',
#   '학기',
#   '명',
#   '말',
#   '수업',
#   '이산',
#   '이산구조',
#   '구조',
#   '정도',
#   '면',
#   '로드',
#   '중간',
#   '이후',
#   '내용',
#   '성적',
#   '정직',
#   '개',
#   '교수님',
#   '강의',
#   '장난',
#   '주의',
#   '수업',
#   '별',
#   '느낌',
#   '프로그래밍',
#   '과제',
#   '면',
#   '별루',
#   '별루임',
#   '임',
#   '교수님',
#   '수업',
#   '중간',
#   '전',
#   '판서',
#   '판서수업',
#   '이후',
#   '태블릿',
#   '필기',
#   '화면',
#   '나중',
#   '식',
#   '변경',
#   '변경하심',
#   '하심',
#   '초반',
#   '말',
#   '정도',
#   '영어',
#   '이해',
#   '편',
#   '글씨체',
#   '적응',
#   '괜찮일주일',
#   '한번',
#   '연습',
#   '연습반',
#   '반',
#   '문제',
#   '구현',
#   '과제',
#   '2',
#   '2인',
#   '인',
#   '1',
#   '1조',
#   '조',
#   '수',
#   '시험',
#   '난이도',
#   '수업때',
#   '때',
#   '거',
#   '응용',
#   '식',
#   '일단',
#   '교수님',
#   '수업',
#   '글씨체',
#   '노트',
#   '부분',
#   '과목',
#   '특성',
#   '글',
#   '글링',
#   '링',
#   '문제',
#   '시험',
#   '중간고사',
#   '편',
#   '체',
#   '체점',
#   '점',
#   '점수',
#   '기말',
#   '기말고사',
#   '고사',
#   '건',
#   '조교',
#   '조교진',
#   '진',
#   '외국인',
#   '교',
#   '교수라',
#   '수라',
#   '눈',
#   '1',
#   '질문',
#   '속도',
#   '자기',
#   '태그',
#   '태그하면서',
#   '하면서',
#   '얘',
#   '2',
#   '2인1조',
#   '인',
#   '조',
#   '팀',
#   '팀과제',
#   '과제',
#   '1명',
#   '명',
#   '드랍해',
#   '혼자',
#   '조치',
#   '안',
#   '3',
#   '내가',
#   '수',
#   '클레임',
#   '가기',
#   '4',
#   '출석',
#   '성적',
#   '확인',
#   '공간',
#   '5',
#   '연습',
#   '연습반',
#   '반',
#   '때',
#   '설명',
#   '교수님',
#   '의외',
#   '강의',
#   '충격적',
#   '필체',
#   '해독',
#   '렉',
#   '렉처노트',
#   '처',
#   '노트',
#   '불성실',
#   '들',
#   '수업',
#   '과제',
#   '은근',
#   '로드',
#   '걸',
#   '요약',
#   '교수님',
#   '악필',
#   '교과서',
#   '전무',
#   '조교',
#   '과한',
#   '부담',
#   '나머지',
#   '학생',
#   '고통',
#   '수업',
#   '학점',
#   '일',
#   '이',
#   '후기',
#   '도움',
#   '듯',
#   '저',
#   '불만',
#   '요',
#   '사정',
#   '좀',
#   '이야기',
#   '1',
#   '수강생',
#   '140',
#   '140명',
#   '명',
#   '4',
#   '4명',
#   '데',
#   '무리',
#   '요구',
#   '시험',
#   '시험주간',
#   '주간',
#   '주',
#   '휴일',
#   '숙제',
#   '총',
#   '12',
#   '12번',
#   '번',
#   '800',
#   '800개',
#   '개',
#   '정도',
#   '게다',
#   '해',
#   '해답지',
#   '답지',
#   '안주',
#   '연습',
#   '연습반',
#   '반',
#   '2',
#   '위',
#   '프로그래밍',
#   '과제',
#   '상의',
#   '전',
#   '독일',
#   '모든',
#   '언어',
#   '사용',
#   '사용가능',
#   '가능',
#   '강의',
#   '강의계획서',
#   '계획서',
#   '바람',
#   '조',
#   '교',
#   '일단',
#   '자바',
#   '파이',
#   '3',
#   '자동',
#   '자동채점',
#   '채점',
#   '버전',
#   '버전차이',
#   '차이',
#   '등',
#   '생겨서',
#   '수동',
#   '이거',
#   '땜',
#   '숙제하나',
#   '하나',
#   '0',
#   '0점처리',
#   '점',
#   '처리',
#   '나중',
#   '중',
#   '전공',
#   '답',
#   '설명',
#   '생각',
#   '특정',
#   '워어어어어낙',
#   '엄격',
#   '채점기준',
#   '기준',
#   '볼펜',
#   '글씨',
#   '가면',
#   '점수',
#   '반토막',
#   '토막',
#   '4분',
#   '분',
#   '난도질',
#   '구',
#   '구글',
#   '글',
#   '학술',
#   '학술검색',
#   '검색',
#   '옛날',
#   '분',
#   '신',
#   '말하기',
#   '영어',
#   '필기체',
#   '문제',
#   '판서',
#   '테블릿',
#   '거',
#   '이것',
#   '맛',
#   '위키피디',
#   '키',
#   '피디',
#   '5',
#   'ㅇ',
#   '주신',
#   '주신거',
#   '무트',
#   '교수님',
#   '오트',
#   '대학원',
#   '시절',
#   '지도',
#   '지도교수님',
#   '쯤',
#   '분',
#   '수업',
#   '짜임새',
#   '강의',
#   '분',
#   '글씨',
#   '독특',
#   '때',
#   '구분',
#   '분반',
#   '개',
#   '학생',
#   '수도',
#   '그',
#   '조교',
#   '수',
#   '의',
#   '부담',
#   '인지',
#   '메일',
#   '답장',
#   '시험',
#   '난이도',
#   '조',
#   '조교',
#   '교',
#   '채점을',
#   '점수',
#   '개인적',
#   '생각',
#   '문제',
#   '자체',
#   '때문',
#   '변별력',
#   '학기',
#   '교수님',
#   '도움',
#   '강의',
#   '설명',
#   '과제',
#   '2',
#   '2인1조',
#   '인',
#   '1',
#   '조',
#   '처음',
#   '생각',
#   '수',
#   '계기',
#   '시험',
#   '시험문제',
#   '문제',
#   '증명',
#   '형식',
#   '이해도',
#   '응용',
#   '테스트',
#   '거',
#   '숙제',
#   '연습',
#   '연습반도',
#   '반도',
#   '노력',
#   '성적',
#   '수학적',
#   '증명',
#   '정렬',
#   '그래프',
#   '문자열',
#   '알고리즘',
#   '등',
#   '분석',
#   '무트',
#   '알트',
#   '교수님',
#   '강의',
#   '스타일',
#   '필기',
#   '위주',
#   '예시',
#   '식',
#   '수업',
#   '때',
#   '짓',
#   '안',
#   '수업내용',
#   '내용',
#   '체화',
#   '작년',
#   '최',
#   '최성희교수님',
#   '성희',
#   '개',
#   '올해',
#   '저',
#   '생각',
#   '이상',
#   '사람',
#   '강의',
#   '평가',
#   '저',
#   '생각',
#   '영어',
#   '구사력',
#   '전달',
#   '전달능력',
#   '능력',
#   '조금',
#   '부족',
#   '수업',
#   '내용',
#   '수업시간',
#   '시간',
#   '과제',
#   '시험',
#   '때',
#   '로드',
#   '매',
#   '퀴즈',
#   '문제',
#   '6',
#   '6번',
#   '번',
#   '2',
#   '2개',
#   '개',
#   '첵',
#   ...],
#  ['전산',
#   '고민',
#   '기선',
#   '사람',
#   '과목',
#   '과제',
#   '랩',
#   '랩시간',
#   '시간',
#   '수업',
#   '이용',
#   '교수님',
#   '친절',
#   '여',
#   '여학우',
#   '학우',
#   '여학우분',
#   '분',
#   '강추',
#   '나중',
#   '오트',
#   '오트교수님',
#   '집',
#   '티타임',
#   '초대',
#   '수',
#   '남자',
#   '남자학우',
#   '겐',
#   '국물',
#   '중간기',
#   '중간기말',
#   '말',
#   '정도',
#   '페이지',
#   '시험',
#   '학점',
#   '로드',
#   '랩',
#   '시간',
#   '길',
#   '과제',
#   '로드',
#   '널',
#   '널하다',
#   '하다',
#   '시험',
#   '퀴즈',
#   '퀴즈형식',
#   '형식',
#   '프로그래밍',
#   '기초',
#   '지장',
#   '하면',
#   '언어',
#   '수',
#   '적응',
#   '교수님',
#   '수업',
#   '간결',
#   '가독성',
#   '세련',
#   '코딩',
#   '도움',
#   '생각',
#   '전산',
#   '거',
#   '유일',
#   '기선',
#   '라',
#   '언어',
#   '101',
#   '101의',
#   '의',
#   '느낌',
#   '과제',
#   '랩',
#   '랩시간',
#   '시간',
#   '학점',
#   '편',
#   '교수님',
#   '수업',
#   '2013',
#   '2013년',
#   '년',
#   '사정',
#   '과목',
#   '전산',
#   '진학',
#   '관심',
#   '복',
#   '부',
#   '부전공',
#   '전공',
#   '분',
#   '정리',
#   '교수님',
#   '서도',
#   '앞',
#   '수업',
#   '이해',
#   '설명',
#   '학점',
#   '저',
#   '경우',
#   '데이터',
#   '구조',
#   '수강',
#   '내용',
#   '정도',
#   '담당',
#   '담당교수',
#   '교수',
#   '정',
#   '정지원',
#   '지원',
#   '교수님',
#   '오프',
#   '오프리드',
#   '리드',
#   '프로그래밍',
#   '기초',
#   '때',
#   '랩',
#   '떼',
#   '느낌',
#   '문제',
#   '과목',
#   '과목명',
#   '명',
#   '실습',
#   '이론',
#   '부분',
#   '수업',
#   '내용',
#   '나중',
#   '시험지',
#   '후회',
#   '참고',
#   '여기',
#   '모',
#   '경우',
#   '프',
#   '프실',
#   '실',
#   '사람',
#   '필요',
#   '정도',
#   '류',
#   '류석영교수님',
#   '석영',
#   '교수님',
#   '한',
#   '시대',
#   '최고',
#   '과목',
#   '꺼',
#   '번',
#   '출석',
#   '태',
#   '태도로',
#   '도로',
#   '성적',
#   '결정',
#   '시험',
#   '조',
#   '조교',
#   '교',
#   '친절하게',
#   '수',
#   '코딩',
#   '코딩입문',
#   '입문',
#   '거',
#   '추천',
#   '정',
#   '정지원',
#   '지원',
#   '교수님',
#   '성함',
#   '반전',
#   '강의',
#   '친절',
#   '라',
#   '언어',
#   '처음',
#   '수업',
#   '만',
#   '원래',
#   '과목',
#   '정',
#   '정지원',
#   '지원',
#   '교수님',
#   '이번',
#   '학기',
#   '류',
#   '류석영',
#   '석영',
#   '담당',
#   '학점',
#   '중간',
#   '기말',
#   '퀴즈',
#   '예년',
#   '100',
#   '출석',
#   '태도',
#   '점수',
#   '전출',
#   '1',
#   '1번',
#   '번',
#   '결석',
#   '정도',
#   '수업',
#   '라',
#   '언어',
#   '사용',
#   '4',
#   '4시간',
#   '시간',
#   '중',
#   '1시간',
#   '각종',
#   '자료',
#   '등',
#   '개념적',
#   '다음',
#   '3',
#   '3시간',
#   '코딩',
#   '응용',
#   '날',
#   '당일',
#   '과제',
#   '뒤',
#   '자율',
#   '금요일',
#   '오후',
#   '강의',
#   '시간',
#   '동안',
#   '끝내기',
#   '때',
#   '매',
#   '주',
#   '하면서',
#   '실력',
#   '수',
#   '생각',
#   '한',
#   '시험',
#   '기간',
#   '공부',
#   '게임',
#   '이번',
#   '교수님',
#   '대신',
#   '류',
#   '류석영',
#   '석영',
#   '수업',
#   '처음',
#   '강의',
#   '수',
#   '중간',
#   '중간중간',
#   '한국말',
#   '이해',
#   '부분',
#   '설명',
#   '질문',
#   '독특',
#   '점',
#   '별도',
#   '과제',
#   '시험',
#   '레포트',
#   '수업시간',
#   '시간',
#   '집중',
#   '출석',
#   '라',
#   '새',
#   '언어',
#   '사용',
#   '조교',
#   '도',
#   '애초',
#   '대상',
#   '프밍기',
#   '사람',
#   '거',
#   '기초적',
#   '내용',
#   '기본적',
#   '언어구조',
#   '구조',
#   '로드',
#   '과목',
#   '추천',
#   '교수',
#   '대신',
#   '이번',
#   '류',
#   '류석영교수님',
#   '석영',
#   '교수님',
#   '강의',
#   '영어',
#   '한번',
#   '한국어',
#   '귀',
#   '학생',
#   '적극적',
#   '수업',
#   '수업태도',
#   '태도',
#   '라',
#   '언어',
#   '프로젝트',
#   '말',
#   '조금',
#   '예제',
#   '도',
#   '코딩',
#   '요령',
#   '다양',
#   '다방',
#   '다방면적',
#   '면적',
#   '사고',
#   '수',
#   '시험',
#   '출석',
#   '과제',
#   '과제제출',
#   '제출',
#   '평가',
#   '평',
#   '평타로',
#   '타로',
#   '내도',
#   '만큼',
#   '중요',
#   '생각',
#   '꿀',
#   '꿀과목',
#   '과목',
#   '101',
#   '이',
#   '고민',
#   '수강',
#   '1',
#   '수업',
#   '내용',
#   '확장',
#   '확장판',
#   '판',
#   '새',
#   '언어',
#   '처음',
#   '코딩',
#   '경험',
#   '바탕',
#   '심화',
#   '과제',
#   '느낌',
#   '2',
#   '교수님',
#   '강의',
#   '영어',
#   '설명',
#   '한국어',
#   '번',
#   '질문',
#   '적극적',
#   '학생',
#   '명',
#   '한',
#   '명의',
#   '이름',
#   '노력',
#   '모습',
#   '명',
#   '명강의',
#   '3',
#   '로드',
#   '금요일',
#   '4',
#   '4시간',
#   '시간',
#   '시간대',
#   '유일',
#   '흠',
#   '시간',
#   '코딩하다',
#   '하다',
#   '부분',
#   '조교',
#   '도',
#   '수업시간',
#   '외',
#   '시험',
#   '퀴즈',
#   '출석',
#   '일주일',
#   '태도',
#   '학점',
#   '반영',
#   '요소',
#   '널',
#   '이번',
#   '기회',
#   '집중',
#   '이것저것',
#   '추천',
#   '오트',
#   '교수님',
#   '프밍',
#   '프밍실습',
#   '실습',
#   '라',
#   '자바',
#   '짝',
#   '언어',
#   '진행',
#   '로드',
#   '느낌',
#   '교수님',
#   '4',
#   '4시간',
#   '시간',
#   '수업',
#   '1',
#   '1시간정도',
#   '시간',
#   '정도',
#   '3',
#   '3시간',
#   '실습',
#   '진행',
#   '프로젝트',
#   '과제',
#   '저',
#   '오트',
#   '수업',
#   '1',
#   '성적',
#   '전',
#   '전산',
#   '타과',
#   '이지만',
#   '수업',
#   '시간',
#   '성실',
#   '사랑',
#   '교수님',
#   '중간',
#   '중간고사',
#   '고사',
#   '기말',
#   '기말고사',
#   '번',
#   '점수',
#   '중요',
#   '평소',
#   '과제',
#   '제출',
#   '코드',
#   '여부',
#   '관계',
#   '난이도',
#   '하면',
#   '그것',
#   '서버',
#   '만',
#   '만점',
#   '점',
#   '확인',
#   '마지막',
#   '컴파일',
#   '채',
#   '사람',
#   '적발',
#   '감점',
#   '질',
#   '평가',
#   '경우',
#   '이',
#   '언급',
#   '조건',
#   '가지',
#   '만족',
#   '만점',
#   '2',
#   '널',
#   '널널',
#   '금요일',
#   '13',
#   '13시-17시',
#   '시',
#   '-17',
#   '강의',
#   '13시-14시',
#   '-14',
#   '랩',
#   '14',
#   '14시-17시',
#   '날',
#   '16',
#   '16시',
#   '30',
#   '30분',
#   '분',
#   '수',
#   '방식',
#   '골격',
#   '숙제',
#   '반대',
#   '때문',
#   '도망',
#   '3',
#   '3시간',
#   '안',
#   '못',
#   '내용',
#   '학기',
#   '중',
#   '로드',
#   '0',
#   '짓',
#   '셀',
#   '셀프로',
#   '프로',
#   '창출',
#   '건',
#   '효율',
#   '방법',
#   '알',
#   '흥미',
#   '분',
#   '수강',
#   '프로그래밍',
#   '기초',
#   '타과생',
#   '생',
#   '역대',
#   '과목',
#   '중',
#   '재미',
#   '분반',
#   '영어',
#   '강의인지',
#   '인지',
#   '조교',
#   '지도',
#   '가능',
#   '뿐',
#   '자체',
#   '정',
#   '정지원',
#   '지원',
#   '천',
#   '천사십',
#   '사십',
#   '자료',
#   '중간중간',
#   '깨알',
#   '드립',
#   '컨텐츠',
#   '지에',
#   '아래',
#   '109',
#   '결론',
#   '후회',
#   '처음',
#   '교수님',
#   '성함',
#   '한국인',
#   '줄',
#   '외국인',
#   '분',
#   '분반',
#   '반',
#   '영어',
#   '영어수업',
#   '수업',
#   '표시',
#   '진행',
#   '후',
#   '실습',
#   '때',
#   '조교',
#   '가능',
#   '때문',
#   '저것',
#   '학생',
#   '수강',
#   '수강신청',
#   '신청',
#   '경쟁률',
#   '1',
#   '진행도',
#   '내용',
#   '기초적',
#   '전산',
#   '전공',
#   '프로그래밍',
#   '언어',
#   '이',
#   '사용',
#   '사람',
#   '이것',
#   '설치',
#   '데',
#   '실험',
#   '번',
#   '강추',
#   '4',
#   '4시간',
#   '시간',
#   '중',
#   '1시간',
#   '남',
#   '3',
#   '3시간동안',
#   '시간',
#   '동안',
#   '랩',
#   '프밍',
#   '프밍기',
#   '기',
#   '과제',
#   '수업시간',
#   '계속',
#   '느낌',
#   '주제가',
#   '외',
#   '투자',
#   '학점',
#   '듯',
#   '성적',
#   '첵',
#   '퀴즈',
#   '기말',
#   '기말고사',
#   '고사',
#   '중간',
#   '중간고사',
#   '안',
#   '만큼',
#   '중요',
#   '시작',
#   '지각',
#   '봄',
#   '봄학기',
#   '학기',
#   '밖',
#   '금요일',
#   '단점',
#   '흥미',
#   '수',
#   '생각',
#   '힐링',
#   '힐링과목',
#   '과목',
#   '실습',
#   '과목',
#   '주가',
#   '수업',
#   '저희',
#   '수업때',
#   '때',
#   '이론적',
#   '거',
#   '학',
#   '교수님',
#   '커맨드',
#   '창',
#   '코드',
#   '적용',
#   '내용',
#   '학기',
#   '프로그래밍',
#   '실력',
#   '초',
#   '생각',
#   '학생',
#   '추천',
#   '필요',
#   '로드',
#   '기초',
#   '업',
#   '업로드',
#   '기말',
#   '기말고사',
#   '고사',
#   '확인',
#   '성적',
#   '위주',
#   '과제',
#   '흥미',
#   '대부분',
#   '전산',
#   '진입',
#   '코딩',
#   '타과',
#   '타과생',
#   '생',
#   '1',
#   '랩',
#   '내용',
#   '흥미로웠어',
#   '프밍',
#   '프밍기',
#   '기',
#   '때',
#   '코딩',
#   '아가',
#   '느낌',
#   '수업',
#   '재미',
#   '기본',
#   '기본적인',
#   '적인',
#   '틀',
#   '2',
#   '2학년',
#   '학년',
#   '상대',
#   '부분',
#   '코드',
#   '대부분',
#   '경우',
#   '스크립트',
#   '실행',
#   '확인',
#   '나도',
#   '전문',
#   '프로그래머',
#   '발짝',
#   '기분',
#   '처음',
#   '적응',
#   '시간',
#   '1시간',
#   '시간',
#   '내외',
#   '3',
#   '3시간',
#   '진행',
#   '교수님',
#   '튜',
#   '리얼',
#   '성적',
#   '수',
#   '퀴즈',
#   '자료',
#   '때문',
#   '두시',
#   '걸',
#   '추천',
#   '추천드리고',
#   '드리고',
#   '중간',
#   '기말',
#   '별',
#   '별탈',
#   '탈',
#   '거',
#   '전',
#   '작년',
#   '시험',
#   '데',
#   '기출',
#   '공부',
#   '세요',
#   '저희',
#   '문제',
#   '변별력',
#   '유형',
#   '출제',
#   '점수',
#   '343',
#   '여유',
#   '제출',
#   '만점',
#   '하루',
#   '전날',
#   '결론',
#   '관심',
#   '번',
#   '보세',
#   '좋으',
#   '좋으심',
#   '심'],
#  ['교수님',
#   '말투',
#   '친절',
#   '조',
#   '조교분',
#   '교분',
#   '불친절',
#   '수업',
#   '반부',
#   '느낌',
#   '중간',
#   '중간고사',
#   '고사',
#   '하면',
#   '등수',
#   '파',
#   '바',
#   '파바',
#   '바박',
#   '박',
#   '학점',
#   '파바바박',
#   '전산',
#   '처음',
#   '기억',
#   '교수님',
#   '수업',
#   '음',
#   '외국',
#   '대학',
#   '기분',
#   '배우',
#   '배우시',
#   '시',
#   '분',
#   '추천',
#   '수업분위기',
#   '분위기',
#   '언어',
#   '레',
#   '레퍼런스같',
#   '퍼런',
#   '스같',
#   '문제',
#   '분',
#   '널',
#   '과목',
#   '플젝',
#   '사랑',
#   '나',
#   '사실',
#   '사용',
#   '언어',
#   '숙제',
#   '숙제량',
#   '량',
#   '과목',
#   '기',
#   '기혁',
#   '혁',
#   '교수님',
#   '매',
#   '매주',
#   '주',
#   '시험',
#   '책',
#   '수',
#   '문제',
#   '전',
#   '전산과',
#   '산과',
#   '생각',
#   '추천',
#   '추천과목',
#   '중',
#   '하나',
#   '교수님',
#   '영어',
#   '혼자',
#   '책',
#   '공부',
#   '로드',
#   '과제',
#   '스켈레톤',
#   '뒤',
#   '연습',
#   '연습문제',
#   '문제',
#   '학점',
#   '기억',
#   '도움',
#   '언어',
#   '수업',
#   '숙제',
#   '2',
#   '2주',
#   '주',
#   '정도',
#   '한번',
#   '거',
#   '책',
#   '내용',
#   '시험',
#   '경우',
#   '풀',
#   '학점',
#   '듯',
#   '평',
#   '나',
#   '교수님',
#   '수업',
#   '내용',
#   '전산',
#   '기본',
#   '기본이자',
#   '이자',
#   '중요',
#   '학점',
#   '거',
#   '교수님',
#   '학생',
#   '친절',
#   '종강',
#   '종강때',
#   '때',
#   '이랑',
#   '단체',
#   '사진',
#   '프로젝트',
#   '편의',
#   '교수님',
#   '이번',
#   '이번학기',
#   '학기',
#   '학점',
#   '칼',
#   '교수님',
#   '거',
#   '한데',
#   '강',
#   '강성원',
#   '성원',
#   '오피셜',
#   '랭',
#   '랭기지',
#   '기지',
#   '자기',
#   '언어',
#   '공부',
#   '수업',
#   '데이터',
#   '구조',
#   '알고리즘',
#   '개념',
#   '개념위주',
#   '위주',
#   '설명',
#   '이제',
#   '나머지',
#   '구현',
#   '숙제',
#   '분',
#   '분반',
#   '반',
#   '하루',
#   '하루안',
#   '안',
#   '중간',
#   '공부',
#   '기말',
#   '과제',
#   '뒤',
#   '숙제',
#   '처음',
#   '저',
#   '난이도',
#   '학점',
#   '만점',
#   '교수님',
#   '거',
#   '타',
#   '타학과',
#   '학과',
#   '학생',
#   '학생분',
#   '분',
#   '추천',
#   '거',
#   '타과',
#   '학생',
#   '추천',
#   '전산',
#   '과목',
#   '과목무조건',
#   '무',
#   '조건',
#   '자바',
#   '프로그래밍',
#   '공부',
#   '목',
#   '내용',
#   '예습',
#   '수업',
#   '학점',
#   '칼',
#   '듯',
#   '듯뒤',
#   '뒤',
#   '프로젝트',
#   '기억',
#   '수업',
#   '내용',
#   '데이터',
#   '데이터구조',
#   '구조',
#   '프로젝트',
#   '2',
#   '2번',
#   '번',
#   '숙제',
#   '6',
#   '6번',
#   '이중',
#   '코딩',
#   '4',
#   '4번',
#   '이',
#   '구현',
#   '거',
#   '거여',
#   '여',
#   '평범',
#   '플젝',
#   '플젝주제',
#   '주제',
#   '흥미',
#   '웠',
#   '플젝들이었어',
#   '학점',
#   '은',
#   '아무',
#   '40',
#   '이상',
#   '과목',
#   '자체',
#   '시험',
#   '당황',
#   '기억',
#   '강의',
#   '내용',
#   '커버',
#   '이',
#   '아무',
#   '충격적',
#   '참고',
#   '이윤',
#   '교수님',
#   '경우',
#   '교재',
#   '숙제',
#   '라',
#   '언어',
#   '강의',
#   '코딩',
#   '컴파일',
#   '소스',
#   '불편',
#   '적응',
#   '데',
#   '시간',
#   '그것',
#   '별개',
#   '매',
#   '하나',
#   '내용',
#   '반복',
#   '느낌',
#   '이해',
#   '도움',
#   '수업',
#   '분위기',
#   '자체',
#   '정리',
#   '9',
#   '9번',
#   '번',
#   '숙제',
#   '교수님',
#   '직전',
#   '주시',
#   '기출',
#   '기출문제',
#   '문제',
#   '오',
#   '오혜연',
#   '혜',
#   '연',
#   '교수님',
#   '사랑',
#   '내용',
#   '수',
#   '과제',
#   '기본적',
#   '개념',
#   '시험',
#   '시험문제',
#   '문제',
#   '단순',
#   '암기',
#   '세세',
#   '디테일',
#   '나열',
#   '데이터',
#   '구조',
#   '설명',
#   '데이터구조',
#   '경우',
#   '등등',
#   '고찰',
#   '유도',
#   '출제',
#   '강의',
#   '대박',
#   '이해',
#   '경쟁률',
#   '전산',
#   '전산꿈나무시',
#   '꿈나무',
#   '시',
#   '추천',
#   '과제',
#   '9',
#   '9개',
#   '개',
#   '내용',
#   '교수님',
#   '언어',
#   '스칼라',
#   '학점',
#   '저',
#   '오',
#   '오혜연',
#   '혜',
#   '연',
#   '교수님',
#   '데이타',
#   '데이타구조',
#   '구조',
#   '수업',
#   '과목',
#   '과목사전',
#   '사전',
#   '거',
#   '항목',
#   '지금',
#   '수업중',
#   '중',
#   '과제',
#   '후반부',
#   '때',
#   '친절',
#   '내용',
#   '특이',
#   '점',
#   '파이',
#   '이',
#   '자바',
#   '본적',
#   '학생',
#   '번',
#   '길',
#   '추천',
#   '제가',
#   '케이스',
#   '정',
#   '정지원',
#   '지원',
#   '교수님',
#   '분',
#   '분반',
#   '반',
#   '운영',
#   '중',
#   '비',
#   '전공자',
#   '파이',
#   '을',
#   '사용',
#   '활용',
#   '수',
#   '데이터',
#   '구조',
#   '집중',
#   '공부',
#   '로드',
#   '하나',
#   '시험',
#   '건',
#   '달',
#   '평균',
#   '부분',
#   '부분점수',
#   '점수',
#   '수도',
#   '있음',
#   '학점',
#   '교수님',
#   '수업',
#   '질문',
#   '친절',
#   '대답',
#   '라',
#   '사이트',
#   '이용',
#   '과제',
#   '제출',
#   '문제',
#   '해결',
#   '코딩',
#   '반부',
#   '후반부',
#   '기업',
#   '입사',
#   '입사문제',
#   '포함',
#   '학점',
#   '자신',
#   '지론',
#   '총점',
#   '평균',
#   '내용',
#   '교수님',
#   '수업',
#   '수업스타일',
#   '스타일',
#   '때문',
#   '수업시간',
#   '시간',
#   '수',
#   '언어',
#   '자유',
#   '자유선정',
#   '선정',
#   '장점',
#   '장점일수',
#   '일수',
#   '단점',
#   '단점일수',
#   '숙제',
#   '1',
#   '2',
#   '2주',
#   '주',
#   '간격',
#   '필기',
#   '필기숙제',
#   '팀',
#   '프로젝트',
#   '2개',
#   '개',
#   '혼자',
#   '수준',
#   '한데',
#   '암',
#   '유발',
#   '팀플젝',
#   '플젝',
#   '겠다',
#   '생각',
#   '학점',
#   '한명',
#   '대체적',
#   '주신',
#   '주신거',
#   '거',
#   '데이터',
#   '데이터구조',
#   '구조',
#   '수',
#   '과목',
#   '강의',
#   '과제',
#   '오류',
#   '시작',
#   '오류밭',
#   '밭',
#   '전산',
#   '기초',
#   '기초과목',
#   '과목',
#   '윤',
#   '교수님',
#   '수업',
#   '학생',
#   '기본적',
#   '필요',
#   '내용',
#   '자바',
#   '사용',
#   '과제',
#   '개',
#   '시험',
#   '기억',
#   '완수',
#   '학점',
#   '절대',
#   '절대평가',
#   '평가',
#   '출석',
#   '퀴즈',
#   '점수',
#   '과제',
#   '예외',
#   '예외처리',
#   '처리',
#   '만점',
#   '점',
#   '수',
#   '제출',
#   '여러번',
#   '가능',
#   '시간',
#   '투자',
#   '투자하면',
#   '하면',
#   '득점',
#   '정도',
#   '중간',
#   '기말',
#   '전산',
#   '전공',
#   '전공필수',
#   '필수',
#   '데이타',
#   '데이타구조',
#   '구조',
#   '진입',
#   '여러분',
#   '처음',
#   '과목',
#   '언어',
#   '라',
#   '플랫폼',
#   '수업',
#   '퀴즈',
#   '10',
#   '10번',
#   '번',
#   '과제',
#   '6',
#   '6번',
#   '0',
#   '포함',
#   '니플',
#   '니플젝',
#   '젝',
#   '번',
#   '중간',
#   '기말',
#   '난이도',
#   '편',
#   '하나',
#   '5',
#   '5문제',
#   '문제',
#   '정도',
#   '데',
#   '시간',
#   '영어',
#   '영어수업',
#   '무리',
#   '교수님',
#   '친절',
#   '강의',
#   '시험',
#   '나',
#   '추천',
#   '코딩',
#   '애',
#   '중',
#   '친구',
#   '과목',
#   '저',
#   '경우',
#   '도움',
#   '과제',
#   '시험',
#   '평',
#   '흠',
#   '교수님',
#   '강의',
#   '조금',
#   '루즈',
#   '편',
#   '공부',
#   '떄',
#   '숙제',
#   '마지막',
#   '마지막수업',
#   '수업',
#   '거',
#   '위주',
#   '학점',
#   '예상',
#   '타과',
#   '타과생도',
#   '생도',
#   '수',
#   '전산',
#   '과목',
#   '말',
#   '코딩',
#   '1',
#   '고생',
#   '사실',
#   '조',
#   '조교',
#   '교',
#   '과제',
#   '난이도',
#   '수업',
#   '수업시간',
#   '시간',
#   '괴리',
#   '경우',
#   '비전',
#   '비전공자',
#   '공자',
#   '2',
#   '2주',
#   '주',
#   '새',
#   '주',
#   '투자',
#   '그것',
#   '개',
#   '완벽',
#   '제출',
#   '마무리',
#   '때',
#   '자괴감',
#   '표현',
#   '프',
#   '프데스크',
#   '데스크',
#   '조교',
#   '질문',
#   '학기',
#   '중간',
#   '답변',
#   '헬프데스크',
#   '자리',
#   '장소',
#   '임의',
#   '변경',
#   '후',
#   '시간전',
#   '전',
#   '공지',
#   '헛걸음',
#   '무성의',
#   '등',
#   '하면',
#   '교수님',
#   '선',
#   '수업진행',
#   '진행',
#   '기말',
#   '기말고사',
#   '고사',
#   '타과생',
#   '생',
#   '배려',
#   '내용',
#   '내용중',
#   '중',
#   '개념',
#   '대부분',
#   '작성',
#   '데이터',
#   '구조',
#   '때문',
#   '여기',
#   '전공자',
#   '전공',
#   '전공자간',
#   '자간',
#   '격차',
#   '듯',
#   '무엇',
#   '학점',
#   '그동안',
#   '제가',
#   '생각',
#   '그',
#   '타과생이',
#   '생이',
#   '경험',
#   '진짜',
#   '완전',
#   '소질',
#   '분',
#   '보시',
#   '보시길',
#   '길',
#   '강의',
#   '조금',
#   '루즈',
#   '편',
#   '재미',
#   '대신',
#   '학점',
#   '이번',
#   '주신',
#   '주신거',
#   '거',
#   '과제',
#   '이번학기',
#   '학기',
#   '총',
#   '10',
#   '10개',
#   '개',
#   '프로젝트',
#   '별도',
#   '난이도',
#   '조교',
#   '도',
#   '전산',
#   '관심',
#   '분',
#   '추천',
#   '초반',
#   '거의',
#   '자바',
#   '기초',
#   '문법',
#   '사람',
#   '수',
#   '시험',
#   '출제',
#   '오',
#   '오혜연',
#   '혜',
#   '연',
#   '교수님',
#   '비교',
#   '때',
#   '성향',
#   '데이타',
#   '구조',
#   '응용',
#   '자체',
#   '구현',
#   '공부',
#   '개인적',
#   '마음',
#   '수업',
#   '자료',
#   '공부',
#   '수',
#   '꿀',
#   '과제',
#   '편',
#   '널',
#   '프로그래밍',
#   '4',
#   '4번',
#   '번',
#   '전부',
#   '추천',
#   '성적',
#   '과제',
#   '4',
#   '4번',
#   '번',
#   '모두',
#   '코딩',
#   '수업',
#   '수업내용',
#   '내용',
#   '바탕',
#   '디테일',
#   '완수',
#   '수',
#   '시간',
#   '투자',
#   '강의',
#   '영어',
#   '설명',
#   '미숙',
#   '문제',
#   '숙제',
#   '학기',
#   '개',
#   '시험',
#   '손',
#   '손코딩',
#   '코딩',
#   '포함',
#   '필기',
#   '1',
#   '학점',
#   '만큼',
#   '2',
#   '시험',
#   '문제',
#   '수도',
#   '3',
#   '4',
#   '4문제',
#   '정도',
#   '수업',
#   '시간',
#   '내용',
#   '만',
#   '수',
#   '마지막',
#   '생각',
#   '이전',
#   '과제',
#   '과제과제',
#   '4번',
#   '번',
#   '프로그래밍',
#   '수업시간',
#   '데이터',
#   '구조',
#   '구현',
#   '3번',
#   '테스트',
#   '케이스',
#   '성질',
#   '확인',
#   '제출',
#   '시',
#   '만점',
#   '실제',
#   '수업수업',
#   '영어',
#   '강의',
#   '렉',
#   '노트',
#   '구성',
#   '공부',
#   '5',
#   '연습',
#   '연습반오피스아워',
#   '반오피스아워',
#   '데',
#   '가본적',
#   '6',
#   '총평',
#   '기',
#   '기응',
#   '응',
#   '교수님',
#   '차',
#   '차냥',
#   '냥',
#   '교수님',
#   '강의',
#   '최고',
#   '수준',
#   '수',
#   '영어',
#   '설명',
#   '질문',
#   '로드',
#   '다',
#   '걱정',
#   '김',
#   '응',
#   '숙제',
#   '5',
#   '5번정도',
#   '번',
#   '정도',
#   '2',
#   '2개',
#   '개',
#   '나머지',
#   '성적',
#   '듯',
#   '오',
#   '오혜연',
#   '혜',
#   '연',
#   '교수님',
#   '사랑',
#   '1',
#   '강의',
#   '만족',
#   '초반',
#   '코딩',
#   '시연',
#   '버벅이시',
#   '모습',
#   '불안',
#   '감',
#   '2',
#   '퀴즈',
#   '날',
#   '첵',
#   '결과적',
#   '3',
#   '총',
#   '7',
#   '7번',
#   '번',
#   '과제',
#   '각각',
#   '꼬리',
#   '문제',
#   '4',
#   '4개',
#   '개',
#   '듀',
#   '중간',
#   '직전',
#   '기말',
#   '번',
#   '3개',
#   '벼락',
#   '기가',
#   '가능',
#   '덕',
#   '널',
#   '내용',
#   '유익',
#   '유익하다',
#   '하다',
#   '느낌',
#   '시험',
#   '난이도',
#   '편',
#   '특정',
#   '주제',
#   '편중',
#   '점',
#   '5',
#   '학점',
#   '최대한',
#   '노력',
#   '책정',
#   '기준',
#   '복잡',
#   '공지',
#   '하향',
#   '학생',
#   '성적',
#   '그레이드',
#   '경계',
#   '윗',
#   '구제',
#   '최고',
#   '생각',
#   '성적',
#   '제가',
#   '예상',
#   '납득',
#   '수',
#   '정',
#   '정도로',
#   '도로',
#   '수업',
#   '내용',
#   '분',
#   '분반',
#   '반',
#   '유사',
#   '데이터',
#   '데이터구조',
#   '구조',
#   '등',
#   '포함',
#   '수준',
#   '교수님',
#   '설명',
#   '설명기법',
#   '기법',
#   '과제',
#   '때',
#   '언어',
#   '클라우드',
#   '플랫폼',
#   '코드',
#   '작성',
#   '제출',
#   '형식',
#   '때문',
#   '컴퓨터',
#   '학기',
#   '4',
#   '4번',
#   '번',
#   '마지막',
#   '나머지',
#   '셋',
#   '중간고사',
#   ...],
#  ['수업',
#   '수업시간',
#   '시간',
#   '완전',
#   '틱틱',
#   '틱틱대시',
#   '대시',
#   '모습',
#   '친절',
#   '시험',
#   '거',
#   '학점',
#   '숙제',
#   '맥시멈',
#   '2',
#   '2시간정도면',
#   '정',
#   '도면',
#   '수업',
#   '수업시간',
#   '시간',
#   '교수님',
#   '학생',
#   '수업참여',
#   '참여',
#   '그날',
#   '질문',
#   '발표',
#   '사람',
#   '이름',
#   '적도',
#   '집중',
#   '거',
#   '졸고',
#   '커피',
#   '주세',
#   '그',
#   '다음',
#   '다음시간',
#   '식',
#   '내용',
#   '내용자체',
#   '자체',
#   '고등',
#   '고등학교',
#   '학교',
#   '수학',
#   '조금',
#   '연장선',
#   '숙제',
#   '교수님',
#   '이해',
#   '부분',
#   '반복',
#   '설명',
#   '크리스탈',
#   '클리어',
#   '숙제',
#   '문제',
#   '저',
#   '구',
#   '구글링',
#   '글',
#   '링',
#   '개',
#   '수업',
#   '내용',
#   '시험',
#   '수',
#   '널',
#   '숙제',
#   '시간',
#   '투자',
#   '시험',
#   '문제',
#   '유사',
#   '숫자',
#   '식',
#   '트리플',
#   '크리스탈',
#   '클리어',
#   '내용',
#   '시험',
#   '평점',
#   '주세',
#   '4',
#   '2',
#   '1',
#   '1학년',
#   '학년',
#   '가을',
#   '가을때',
#   '때',
#   '전산',
#   '맛보기',
#   '생각',
#   '전선',
#   '과목',
#   '산',
#   '산구조',
#   '구조',
#   '이산',
#   '이산수학',
#   '수학',
#   '내용',
#   '거',
#   '교수님',
#   '족보',
#   '한글',
#   '한글수업',
#   '수업',
#   '시험',
#   '시험문제',
#   '문제',
#   '만점',
#   '학점',
#   '수도',
#   '숙제',
#   '편이',
#   '정도',
#   '트리플',
#   '크리스탈',
#   '클리어',
#   '전산',
#   '이산',
#   '이산구조',
#   '구조',
#   '대신',
#   '수업',
#   '집중도',
#   '이해',
#   '복습',
#   '철',
#   '저희',
#   '안',
#   '안하면',
#   '하면',
#   '시험',
#   '망해',
#   '타과',
#   '타과생',
#   '생',
#   '점',
#   '학점',
#   '인상',
#   '천사',
#   '박진',
#   '교수님',
#   '친절',
#   '전산',
#   '전산학과',
#   '학과',
#   '과목',
#   '처음',
#   '절대',
#   '절대평가',
#   '평가',
#   '주신',
#   '주신거',
#   '거',
#   '숙제',
#   '2',
#   '2주',
#   '주',
#   '한번',
#   '가량',
#   '가량정도',
#   '정도',
#   '중간',
#   '프로그래밍',
#   '언어',
#   '이산',
#   '이산구조',
#   '구조',
#   '수업',
#   '교수님',
#   '천사',
#   '숙제',
#   '프로그래밍',
#   '프로그래밍숙제',
#   '시간',
#   '수업',
#   '이산',
#   '이산구조',
#   '구조',
#   '박진',
#   '교수님',
#   '거',
#   '전산',
#   '필',
#   '뭐',
#   '중간',
#   '전',
#   '정',
#   '정진완',
#   '진완',
#   '교수님',
#   '공부',
#   '안',
#   '정도',
#   '시험',
#   '범위',
#   '뿐',
#   '문제',
#   '이후',
#   '터',
#   '최',
#   '최성희',
#   '성희',
#   '진도',
#   '하루',
#   '챕터',
#   '날',
#   '수업',
#   '준비',
#   '질문',
#   '당황',
#   '모두',
#   '영어',
#   '영어강의',
#   '강의',
#   '학생',
#   '입장',
#   '집중',
#   '박진',
#   '교수님',
#   '이산',
#   '이산구조',
#   '구조',
#   '사랑',
#   '이산수학',
#   '수학',
#   '고민',
#   '분',
#   '저',
#   '추천',
#   '추천해',
#   '해',
#   '학생',
#   '신경',
#   '가지',
#   '팁',
#   '매',
#   '시간',
#   '출석',
#   '대신',
#   '때',
#   '질문',
#   '제출',
#   '대부분',
#   '별',
#   '수업',
#   '이름',
#   '1',
#   '2',
#   '2분',
#   '애',
#   '말',
# ...
#   '저',
#   '경우',
#   '강의',
#   '전',
#   '겨울',
#   '겨울방학때',
#   '방학',
#   '때',
#   '7',
#   '7단원',
#   '단원',
#   '공부',
#   '이해',
#   '책',
#   '선행',
#   '선행나가시',
#   '나가시',
#   '추천',
#   '논리',
#   '설명',
#   '데',
#   '개인적',
#   '생각',
#   '명제',
#   '명제논리',
#   '1차논리',
#   '차',
#   '추론',
#   '추론규칙',
#   '규칙',
#   '부분',
#   '수',
#   '2',
#   '오신',
#   '신지라',
#   '수업중',
#   '중',
#   '시간',
#   '흐름',
#   '학생',
#   '혼란',
#   '이',
#   '처음',
#   '반감',
#   '점',
#   '위주',
#   '체계적',
#   '특정',
#   '교재',
#   '선택',
#   '예',
#   '위',
#   '언급',
#   '3',
#   '논리학',
#   '학',
#   '학문',
#   '하면',
#   '안',
#   '시작',
#   '동안',
#   '1',
#   '교수님',
#   '학교',
#   '새',
#   '오심',
#   '원래',
#   '전공',
#   '거',
#   '논리',
#   '과목',
#   '처음',
#   '본인',
#   '강의',
#   '이해',
#   '의문',
#   '내용',
#   '렉',
#   '노트',
#   '책',
#   '꿀',
#   '꿀잼2',
#   '잼',
#   '2',
#   '과제',
#   '논리식',
#   '식',
#   '프로그램',
#   '이용',
#   '네모',
#   '직',
#   '솔버',
#   '소스',
#   '테스터',
#   '나름',
#   '사실',
#   '방법',
#   '하나',
#   '하나여',
#   '여',
#   '프리',
#   '제일',
#   '실행',
#   '실행속',
#   '속',
#   '친구',
#   '상도',
#   '하면',
#   '3',
#   '시험',
#   '공부',
#   '머리',
#   '수',
#   '정도',
#   '학점',
#   '성적',
#   '1',
#   '평',
#   '평균',
#   '균',
#   '3',
#   '2',
#   '9',
#   '중간',
#   '메디',
#   '메디안',
#   '안',
#   '10',
#   '기말',
#   '평균',
#   '8',
#   '전부',
#   '100',
#   '100점',
#   '점',
#   '만점',
#   '수업',
#   '전출',
#   '참',
#   '참여하',
#   '여하',
#   '결과',
#   '만족',
#   '시험',
#   '중간고사',
#   '기말고사',
#   '고사',
#   '내용',
#   '25',
#   '25점',
#   '가량',
#   '전반적',
#   '구성',
#   '구성요소',
#   '요소',
#   '정도',
#   '중',
#   '범위',
#   '교수님',
#   '뒤',
#   '정신',
#   '혼미',
#   '끝',
#   '날',
#   '적극적',
#   '참여',
#   '학생',
#   '점수',
#   '추가',
#   '기본',
#   '결석',
#   '5',
#   '5회',
#   '회',
#   '미만',
#   '70',
#   '주',
#   '주심',
#   '심',
#   '집중',
#   '과제',
#   '1은',
#   '은',
#   '코딩',
#   '때',
#   '고려',
#   '정신건강',
#   '건강',
#   '논리',
#   '흥미',
#   '과목',
#   '내용',
#   '특성',
#   '유발',
#   '중간',
#   '고사',
#   '이후',
#   '한번',
#   '흐름',
#   '의지',
#   '걱정',
#   '마',
#   '마세요',
#   '세요',
#   '당신',
#   '혼자',
#   '벼락',
#   '기와',
#   '숙제',
#   '시간',
#   '조금',
#   '학기',
#   '7',
#   '7일',
#   '일',
#   '이내',
#   '노력',
#   '필요',
#   '성적',
#   '널',
#   '널널',
#   '강의',
#   '교수님',
#   '듯',
#   '중간고사',
#   '이전',
#   '겐트젠',
#   '힐',
#   '힐베르트',
#   '베르트',
#   '자연',
#   '유도',
#   '기말',
#   '기말고사',
#   '고사',
#   '동그라미',
#   '네모',
#   '다이',
#   '다이아몬드',
#   '아몬드',
#   '신이',
#   '존재',
#   '증명',
#   '소리',
#   '구',
#   '신청',
#   '후'],
#  ['개론',
#   '개론과목',
#   '과목',
#   '인공',
#   '인공지능',
#   '지능',
#   '이슈',
#   '무엇',
#   '공부',
#   '점',
#   '긍정적',
#   '생각',
#   '수업',
#   '편이',
#   '파이',
#   '외',
#   '등',
#   '언어',
#   '과제',
#   '6',
#   '7',
#   '7개',
#   '개',
#   '정도',
#   '기억',
#   '시험',
#   '학점',
#   '학점',
#   '샘플링',
#   '필요',
#   '문제',
#   '제가',
#   '그레이',
#   '그레이딩',
#   '딩',
#   '정책',
#   '이해',
#   '널',
#   '널널',
#   '과제',
#   '편',
#   '수업',
#   '공부',
#   '하면',
#   '강',
#   '강의',
#   '이거',
#   '수',
#   '정보',
#   '매',
#   '나이아가라',
#   '폭포수',
#   '이중',
#   '절반',
#   '절반정도',
#   '정도',
#   '실제',
#   '구현',
#   '나머지',
#   '진짜',
#   '시간',
#   '진도',
#   '이름',
#   '챕터',
#   '중요',
#   '기술',
#   '이젠',
#   '거만',
#   '관심',
#   '분',
#   '적극',
#   '적극권장',
#   '권장',
#   '김',
#   '응',
#   '응교수님',
#   '교수님',
#   '전산',
#   '질문',
#   '답변',
#   '퀄리티',
#   '적',
#   '필드',
#   '생각',
#   '이것',
#   '존재',
#   '배',
#   '때문',
#   '거',
#   '말',
#   '이상',
#   '나름',
#   '가치',
#   '일',
#   '성적',
#   '의문',
#   '중간',
#   '중간기말',
#   '기말',
#   '비중',
#   '점수',
#   '여',
#   '감사',
#   '기대',
#   '만큼',
#   '수업',
#   '전산',
#   '학생',
#   '강',
#   '슬라이드',
#   '수식',
#   '시험',
#   '수학',
#   '조교',
#   '의',
#   '부분',
#   '부분점수',
#   '점수',
#   '기준',
#   '가혹',
#   '성적',
#   '과제',
#   '비중',
#   '수업',
#   '수업자료',
#   '자료',
#   '질',
#   '만족',
#   '중간',
#   '중간고사',
#   '고사',
#   '기말',
#   '기말고사',
#   '문제',
#   '경우',
#   '조정',
#   '필요',
#   '필요하다',
#   '하다',
#   '생각',
#   '내용',
#   '대부분',
#   '부분',
#   '포함',
#   '수업',
#   '저',
#   '겐',
#   '학교',
#   '3',
#   '3년동안',
#   '년',
#   '동안',
#   '역대',
#   '최악',
#   '강의',
#   '실력',
#   '추임새',
#   '정도',
#   '중간',
#   '기말',
#   '공부',
#   '거',
#   '의미',
#   '쌩뚱맞',
#   '곳',
#   '문제',
#   '편차',
#   '전반적',
#   '커리큘럼',
#   '뒤죽박죽',
#   '내용',
#   '설명',
#   '빈약',
#   '혼자',
#   '책',
#   '보고',
#   '과제',
#   '플젝',
#   '3번',
#   '번',
#   '문제풀기',
#   '풀기',
#   '2',
#   '2번',
#   '씨름',
#   '씨름하다',
#   '하다',
#   '과목',
#   '무엇',
#   '이해',
#   '완전',
#   '강판',
#   '예상',
#   '성적',
#   '비중'],
#  ['전산',
#   '전산학부',
#   '학부',
#   '과목',
#   '중',
#   '다음',
#   '로드',
#   '수업',
#   '생각',
#   '시험',
#   '팀',
#   '프로젝트',
#   '안',
#   '안드로이드',
#   '드로',
#   '이드',
#   '프로그래밍',
#   '에세이',
#   '작성',
#   '퀴즈',
#   '등',
#   '자주',
#   '안드로이드로만',
#   '로만',
#   '구현',
#   '전산학',
#   '교수님',
#   '본인',
#   '선',
#   '학점',
#   '수강생',
#   '성적',
#   '만족',
#   '분',
#   '강의',
#   '토론',
#   '유도',
#   '수',
#   '초반',
#   '교수님',
#   '수업',
#   '뒤',
#   '모바일',
#   '컴퓨팅',
#   '분야',
#   '논문',
#   '학생',
#   '발표',
#   '식',
#   '진행',
#   '팀',
#   '프로젝트',
#   '영어',
#   '때문',
#   '분',
#   '부담',
#   '수',
#   '눈치',
#   '분위기',
#   '주제',
#   '선정',
#   '때',
#   '조',
#   '조교',
#   '교',
#   '조언도',
#   '번',
#   '번정도',
#   '정도',
#   '안',
#   '안드로이드',
#   '드로',
#   '이드',
#   '두이',
#   '두이노',
#   '노',
#   '숙제',
#   '학부',
#   '유형',
#   '사람',
#   '켄즈',
#   '17',
#   '17봄',
#   '봄',
#   '성적',
#   '기억',
#   '전산',
#   '과목',
#   '중',
#   '강의',
#   '수업',
#   '최근',
#   '모바일',
#   '컴퓨팅',
#   '분야',
#   '논문',
#   '영어',
#   '발표',
#   '디스커션',
#   '식',
#   '외',
#   '팀',
#   '프로젝트',
#   '로드',
#   '성장',
#   '초반',
#   '준비',
#   '에세이',
#   '작성',
#   '학기말',
#   '거부감',
#   '수',
#   '작업',
#   '구현',
#   '발전',
#   '자체',
#   '집중',
#   '개인적',
#   '만족',
#   '교수님',
#   '직접적',
#   '공부',
#   '연락',
#   '분위기',
#   '직접',
#   '피드백',
#   '학생',
#   '생산적',
#   '고민',
#   '대학원',
#   '진학',
#   '생각',
#   '학점'],
#  ['과제',
#   '스타트',
#   '스타트업',
#   '업',
#   '관련',
#   '2',
#   '2가지',
#   '가지',
#   '중간',
#   '전',
#   '단원',
#   '요약',
#   '정리',
#   '2쪽',
#   '쪽',
#   '이내',
#   '이내임',
#   '임',
#   '조교',
#   '평가',
#   '교수님',
#   '3',
#   '3가지',
#   '점수',
#   '주심',
#   '기말',
#   '추가',
#   '제출',
#   '추가점수',
#   '2명',
#   '명',
#   '팀',
#   '매',
#   '단계',
#   '발표',
#   '거',
#   '기준',
#   '데',
#   '코멘트',
#   '수정',
#   '성적',
#   '프로젝트',
#   '전체',
#   '중간고사',
#   '고사',
#   '주신',
#   '중요',
#   '부분',
#   '모두',
#   '서술',
#   '사람',
#   '기출',
#   '유형',
#   '감',
#   '강의',
#   '나름',
#   '도움'],
#  ['학점',
#   '전',
#   '강의',
#   '강의자료',
#   '자료',
#   '퀄리티',
#   '후',
#   '애니메이션',
#   '떡',
#   '떡칠',
#   '칠',
#   '시험',
#   '시험기간',
#   '기간',
#   '직전',
#   '버전',
#   '공유',
#   '안',
#   '숙제',
#   '수업',
#   '수업시간',
#   '시간',
#   '집중',
#   '순',
#   '진짜',
#   '이상',
#   '농담',
#   '순수',
#   '이거',
#   '확인',
#   '문제',
#   '완전',
#   '꽝',
#   '다가',
#   '채점',
#   '피드백',
#   '솔루션',
#   '설명',
#   '완전별',
#   '별',
#   '저',
#   '중간고사',
#   '이후',
#   '포기',
#   '만약',
#   '필수',
#   '필수선택',
#   '선택',
#   '때문',
#   '거',
#   '과목',
#   '평가',
#   '교수님',
#   '수업',
#   '생각',
#   '강의',
#   '자료',
#   '퀄리티',
#   '이견',
#   '고요',
#   '확인',
#   '보시기',
#   '18',
#   '500',
#   '슬라이드',
#   '불친절',
#   '흥미',
#   '토픽',
#   '대체적',
#   '과목',
#   '운영',
#   '시험',
#   '통계',
#   '21',
#   '21세기',
#   '세기',
#   '전산',
#   '전산학부',
#   '학부',
#   '대학원',
#   '손',
#   '숙제',
#   '강제',
#   '학기',
#   '요건',
#   '때문',
#   '집중',
#   '수',
#   '강의',
#   '부실',
#   '강의자료',
#   '자료',
#   '수업',
#   '독학',
#   '총체적',
#   '난국',
#   '숙제',
#   '문제',
#   '능력',
#   '학점',
#   '걱정',
#   '안',
#   '듯'],
#  ['단점',
#   '단점1',
#   '1',
#   '강의',
#   '요구',
#   '프로젝트',
#   '2',
#   '학생',
#   '발표',
#   '중간',
#   '태클',
#   '진행',
#   '안됨',
#   '안됨2',
#   '마나',
#   '3',
#   '수준',
#   '나도',
#   '정도',
#   '생각',
#   '장점',
#   '장점1',
#   '수업',
#   '결론'],
#  ['요약',
#   '수업',
#   '갓',
#   '쨋',
#   '우리',
#   '중요',
#   '건',
#   '학점',
#   '최소한',
#   '수강',
#   '수강후기',
#   '후기',
#   '수',
#   '정도',
#   '관점',
#   '한마디',
#   '표현',
#   '시간',
#   '시간대비',
#   '대비',
#   '성비',
#   '개똥',
#   '개똥망인',
#   '망인',
#   '개론',
#   '교수님',
#   '수업자료',
#   '자료',
#   '준비',
#   '신경',
#   '눈',
#   '실제',
#   '사례',
#   '영상',
#   '내용',
#   '적용',
#   '확인',
#   '매',
#   '매수업',
#   '5',
#   '5분',
#   '분',
#   '10',
#   '10분',
#   '분',
#   '실습',
#   '포함',
#   '수업내용',
#   '전달',
#   '때문',
#   '류',
#   '류석영',
#   '석영',
#   '부류',
#   '명',
#   '명강의',
#   '강의',
#   '체험',
#   '학기',
#   '진행',
#   '이것',
#   '구성',
#   '프로젝트',
#   '거',
#   '엉',
#   '여기',
#   '문제',
#   '지간',
#   '지간히',
#   '히',
#   '실수',
#   '감점',
#   '과제',
#   '평균',
#   '100',
#   '100점',
#   '점',
#   '만점',
#   '92',
#   '92점',
#   '식',
#   '변별력',
#   '과장',
#   '정말',
#   '조',
#   '조차',
#   '차',
#   '사태',
#   '역시나',
#   '예상',
#   '성적',
#   '의아',
#   '중',
#   '성적',
#   '주심',
#   '로드',
#   '개',
#   '리딩',
#   '리딩메터리얼',
#   '메터',
#   '리얼',
#   '나노',
#   '나노퀴즈',
#   '퀴즈',
#   '매',
#   '보고서',
#   '할거',
#   '발표',
#   '구현',
#   '과제',
#   '프밍',
#   '프밍과제',
#   '캬',
#   '캬진짜',
#   '진짜',
#   '극',
#   '극강임',
#   '강',
#   '임',
#   '강의',
#   '하심',
#   '수업',
#   '방식',
#   '자체',
#   '고전적',
#   '오픈',
#   '로드',
#   '학점',
#   '안주',
#   '데',
#   '웹',
#   '개발',
#   '시',
#   '수업',
#   '완전',
#   '추천',
#   '분야',
#   '개론',
#   '만큼',
#   '이해',
#   '교수님',
#   '강의',
#   '우리',
#   '우리학교',
#   '학교',
#   '명',
#   '명강의중',
#   '중',
#   '하나',
#   '정도',
#   '학생',
#   '적극적',
#   '학기',
#   '학기동안',
#   '동안',
#   '개인적',
#   '숙제',
#   '3',
#   '3개정도',
#   '개',
#   '그룹',
#   '프로젝트',
#   '개인',
#   '실력',
#   '로드',
#   '앞',
#   '일',
#   '내용',
#   '100',
#   '성적',
#   '로드',
#   '8',
#   '8학기',
#   '학기',
#   '지금',
#   '수업',
#   '중',
#   '학기동안',
#   '동안',
#   '웹',
#   '웹서비스',
#   '서비스',
#   '하나',
#   '중간',
#   '조',
#   '발표',
#   '레포트',
#   '8번',
#   '번',
#   '매',
#   '퀴즈',
#   '영어',
#   '읽기',
#   '읽기자료',
#   '자료',
#   '진짜',
#   '교수님',
#   '수업내용',
#   '내용',
#   '흥미',
#   '영상',
#   '예시',
#   '총평',
#   '디자인',
#   '관심',
#   '대비',
#   '기억',
#   '프로그래밍',
#   '줄',
#   '제가',
#   '카',
#   '카이스트',
#   '이스트',
#   '전공',
#   '전공중',
#   '중',
#   '탑',
#   '탑2',
#   '2',
#   '명',
#   '명강의',
#   '강의',
#   '교수님',
#   '영어',
#   '다양',
#   '자료',
#   '활용',
#   '수업',
#   '사실',
#   '나',
#   '만큼',
#   '지',
#   '최고',
#   '학점',
#   '평',
#   '거',
#   '절반',
#   '절반가량',
#   '가량',
#   '에이',
#   '평가',
#   '로드',
#   '기본적',
#   '팀',
#   '프로젝트',
#   '하나',
#   '완성',
#   '1',
#   '팀플',
#   '플',
#   '베이스',
#   '격주',
#   '리포트',
#   '지',
#   '조원',
#   '진짜',
#   '포함',
#   '일주일',
#   '6',
#   '6번',
#   '번',
#   '퀴즈',
#   '3',
#   '개인',
#   '플젝',
#   '플젝과제',
#   '과제',
#   '2번',
#   '번',
#   '웹',
#   '웹개발',
#   '개발',
#   '생각',
#   '정도',
#   '전',
#   '전프',
#   '프',
#   '소',
#   '소공개',
#   '공개',
#   '신선',
#   '시간',
#   '투자',
#   '결과',
#   '과목',
#   '말길',
#   '예',
#   '라',
#   '1',
#   '로드',
#   '로드로드',
#   '스타일',
#   '시간',
#   '건',
#   '팀',
#   '팀플',
#   '플',
#   '커뮤니케이션',
#   '비용',
#   '거',
#   '거라',
#   '라',
#   '조장',
#   '전체적',
#   '소통',
#   '진',
#   '웹',
#   '웹코딩',
#   '코딩',
#   '경우',
#   '기술',
#   '결국',
#   '습득',
#   '습득시간',
#   '마련',
#   '저',
#   '원래',
#   '사람',
#   '코드',
#   '작성',
#   '자체',
#   '코드',
#   '2',
#   '2주말',
#   '주말',
#   '정도',
#   '것교수님',
#   '교수님',
#   '교육',
#   '관심',
#   '강의',
#   '관련',
#   '입증',
#   '연구',
#   '결과',
#   '교실',
#   '체험',
#   '수',
#   '수업',
#   '설계',
#   '하나',
#   '교훈',
#   '분',
#   '비교',
#   '고전적',
#   '전달',
#   '생각',
#   '형태',
#   '시간내',
#   '내',
#   '효율적',
#   '지식',
#   '방법',
#   '무엇',
#   '지에',
#   '고민',
#   '느낌',
#   '3',
#   '학점',
#   '학점로드',
#   '최대한',
#   '모든',
#   '과제',
#   '만점',
#   '연속',
#   '본인',
#   '최종적',
#   '산출',
#   '플젝',
#   '성실성',
#   '보상',
#   '내고',
#   '출석',
#   '예상',
#   '4',
#   '주의',
#   '점',
#   '점최종',
#   '최종',
#   '산출물',
#   '기술적',
#   '성적',
#   '참고',
#   '바',
#   '바래요',
#   '래요',
#   '인터페이스',
#   '사용자',
#   '경험',
#   '부분',
#   '앵',
#   '앵귤러',
#   '귤',
#   '러',
#   '리',
#   '써서',
#   '구현',
#   '경험적',
#   '문제',
#   '접근',
#   '해결',
#   '평가',
#   '문제점',
#   '발견',
#   '다음',
#   '두시',
#   '두시길',
#   '길',
#   '번',
#   '고통',
#   '결석',
#   '조심',
#   '대충',
#   '3회',
#   '회',
#   '명실상부',
#   '최고',
#   '내용',
#   '수업',
#   '학기',
#   '고통',
#   '당신',
#   '모습',
#   '군',
#   '과목',
#   '0',
#   '만큼',
#   '고생',
#   '그',
#   '보상',
#   '성적',
#   '편',
#   '거란',
#   '보장',
#   '학생',
#   '누군가',
#   '렉',
#   '전달',
#   '방식',
#   '탈피',
#   '강',
#   '수업',
#   '컨텐츠',
#   '다양',
#   '중간',
#   '동영상',
#   '매',
#   '시간',
#   '교수님',
#   '설명',
#   '옆',
#   '짝꿍',
#   '활동',
#   '예시',
#   '이해',
#   '카',
#   '카이스트',
#   '이스트',
#   '생각',
#   '영어',
#   '영어영어',
#   '완벽',
#   '구사',
#   '뿐',
#   '조교',
#   '영어를',
#   '발표',
#   '과제',
#   '저',
#   '한국',
#   '학생',
#   '이것',
#   '부담',
#   '로드',
#   '메인',
#   '8',
#   '8개',
#   '개',
#   '하나',
#   '하나당',
#   '당',
#   '5',
#   '5시간',
#   '예상',
#   '저희',
#   '팀',
#   '10',
#   '10시간정도',
#   '시간',
#   '정도',
#   '이상',
#   '24',
#   '24시간',
#   '개인',
#   '플러스',
#   '오',
#   '오티엘',
#   '티',
#   '엘',
#   '평가',
#   '학점',
#   '이전',
#   '성적',
#   '이번',
#   '분포',
#   '메일',
#   '공지',
#   '60',
#   '60명',
#   '명',
#   '중',
#   '41',
#   '41명',
#   '요',
#   'ㄸ'],
#  ['교수님', '강의', '하심', '프로젝트', '평가', '기준', '감사'],
#  ['교수님',
#   '수업',
#   '수업내용',
#   '내용',
#   '나름',
#   '아주',
#   '강추',
#   '학점',
#   '편',
#   '수업',
#   '널',
#   '매시간',
#   '퀴즈',
#   '성적',
#   '영향',
#   '주기',
#   '때문',
#   '별',
#   '부담',
#   '중간',
#   '중간고사도',
#   '고사도',
#   '이전',
#   '학기',
#   '시험',
#   '시험문제',
#   '문제',
#   '공부',
#   '지장',
#   '중간고사',
#   '이후',
#   '수업시간',
#   '시간',
#   '학생',
#   '발표',
#   '기말',
#   '기말고사',
#   '고사',
#   '대체',
#   '준비',
#   '최종',
#   '최종성적'],
#  ['출석', '로드', '수업', '네트워크', '운영', '운영체제', '체제', '과목'],
#  ['매', '캠프'],
#  ['소프트',
#   '소프트웨어',
#   '웨어',
#   '공학',
#   '350',
#   '개론',
#   '과목',
#   '알고리즘',
#   '문제',
#   '한정',
#   '안',
#   '수',
#   '공부',
#   '등',
#   '베이스',
#   '수업',
#   '자체',
#   '기한',
#   '기법',
#   '이해',
#   '강화',
#   '강화학습',
#   '학습',
#   '개념',
#   '상태',
#   '연관',
#   '학기',
#   '반',
#   '교수님',
#   '렉',
#   '중간',
#   '고사',
#   '이후',
#   '팀',
#   '논문',
#   '하나',
#   '요약',
#   '소개',
#   '이용',
#   '구현',
#   '프로젝트',
#   '발표',
#   '가급적',
#   '중요',
#   '인용',
#   '인용수도',
#   '수도',
#   '강의',
#   '성격',
#   '질문',
#   '과제',
#   '2',
#   '2개',
#   '개',
#   '들',
#   '프로그램',
#   '테스트',
#   '자신',
#   '기반',
#   '마감',
#   '기말',
#   '기말고사',
#   '직전',
#   '촉박',
#   '형식',
#   '자유',
#   '자유주제',
#   '주제',
#   '얼마',
#   '전',
#   '내신',
#   '처음',
#   '이것',
#   '소리',
#   '추천',
#   '팀발표',
#   '준비',
#   '하셔야겠지만',
#   '시험',
#   '전반적',
#   '출제',
#   '성적',
#   '평균적',
#   '널',
#   '널널',
#   '로드',
#   '정도',
#   '편',
#   '신경',
#   '과제',
#   '2',
#   '2개',
#   '개',
#   '학기',
#   '프로젝트',
#   '1',
#   '1개',
#   '논문',
#   '편',
#   '배정',
#   '하나',
#   '발표',
#   '조가',
#   '질문',
#   '용도',
#   '강의',
#   '영국',
#   '거',
#   '여',
#   '해외',
#   '교수님',
#   '영어',
#   '설명',
#   '이쪽',
#   '필드',
#   '유명',
#   '유명세',
#   '나이',
#   '소프트',
#   '소프트웨어',
#   '웨어',
#   '테스팅',
#   '학',
#   '학회의',
#   '회의',
#   '체어',
#   '분',
#   '주변',
#   '수업',
#   '오해',
#   '이름',
#   '교양',
#   '교양수업',
#   '인문계',
#   '공학',
#   '파트',
#   '관해',
#   '절반',
#   '적용',
#   '기술',
#   '중간',
#   '이후',
#   '나머지',
#   '지',
#   '관심',
#   '분',
#   '기반',
#   '사례',
#   '도움',
#   '이',
#   '분야',
#   '전',
#   '바',
#   '학생',
#   '알고리즘',
#   '문제',
#   '방법론',
#   '이용',
#   '불완전',
#   '만큼',
#   '해결',
#   '과정',
#   '생각',
#   '건',
#   '불가능',
#   '성능',
#   '솔루션',
#   '휴',
#   '휴리스틱',
#   '리',
#   '스틱',
#   '메',
#   '메소드',
#   '소드',
#   '최단',
#   '최단거리',
#   '거리',
#   '기록',
#   '루트',
#   '현실',
#   '최단루트',
#   '이동',
#   '이동거리',
#   '경우',
#   '왕좌',
#   '건',
#   '요',
#   '근래',
#   '이',
#   '접근',
#   '연구',
#   '퍼포먼스',
#   '반쯤',
#   '미래',
#   '연',
#   '추천',
#   '이것',
#   '수강',
#   '산업',
#   '활용',
#   '수',
#   '예시',
#   '보기',
#   '현실적',
#   '예',
#   '교수님',
#   '수업',
#   '시험',
#   '공부',
#   '없었지만코스웍',
#   '프로젝트',
#   '발표',
#   '약간',
#   '부담',
#   '정도',
#   '강',
#   '명',
#   '인공',
#   '인공지능',
#   '지능',
#   '소프트',
#   '소프트웨어',
#   '웨어',
#   '공학',
#   '키워드',
#   '개론',
#   '선행',
#   '선행과목',
#   '과목',
#   '필요',
#   '대학원',
#   '분',
#   '듣기',
#   '기본적',
#   '내용',
#   '중간',
#   '중간기간',
#   '기간',
#   '전',
#   '중간고사',
#   '적용',
#   '들',
#   '조',
#   '조별',
#   '별',
#   '형식',
#   '흥미',
#   '수',
#   '추천'],
#  ['텍스트',
#   '텍스트마이닝',
#   '마이닝',
#   '기본',
#   '기본적인',
#   '적인',
#   '내용',
#   '대부분',
#   '압축',
#   '수',
#   '대학원',
#   '씬',
#   '과목',
#   '과제',
#   '레벨',
#   '시험',
#   '플젝',
#   '저',
#   '의',
#   '발표',
#   '와중',
#   '그분',
#   '클라스',
#   '감탄',
#   '이스트',
#   '쯤',
#   '시더',
#   '그것',
#   '준비',
#   '종합적',
#   '학부',
#   '학부생이',
#   '생이',
#   '마음',
#   '실제',
#   '추천',
#   '자체'],
#  ['전', '과목', '행운', '할렐루야'],
#  ['교수님', '친절', '강의', '내용', '흥미', '주제', '실제', '프로젝트', '멘토링', '한번쯤', '과목'],
#  ['3',
#   '3줄요약코딩',
#   '줄',
#   '요약',
#   '코딩',
#   '프로젝트',
#   '비트',
#   '비트코인',
#   '코',
#   '인',
#   '구현',
#   '중간',
#   '퀴즈',
#   '기말',
#   '대체',
#   '대체수업',
#   '수업',
#   '기',
#   '공부',
#   '느낌',
#   '널',
#   '널널',
#   '강의',
#   '강의계획서',
#   '계획서',
#   '문',
#   '문수복',
#   '수복',
#   '교수님',
#   '준비',
#   '때문',
#   '흐름',
#   '집중',
#   '건강',
#   '문제',
#   '휴강',
#   '당일',
#   '발표',
#   '아침',
#   '9',
#   '9시',
#   '시',
#   '7',
#   '시',
#   '중간고사',
#   '전',
#   '분산',
#   '알고리즘',
#   '책',
#   '사용',
#   '말',
#   '이해',
#   '기말고사',
#   '고사',
#   '시스템',
#   '내용',
#   '가상',
#   '가상화폐',
#   '화폐',
#   '을',
#   '개',
#   '이름',
#   '나름',
#   '우리',
#   '학교',
#   '학교산',
#   '산',
#   '개발',
#   '재미',
#   '초창',
#   '초창기라',
#   '기라',
#   '시행착오',
#   '언어',
#   '자유',
#   '조교',
#   '파이',
#   '도움',
#   '답변',
#   '제출',
#   '과제물',
#   '평가',
#   '수',
#   '채점',
#   '의문',
#   '출석',
#   '눈',
#   '성적',
#   '반영',
#   '자세',
#   '외',
#   '레포트',
#   '개',
#   '작성',
#   '주제',
#   '한글'],
#  ['학점',
#   '절대',
#   '절대평가',
#   '평가',
#   '시험',
#   '시험체점',
#   '체',
#   '점',
#   '학기',
#   '학기중',
#   '중',
#   '시간',
#   '앞내',
#   '이해',
#   '하면',
#   '뒷',
#   '뒷내용',
#   '내용',
#   '불가능',
#   '진도',
#   '시작',
#   '수업',
#   '복습',
#   '교수님',
#   '강의',
#   '집중',
#   '집중안',
#   '안',
#   '이상',
#   '증명',
#   '칠판',
#   '수'],
#  ['중간',
#   '유익',
#   '로드',
#   '이후',
#   '과목',
#   '중간고사',
#   '고사',
#   '머신',
#   '머신러닝',
#   '러닝',
#   '개관',
#   '수',
#   '기말',
#   '때',
#   '생물학',
#   '문제',
#   '적용',
#   '프로젝트',
#   '진행',
#   '수업',
#   '100',
#   '학생',
#   '발표',
#   '플젝',
#   '상황',
#   '로',
#   '아무것',
#   '상태',
#   '직접',
#   '점'],
#  ['참고',
#   '수학과',
#   '학부',
#   '충동적',
#   '수강',
#   '수강신청',
#   '신청',
#   '학기',
#   '학기동안',
#   '동안',
#   '한일',
#   '과목',
#   '공부',
#   '전반적',
#   '만족',
#   '수업',
#   '강의',
#   '강의구성',
#   '구성',
#   '17',
#   '17개',
#   '개',
#   '고차원',
#   '기계',
#   '기계학습',
#   '학습',
#   '관련',
#   '논문',
#   '평균',
#   '30',
#   '30페이지',
#   '페이지',
#   '이상',
#   '을',
#   '자유',
#   '형식',
#   '분량',
#   '내용',
#   '발표',
#   '팀',
#   '팀발표',
#   '수업전체',
#   '전체',
#   '개인',
#   '개인발표',
#   '수업절반',
#   '절반',
#   '시험',
#   '날',
#   '중간',
#   '중간중간',
#   '별개',
#   '교수님',
#   '이',
#   '수',
#   '주제',
#   '다양',
#   '상황',
#   '1',
#   '역할',
#   '그것',
#   '수학적',
#   '증명',
#   '사실',
#   '수학',
#   '언어',
#   '표현',
#   '때문',
#   '개념',
#   '등',
#   '등장',
#   '생소',
#   '흥미',
#   '후반부',
#   '특성',
#   '특성때문',
#   '즉석',
#   '논리',
#   '수식',
#   '나열',
#   '때',
#   '나중',
#   '이해',
#   '발표자',
#   '질문',
#   '토의',
#   '장려',
#   '학생',
#   '안해',
#   '인지',
#   '의미',
#   '오가',
#   '로드',
#   '사람',
#   '로드',
#   '공부량',
#   '량',
#   '과제',
#   '발표한번',
#   '한번',
#   '약간',
#   '수렴',
#   '3',
#   '3과목',
#   '자신',
#   '별',
#   '문제',
#   '성적',
#   '처음',
#   '수업참여',
#   '참여',
#   '만큼',
#   '하면',
#   '거',
#   '말'],
#  ['나이', '학생', '예의', '말', '말아드신', '아드', '신', '수업', '은퇴', '이상', '일', '다행'],
#  ['야', '세미나', '3', '양심적', '봄', '1', '가을', '장소'],
#  ['대학원',
#   '과목',
#   '대신',
#   '사용',
#   '기술',
#   '곳',
#   '적용',
#   '부분',
#   '관심',
#   '추천',
#   '과목',
#   '로드',
#   '중간고사',
#   '논문',
#   '논문발표',
#   '발표',
#   '플젝',
#   '플젝보고서',
#   '보고서',
#   '플젝발표',
#   '기말',
#   '기말고사',
#   '고사',
#   '공부',
#   '거리',
#   '교수님',
#   '설명',
#   '목',
#   '목소리',
#   '소리',
#   '수',
#   '전반적',
#   '수강',
#   '추천'],
#  ['시험',
#   '2',
#   '2번',
#   '번',
#   '논문',
#   '논문발표준비',
#   '발표',
#   '준비',
#   '프로젝트',
#   '머신',
#   '머신러닝',
#   '러닝',
#   '베이스',
#   '이해',
#   '데',
#   '시간',
#   '추천']]

# %%
dataset = lls
dct = Dictionary(lls)  # fit dictionary
corpus = [dct.doc2bow(line) for line in dataset]  # convert corpus to BoW format

# %%
model = TfidfModel(corpus)  # fit model
vector = model[corpus[4]]  # apply model to the first corpus document
vector
# Out:
# [(2, 0.062339505110142274),
#  (3, 0.07760376271521084),
#  (4, 0.026598527133749782),
#  (5, 0.021436415077859167),
#  (7, 0.016759458677371317),
#  (9, 0.06895470405267622),
#  (15, 0.043229412329871576),
#  (18, 0.04546722221986429),
#  (21, 0.0504858723241575),
#  (24, 0.062339505110142274),
#  (25, 0.07828602330300392),
#  (27, 0.03351891735474263),
#  (32, 0.05871451747725295),
#  (33, 0.025964038586171075),
#  (41, 0.0393206220877143),
#  (44, 0.021436415077859167),
#  (45, 0.129237790445732),
#  (46, 0.027229352326037803),
#  (47, 0.02524293616207875),
#  (51, 0.030311481479909527),
#  (52, 0.051735841810140556),
#  (53, 0.027229352326037803),
#  (57, 0.01377856857757235),
#  (59, 0.013635158049059945),
#  (63, 0.01804776401864386),
#  (66, 0.03040344788553281),
#  (70, 0.020970998446780957),
#  (71, 0.06897925666649567),
#  (75, 0.06554879125113791),
#  (76, 0.08773217143354149),
#  (77, 0.01465911295942856),
#  (78, 0.01377856857757235),
#  (80, 0.10389917518357046),
#  (83, 0.04397733887828567),
#  (84, 0.041804740842607616),
#  (86, 0.01377856857757235),
#  (87, 0.029551621744505714),
#  (89, 0.021933042858385373),
#  (90, 0.023171748992714524),
#  (91, 0.052938798862493905),
#  (93, 0.030603610386427667),
#  (95, 0.05194958759178523),
#  (96, 0.03289956428757806),
#  (99, 0.012982019293085538),
#  (100, 0.0193856685668598),
#  (107, 0.036764480311395696),
#  (108, 0.0275571371551447),
#  (111, 0.028031621491773837),
#  (112, 0.050323574314348356),
#  (113, 0.012982019293085538),
#  (114, 0.04546722221986429),
#  (116, 0.02384070126682249),
#  (120, 0.031169752555071137),
#  (122, 0.0452332266560062),
#  (123, 0.0387713371337196),
#  (124, 0.01465911295942856),
#  (126, 0.07120782047645008),
#  (127, 0.025867920905070278),
#  (130, 0.016759458677371317),
#  (134, 0.031169752555071137),
#  (135, 0.03026058863091011),
#  (136, 0.025964038586171075),
#  (138, 0.031169752555071137),
#  (139, 0.031942525317574876),
#  (140, 0.009343873830591279),
#  (141, 0.031942525317574876),
#  (142, 0.04768140253364498),
#  (145, 0.0551142743102894),
#  (151, 0.08645882465974315),
#  (153, 0.010966521429192687),
#  (164, 0.010966521429192687),
#  (166, 0.05477524652034621),
#  (167, 0.01465911295942856),
#  (168, 0.04397733887828567),
#  (169, 0.034757623489071784),
#  (172, 0.011585874496357262),
#  (173, 0.013635158049059945),
#  (177, 0.06573029582441545),
#  (179, 0.01377856857757235),
#  (180, 0.01804776401864386),
#  (182, 0.05304509258984168),
#  (183, 0.0071890820449069075),
#  (184, 0.021436415077859167),
#  (187, 0.016759458677371317),
#  (190, 0.059760743512319386),
#  (193, 0.016759458677371317),
#  (194, 0.04138867344811245),
#  (196, 0.045605171828299214),
#  (197, 0.07152210380046747),
#  (201, 0.034757623489071784),
#  (203, 0.052894296157193155),
#  (204, 0.015971262658787438),
#  (207, 0.07675212423734627),
#  (208, 0.0551142743102894),
#  (209, 0.04671936915295639),
#  (210, 0.016759458677371317),
#  (212, 0.02077983503671409),
#  (213, 0.01377856857757235),
#  (214, 0.01465911295942856),
#  (215, 0.08689405872267947),
#  (216, 0.01465911295942856),
#  (218, 0.012982019293085538),
#  (221, 0.015643477829680535),
#  (222, 0.032460826666586194),
#  (223, 0.02384070126682249),
#  (225, 0.058391530798354616),
#  (229, 0.023171748992714524),
#  (231, 0.01377856857757235),
#  (235, 0.02727031609811989),
#  (236, 0.159312748016048),
#  (237, 0.011585874496357262),
#  (241, 0.009850540581501905),
#  (249, 0.01377856857757235),
#  (251, 0.01377856857757235),
#  (264, 0.021436415077859167),
#  (266, 0.03351891735474263),
#  (270, 0.01377856857757235),
#  (272, 0.01377856857757235),
#  (278, 0.012982019293085538),
#  (280, 0.023956893988181155),
#  (281, 0.01377856857757235),
#  (282, 0.02524293616207875),
#  (284, 0.03914301165150196),
#  (286, 0.007985631329393719),
#  (287, 0.015155740739954763),
#  (288, 0.01377856857757235),
#  (291, 0.01957150582575098),
#  (292, 0.06573029582441545),
#  (293, 0.01465911295942856),
#  (294, 0.02875632817962763),
#  (298, 0.018687747661182558),
#  (300, 0.04768140253364498),
#  (303, 0.018687747661182558),
#  (307, 0.011585874496357262),
#  (309, 0.01957150582575098),
#  (312, 0.05508649869556981),
#  (317, 0.04138867344811245),
#  (318, 0.010389917518357045),
#  (320, 0.03408789512264986),
#  (323, 0.015643477829680535),
#  (326, 0.036724332463713205),
#  (328, 0.02875632817962763),
#  (329, 0.05619823602883305),
#  (331, 0.01377856857757235),
#  (332, 0.011585874496357262),
#  (335, 0.05792937248178631),
#  (336, 0.029551621744505714),
#  (337, 0.03914301165150196),
#  (339, 0.022733611109932144),
#  (340, 0.02077983503671409),
#  (341, 0.043866085716770746),
#  (342, 0.02931822591885712),
#  (344, 0.007985631329393719),
#  (346, 0.048965776618284274),
#  (347, 0.041804740842607616),
#  (348, 0.018387921080713656),
#  (350, 0.016759458677371317),
#  (354, 0.023956893988181155),
#  (355, 0.08795467775657134),
#  (358, 0.012254826770465231),
#  (360, 0.03609552803728772),
#  (362, 0.0168286241080525),
#  (364, 0.015971262658787438),
#  (365, 0.01804776401864386),
#  (369, 0.04925270290750953),
#  (371, 0.03940216232600762),
#  (373, 0.015155740739954763),
#  (377, 0.049019307081860926),
#  (378, 0.012982019293085538),
#  (380, 0.08574566031143667),
#  (382, 0.02384070126682249),
#  (384, 0.01804776401864386),
#  (388, 0.0043229412329871585),
#  (390, 0.09850540581501906),
#  (391, 0.01465911295942856),
#  (392, 0.00841431205402625),
#  (393, 0.01804776401864386),
#  (395, 0.042872830155718335),
#  (401, 0.01970108116300381),
#  (410, 0.012982019293085538),
#  (414, 0.0275571371551447),
#  (416, 0.061207220772855335),
#  (417, 0.043134492269441445),
#  (418, 0.0168286241080525),
#  (424, 0.03351891735474263),
#  (425, 0.07187068196454346),
#  (427, 0.009193960540356828),
#  (430, 0.00841431205402625),
#  (433, 0.0732955647971428),
#  (435, 0.007985631329393719),
#  (437, 0.023956893988181155),
#  (443, 0.027581881621070486),
#  (445, 0.02840322333326292),
#  (446, 0.060365921901015036),
#  (450, 0.010966521429192687),
#  (452, 0.024509653540930463),
#  (455, 0.017732351422499855),
#  (459, 0.10261379071599992),
#  (462, 0.02384070126682249),
#  (467, 0.015643477829680535),
#  (469, 0.025964038586171075),
#  (470, 0.041335705732717054),
#  (471, 0.04397733887828567),
#  (472, 0.14304420760093495),
#  (473, 0.012254826770465231),
#  (474, 0.06889284288786175),
#  (475, 0.08379729338685658),
#  (479, 0.02077983503671409),
#  (481, 0.01377856857757235),
#  (484, 0.01804776401864386),
#  (494, 0.06491009646542768),
#  (496, 0.01465911295942856),
#  (497, 0.02077983503671409),
#  (501, 0.03128695565936107),
#  (504, 0.016759458677371317),
#  (507, 0.01377856857757235),
#  (508, 0.016759458677371317),
#  (516, 0.021436415077859167),
#  (520, 0.016759458677371317),
#  (522, 0.02384070126682249),
#  (524, 0.042872830155718335),
#  (531, 0.012254826770465231),
#  (540, 0.012982019293085538),
#  (541, 0.008866175711249927),
#  (544, 0.010966521429192687),
#  (549, 0.020694336724056225),
#  (553, 0.01804776401864386),
#  (561, 0.0275571371551447),
#  (564, 0.07789211575851322),
#  (565, 0.0168286241080525),
#  (570, 0.010389917518357045),
#  (573, 0.0193856685668598),
#  (576, 0.01377856857757235),
#  (582, 0.021436415077859167),
#  (585, 0.0551142743102894),
#  (586, 0.016759458677371317),
#  (587, 0.06206322997874948),
#  (591, 0.021436415077859167),
#  (602, 0.01957150582575098),
#  (610, 0.01957150582575098),
#  (611, 0.02077983503671409),
#  (612, 0.012982019293085538),
#  (618, 0.04768140253364498),
#  (624, 0.024509653540930463),
#  (627, 0.012254826770465231),
#  (629, 0.017732351422499855),
#  (631, 0.026598527133749782),
#  (634, 0.04925270290750953),
#  (640, 0.016759458677371317),
#  (641, 0.009343873830591279),
#  (642, 0.027229352326037803),
#  (647, 0.016759458677371317),
#  (655, 0.01465911295942856),
#  (656, 0.025964038586171075),
#  (658, 0.012254826770465231),
#  (659, 0.021436415077859167),
#  (660, 0.04155967007342818),
#  (662, 0.02384070126682249),
#  (667, 0.036764480311395696),
#  (671, 0.04925270290750953),
#  (677, 0.015643477829680535),
#  (683, 0.03351891735474263),
#  (684, 0.016759458677371317),
#  (695, 0.01377856857757235),
#  (698, 0.027229352326037803),
#  (705, 0.01970108116300381),
#  (707, 0.01804776401864386),
#  (708, 0.016759458677371317),
#  (709, 0.06889284288786175),
#  (712, 0.03894605787925661),
#  (713, 0.01957150582575098),
#  (714, 0.01957150582575098),
#  (715, 0.01465911295942856),
#  (734, 0.03609552803728772),
#  (736, 0.06127413385232616),
#  (737, 0.01465911295942856),
#  (738, 0.07572880848623624),
#  (742, 0.03351891735474263),
#  (746, 0.01957150582575098),
#  (752, 0.027229352326037803),
#  (757, 0.01970108116300381),
#  (758, 0.01804776401864386),
#  (760, 0.02384070126682249),
#  (761, 0.054143292055931574),
#  (764, 0.03351891735474263),
#  (768, 0.025964038586171075),
#  (776, 0.01957150582575098),
#  (781, 0.011585874496357262),
#  (782, 0.015643477829680535),
#  (786, 0.05871451747725295),
#  (788, 0.01465911295942856),
#  (789, 0.023171748992714524),
#  (793, 0.012254826770465231),
#  (797, 0.015643477829680535),
#  (799, 0.02384070126682249),
#  (801, 0.01377856857757235),
#  (805, 0.06820083332979643),
#  (806, 0.01377856857757235),
#  (809, 0.012254826770465231),
#  (810, 0.03914301165150196),
#  (812, 0.021436415077859167),
#  (814, 0.0275571371551447),
#  (815, 0.01465911295942856),
#  (817, 0.042872830155718335),
#  (822, 0.02384070126682249),
#  (827, 0.03594541022453454),
#  (828, 0.0275571371551447),
#  (840, 0.012254826770465231),
#  (841, 0.012982019293085538),
#  (844, 0.01804776401864386),
#  (845, 0.03609552803728772),
#  (855, 0.01377856857757235),
#  (856, 0.015643477829680535),
#  (862, 0.03408789512264986),
#  (871, 0.0275571371551447),
#  (872, 0.025964038586171075),
#  (878, 0.024509653540930463),
#  (887, 0.034757623489071784),
#  (890, 0.036764480311395696),
#  (896, 0.01957150582575098),
#  (903, 0.021436415077859167),
#  (905, 0.03351891735474263),
#  (906, 0.05871451747725295),
#  (907, 0.02384070126682249),
#  (910, 0.010966521429192687),
#  (928, 0.012254826770465231),
#  (929, 0.01465911295942856),
#  (954, 0.016759458677371317),
#  (956, 0.04768140253364498),
#  (959, 0.016759458677371317),
#  (965, 0.01804776401864386),
#  (966, 0.016759458677371317),
#  (971, 0.02077983503671409),
#  (973, 0.03289956428757806),
#  (975, 0.1370005407802569),
#  (980, 0.01804776401864386),
#  (981, 0.01465911295942856),
#  (988, 0.0551142743102894),
#  (989, 0.021436415077859167),
#  (1001, 0.024509653540930463),
#  (1008, 0.027229352326037803),
#  (1010, 0.010966521429192687),
#  (1013, 0.023171748992714524),
#  (1014, 0.027229352326037803),
#  (1015, 0.016759458677371317),
#  (1022, 0.01377856857757235),
#  (1029, 0.01957150582575098),
#  (1031, 0.027229352326037803),
#  (1032, 0.028031621491773837),
#  (1038, 0.012982019293085538),
#  (1050, 0.03289956428757806),
#  (1051, 0.01465911295942856),
#  (1056, 0.02931822591885712),
#  (1057, 0.03128695565936107),
#  (1064, 0.02384070126682249),
#  (1066, 0.01804776401864386),
#  (1072, 0.03894605787925661),
#  (1074, 0.021436415077859167),
#  (1075, 0.016759458677371317),
#  (1079, 0.01465911295942856),
#  (1086, 0.016759458677371317),
#  (1093, 0.02384070126682249),
#  (1102, 0.016759458677371317),
#  (1103, 0.01804776401864386),
#  (1110, 0.027229352326037803),
#  (1111, 0.027229352326037803),
#  (1114, 0.01804776401864386),
#  (1121, 0.012982019293085538),
#  (1122, 0.03128695565936107),
#  (1134, 0.046930433489041606),
#  (1155, 0.016759458677371317),
#  (1161, 0.015643477829680535),
#  (1174, 0.01465911295942856),
#  (1175, 0.03128695565936107),
#  (1176, 0.010966521429192687),
#  (1193, 0.012982019293085538),
#  (1195, 0.05863645183771424),
#  (1196, 0.02384070126682249),
#  (1198, 0.042872830155718335),
#  (1199, 0.011585874496357262),
#  (1203, 0.01804776401864386),
#  (1210, 0.0275571371551447),
#  (1214, 0.015643477829680535),
#  (1220, 0.01465911295942856),
#  (1221, 0.027229352326037803),
#  (1232, 0.01465911295942856),
#  (1234, 0.08267141146543411),
#  (1237, 0.027229352326037803),
#  (1245, 0.05606324298354767),
#  (1253, 0.012254826770465231),
#  (1261, 0.01957150582575098),
#  (1262, 0.015643477829680535),
#  (1267, 0.016759458677371317),
#  (1270, 0.023171748992714524),
#  (1276, 0.01957150582575098),
#  (1279, 0.03128695565936107),
#  (1280, 0.015643477829680535),
#  (1283, 0.027229352326037803),
#  (1299, 0.01957150582575098),
#  (1302, 0.04397733887828567),
#  (1334, 0.009343873830591279),
#  (1365, 0.033022289574216435),
#  (1366, 0.033022289574216435),
#  (1367, 0.021436415077859167),
#  (1368, 0.033022289574216435),
#  (1369, 0.033022289574216435),
#  (1370, 0.033022289574216435),
#  (1371, 0.033022289574216435),
#  (1372, 0.027229352326037803),
#  (1373, 0.033022289574216435),
#  (1374, 0.033022289574216435),
#  (1375, 0.02384070126682249),
#  (1376, 0.033022289574216435),
#  (1377, 0.021436415077859167),
#  (1378, 0.01957150582575098),
#  (1379, 0.033022289574216435),
#  (1380, 0.033022289574216435),
#  (1381, 0.027229352326037803),
#  (1382, 0.054458704652075605),
#  (1383, 0.033022289574216435),
#  (1384, 0.027229352326037803),
#  (1385, 0.027229352326037803),
#  (1386, 0.01804776401864386),
#  (1387, 0.033022289574216435),
#  (1388, 0.033022289574216435),
#  (1389, 0.027229352326037803),
#  (1390, 0.02384070126682249),
#  (1391, 0.033022289574216435),
#  (1392, 0.033022289574216435),
#  (1393, 0.033022289574216435),
#  (1394, 0.027229352326037803),
#  (1395, 0.033022289574216435),
#  (1396, 0.027229352326037803),
#  (1397, 0.033022289574216435),
#  (1398, 0.01957150582575098),
#  (1399, 0.033022289574216435),
#  (1400, 0.027229352326037803),
#  (1401, 0.033022289574216435),
#  (1402, 0.033022289574216435),
#  (1403, 0.01957150582575098),
#  (1404, 0.033022289574216435),
#  (1405, 0.015643477829680535),
#  (1406, 0.02384070126682249),
#  (1407, 0.033022289574216435),
#  (1408, 0.033022289574216435),
#  (1409, 0.07152210380046747),
#  (1410, 0.033022289574216435),
#  (1411, 0.016759458677371317),
#  (1412, 0.033022289574216435),
#  (1413, 0.03609552803728772),
#  (1414, 0.01804776401864386),
#  (1415, 0.033022289574216435),
#  (1416, 0.033022289574216435),
#  (1417, 0.02384070126682249),
#  (1418, 0.012982019293085538),
#  (1419, 0.02384070126682249),
#  (1420, 0.033022289574216435),
#  (1421, 0.033022289574216435),
#  (1422, 0.027229352326037803),
#  (1423, 0.033022289574216435),
#  (1424, 0.033022289574216435),
#  (1425, 0.02384070126682249),
#  (1426, 0.033022289574216435),
#  (1427, 0.02384070126682249),
#  (1428, 0.027229352326037803),
#  (1429, 0.027229352326037803),
#  (1430, 0.033022289574216435),
#  (1431, 0.027229352326037803),
#  (1432, 0.02384070126682249),
#  (1433, 0.06604457914843287),
#  (1434, 0.033022289574216435),
#  (1435, 0.054458704652075605),
#  (1436, 0.06604457914843287),
#  (1437, 0.016759458677371317),
#  (1438, 0.021436415077859167),
#  (1439, 0.033022289574216435),
#  (1440, 0.033022289574216435),
#  (1441, 0.033022289574216435),
#  (1442, 0.01377856857757235),
#  (1443, 0.02384070126682249),
#  (1444, 0.02384070126682249),
#  (1445, 0.015643477829680535),
#  (1446, 0.021436415077859167),
#  (1447, 0.027229352326037803),
#  (1448, 0.01957150582575098),
#  (1449, 0.033022289574216435),
#  (1450, 0.015643477829680535),
#  (1451, 0.033022289574216435),
#  (1452, 0.033022289574216435),
#  (1453, 0.03609552803728772),
#  (1454, 0.04768140253364498),
#  (1455, 0.027229352326037803),
#  (1456, 0.06604457914843287),
#  (1457, 0.033022289574216435),
#  (1458, 0.027229352326037803),
#  (1459, 0.033022289574216435),
#  (1460, 0.027229352326037803),
#  (1461, 0.033022289574216435),
#  (1462, 0.033022289574216435),
#  (1463, 0.027229352326037803),
#  (1464, 0.027229352326037803),
#  (1465, 0.033022289574216435),
#  (1466, 0.033022289574216435),
#  (1467, 0.033022289574216435),
#  (1468, 0.033022289574216435),
#  (1469, 0.02384070126682249),
#  (1470, 0.027229352326037803),
#  (1471, 0.015643477829680535),
#  (1472, 0.01957150582575098),
#  (1473, 0.02384070126682249),
#  (1474, 0.06604457914843287),
#  (1475, 0.054458704652075605),
#  (1476, 0.015643477829680535),
#  (1477, 0.02384070126682249),
#  (1478, 0.01957150582575098),
#  (1479, 0.01957150582575098),
#  (1480, 0.06604457914843287),
#  (1481, 0.0990668687226493),
#  (1482, 0.033022289574216435),
#  (1483, 0.033022289574216435),
#  (1484, 0.027229352326037803),
#  (1485, 0.027229352326037803),
#  (1486, 0.033022289574216435),
#  (1487, 0.033022289574216435),
#  (1488, 0.033022289574216435),
#  (1489, 0.033022289574216435),
#  (1490, 0.033022289574216435),
#  (1491, 0.033022289574216435),
#  (1492, 0.027229352326037803),
#  (1493, 0.02384070126682249),
#  (1494, 0.033022289574216435),
#  (1495, 0.033022289574216435),
#  (1496, 0.027229352326037803),
#  (1497, 0.033022289574216435),
#  (1498, 0.04768140253364498),
#  (1499, 0.033022289574216435),
#  (1500, 0.033022289574216435),
#  (1501, 0.01465911295942856),
#  (1502, 0.021436415077859167),
#  (1503, 0.02384070126682249),
#  (1504, 0.033022289574216435),
#  (1505, 0.033022289574216435),
#  (1506, 0.021436415077859167),
#  (1507, 0.033022289574216435),
#  (1508, 0.033022289574216435),
#  (1509, 0.01804776401864386),
#  (1510, 0.042872830155718335),
#  (1511, 0.033022289574216435),
#  (1512, 0.027229352326037803),
#  (1513, 0.027229352326037803),
#  (1514, 0.027229352326037803),
#  (1515, 0.033022289574216435),
#  (1516, 0.016759458677371317),
#  (1517, 0.033022289574216435),
#  (1518, 0.042872830155718335),
#  (1519, 0.021436415077859167),
#  (1520, 0.033022289574216435),
#  (1521, 0.01957150582575098),
#  (1522, 0.033022289574216435),
#  (1523, 0.042872830155718335),
#  (1524, 0.033022289574216435),
#  (1525, 0.033022289574216435),
#  (1526, 0.033022289574216435),
#  (1527, 0.02384070126682249),
#  (1528, 0.033022289574216435),
#  (1529, 0.033022289574216435),
#  (1530, 0.033022289574216435),
#  (1531, 0.02384070126682249),
#  (1532, 0.021436415077859167),
#  (1533, 0.033022289574216435),
#  (1534, 0.027229352326037803),
#  (1535, 0.033022289574216435),
#  (1536, 0.033022289574216435),
#  (1537, 0.033022289574216435),
#  (1538, 0.033022289574216435),
#  (1539, 0.01957150582575098),
#  (1540, 0.033022289574216435),
#  (1541, 0.025964038586171075),
#  (1542, 0.027229352326037803),
#  (1543, 0.033022289574216435),
#  (1544, 0.02384070126682249),
#  (1545, 0.033022289574216435),
#  (1546, 0.033022289574216435),
#  (1547, 0.033022289574216435),
#  (1548, 0.033022289574216435),
#  (1549, 0.033022289574216435),
#  (1550, 0.033022289574216435),
#  (1551, 0.033022289574216435),
#  (1552, 0.033022289574216435),
#  (1553, 0.03609552803728772),
#  (1554, 0.021436415077859167),
#  (1555, 0.02384070126682249),
#  (1556, 0.027229352326037803),
#  (1557, 0.033022289574216435),
#  (1558, 0.027229352326037803),
#  (1559, 0.02384070126682249),
#  (1560, 0.033022289574216435),
#  (1561, 0.02384070126682249),
#  (1562, 0.07152210380046747),
#  (1563, 0.033022289574216435),
#  (1564, 0.027229352326037803),
#  (1565, 0.027229352326037803),
#  (1566, 0.01804776401864386),
#  (1567, 0.027229352326037803),
#  (1568, 0.033022289574216435),
#  (1569, 0.054458704652075605),
#  (1570, 0.0990668687226493),
#  (1571, 0.033022289574216435),
#  (1572, 0.0990668687226493),
#  (1573, 0.02384070126682249),
#  (1574, 0.016759458677371317),
#  (1575, 0.033022289574216435),
#  (1576, 0.033022289574216435),
#  (1577, 0.03914301165150196),
#  (1578, 0.033022289574216435),
#  (1579, 0.033022289574216435),
#  (1580, 0.01804776401864386),
#  (1581, 0.01957150582575098),
#  (1582, 0.02384070126682249),
#  (1583, 0.02384070126682249),
#  (1584, 0.033022289574216435),
#  (1585, 0.016759458677371317),
#  (1586, 0.033022289574216435),
#  (1587, 0.033022289574216435),
#  (1588, 0.10828658411186315),
#  (1589, 0.10828658411186315),
#  (1590, 0.033022289574216435),
#  (1591, 0.027229352326037803),
#  (1592, 0.027229352326037803),
#  (1593, 0.015643477829680535),
#  (1594, 0.054458704652075605),
#  (1595, 0.033022289574216435),
#  (1596, 0.033022289574216435),
#  (1597, 0.033022289574216435),
#  (1598, 0.027229352326037803),
#  (1599, 0.033022289574216435),
#  (1600, 0.01957150582575098),
#  (1601, 0.02384070126682249),
#  (1602, 0.01804776401864386),
#  (1603, 0.10828658411186315),
#  (1604, 0.033022289574216435),
#  (1605, 0.033022289574216435),
#  (1606, 0.027229352326037803),
#  (1607, 0.027229352326037803),
#  (1608, 0.01957150582575098),
#  (1609, 0.02384070126682249),
#  (1610, 0.046930433489041606),
#  (1611, 0.033022289574216435),
#  (1612, 0.027229352326037803),
#  (1613, 0.04768140253364498),
#  (1614, 0.033022289574216435),
#  (1615, 0.033022289574216435),
#  (1616, 0.027229352326037803),
#  (1617, 0.042872830155718335),
#  (1618, 0.02384070126682249),
#  (1619, 0.033022289574216435),
#  (1620, 0.033022289574216435),
#  (1621, 0.033022289574216435),
#  (1622, 0.06604457914843287),
#  (1623, 0.033022289574216435),
#  (1624, 0.07152210380046747),
#  (1625, 0.06604457914843287),
#  (1626, 0.02384070126682249),
#  (1627, 0.04768140253364498),
#  (1628, 0.027229352326037803),
#  (1629, 0.033022289574216435),
#  (1630, 0.010966521429192687),
#  (1631, 0.042872830155718335),
#  (1632, 0.027229352326037803),
#  (1633, 0.021436415077859167),
#  (1634, 0.027229352326037803),
#  (1635, 0.027229352326037803),
#  (1636, 0.033022289574216435),
#  (1637, 0.033022289574216435),
#  (1638, 0.033022289574216435),
#  (1639, 0.012982019293085538),
#  (1640, 0.01957150582575098),
#  (1641, 0.027229352326037803),
#  (1642, 0.02384070126682249),
#  (1643, 0.033022289574216435),
#  (1644, 0.042872830155718335),
#  (1645, 0.033022289574216435),
#  (1646, 0.02384070126682249),
#  (1647, 0.033022289574216435),
#  (1648, 0.033022289574216435),
#  (1649, 0.033022289574216435),
#  (1650, 0.033022289574216435),
#  (1651, 0.033022289574216435),
#  (1652, 0.033022289574216435),
#  (1653, 0.033022289574216435),
#  (1654, 0.033022289574216435),
#  (1655, 0.033022289574216435),
#  (1656, 0.027229352326037803),
#  (1657, 0.054458704652075605),
#  (1658, 0.054458704652075605),
#  (1659, 0.010966521429192687),
#  (1660, 0.027229352326037803),
#  (1661, 0.02384070126682249),
#  (1662, 0.027229352326037803),
#  (1663, 0.033022289574216435),
#  (1664, 0.027229352326037803),
#  (1665, 0.0643092452335775),
#  (1666, 0.01804776401864386),
#  (1667, 0.021436415077859167),
#  (1668, 0.033022289574216435),
#  (1669, 0.033022289574216435),
#  (1670, 0.033022289574216435),
#  (1671, 0.033022289574216435),
#  (1672, 0.033022289574216435),
#  (1673, 0.033022289574216435),
#  (1674, 0.03351891735474263),
#  (1675, 0.02384070126682249),
#  (1676, 0.033022289574216435),
#  (1677, 0.04768140253364498),
#  (1678, 0.027229352326037803),
#  (1679, 0.0816880569781134),
#  (1680, 0.033022289574216435),
#  (1681, 0.027229352326037803),
#  (1682, 0.027229352326037803),
#  (1683, 0.054458704652075605),
#  (1684, 0.033022289574216435),
#  (1685, 0.033022289574216435),
#  (1686, 0.033022289574216435),
#  (1687, 0.02931822591885712),
#  (1688, 0.033022289574216435),
#  (1689, 0.01957150582575098),
#  (1690, 0.0990668687226493),
#  (1691, 0.033022289574216435),
#  (1692, 0.033022289574216435),
#  (1693, 0.02384070126682249),
#  (1694, 0.033022289574216435),
#  (1695, 0.010966521429192687),
#  (1696, 0.033022289574216435),
#  (1697, 0.033022289574216435),
#  (1698, 0.033022289574216435),
#  (1699, 0.02384070126682249),
#  (1700, 0.033022289574216435),
#  (1701, 0.01804776401864386),
#  (1702, 0.033022289574216435),
#  (1703, 0.033022289574216435),
#  (1704, 0.027229352326037803),
#  (1705, 0.015643477829680535),
#  (1706, 0.021436415077859167),
#  (1707, 0.027229352326037803),
#  (1708, 0.033022289574216435),
#  (1709, 0.031169752555071137)]

# %%
for i in range(len(lls)):
    vector = model[corpus[i]]    
    for k,v in vector:
        print(dct[k],v)
    break
# Out:
# -3 0.042280422918735745
# -5 0.034863377039944604
# 0 0.0133028361276897
# 1 0.05299240724961653
# 10 0.011351897871919881
# 10개 0.027446331161153453
# 15 0.023107637455932237
# 1개 0.021458142663784353
# 1점 0.06972675407988921
# 2 0.029428951244492768
# 2.6 0.034863377039944604
# 2.7 0.042280422918735745
# 20 0.017641529832910913
# 2012 0.034863377039944604
# 2015 0.027446331161153453
# 3 0.027674607960292374
# 300 0.023107637455932237
# 300번 0.042280422918735745
# 4 0.048512015398859985
# 4.7 0.042280422918735745
# 46 0.042280422918735745
# 5 0.021546699323490962
# 5개 0.023107637455932237
# 5번째 0.042280422918735745
# 6 0.0665141806384485
# 6개 0.10023430284680823
# 6개정도 0.034863377039944604
# 6번 0.021458142663784353
# 7 0.017641529832910913
# 7개 0.025058575711702058
# ㄹ 0.03052468333472338
# ㄹㅇ개꿀 0.042280422918735745
# ㅇ 0.025058575711702058
# 가능 0.016621659888762196
# 가세 0.042280422918735745
# 가에 0.034863377039944604
# 가을 0.03324331977752439
# 가차 0.03052468333472338
# 각 0.034863377039944604
# 간격 0.034863377039944604
# 감각 0.042280422918735745
# 강의 0.03356303782954337
# 강의최광무 0.042280422918735745
# 강의평가 0.03052468333472338
# 강조 0.027446331161153453
# 개 0.057914819888449647
# 개꿀 0.034863377039944604
# 개념 0.043093398646981924
# 개념설명 0.042280422918735745
# 개론 0.040058570564724616
# 개설 0.042280422918735745
# 개인적 0.02910720923931599
# 거 0.013248101812404132
# 거로 0.034863377039944604
# 거로워 0.042280422918735745
# 거지 0.027446331161153453
# 건강 0.023107637455932237
# 결국 0.017641529832910913
# 경계 0.034863377039944604
# 경우 0.008728956355106666
# 경험 0.015690591577141096
# 계산 0.025058575711702058
# 계산실수 0.042280422918735745
# 고 0.023107637455932237
# 고전 0.042280422918735745
# 공 0.027446331161153453
# 공부 0.029195521828499032
# 공부안 0.042280422918735745
# 공학과 0.042280422918735745
# 과로 0.034863377039944604
# 과목 0.02013782269772602
# 과제 0.03636635467346013
# 관심 0.011351897871919881
# 광무 0.2536825375124145
# 괴짜 0.042280422918735745
# 교수님 0.03560499463463529
# 구 0.014041096784993209
# 구글링 0.018768943750711028
# 구성 0.03528305966582183
# 그것 0.0133028361276897
# 글 0.0399085083830691
# 기 0.04291628532756871
# 기계 0.03052468333472338
# 기대 0.018768943750711028
# 기말 0.004865920304749839
# 기반 0.027446331161153453
# 기본적 0.017641529832910913
# 기억 0.012612239403571163
# 기초 0.01483409175758229
# 나 0.04212329035497963
# 나중 0.01483409175758229
# 내용 0.03812665911075602
# 내용면 0.034863377039944604
# 널 0.007836728504668374
# 노 0.025058575711702058
# 노력 0.0133028361276897
# 노트 0.014041096784993209
# 논리적 0.034863377039944604
# 누 0.03052468333472338
# 눈 0.016621659888762196
# 느낌 0.02482063709504985
# 느냐에 0.042280422918735745
# 니 0.08456084583747149
# 니들 0.042280422918735745
# 다섯 0.06972675407988921
# 단계 0.027446331161153453
# 단답형 0.042280422918735745
# 답 0.015690591577141096
# 당황 0.017641529832910913
# 대 0.04212329035497963
# 대로 0.08233899348346035
# 대부분 0.011963523497327969
# 데 0.01840922801994211
# 도로 0.016621659888762196
# 도움 0.048512015398859985
# 도중 0.034863377039944604
# 독특 0.03052468333472338
# 동양 0.08456084583747149
# 동양고전 0.042280422918735745
# 동양철학개론 0.042280422918735745
# 뒤 0.0133028361276897
# 듣기 0.04291628532756871
# 듯 0.00827354569834995
# 등 0.00827354569834995
# 등등 0.018768943750711028
# 디테일 0.03052468333472338
# 때 0.014026408333397333
# 때문 0.013248101812404132
# 뜬구름 0.042280422918735745
# 량 0.04291628532756871
# 레 0.021458142663784353
# 레벨 0.027446331161153453
# 레이저 0.042280422918735745
# 레터 0.042280422918735745
# 렉 0.0266056722553794
# 로드 0.027674607960292374
# 링 0.04986497966628659
# 마 0.15015155000568822
# 마지막 0.0266056722553794
# 만점 0.010224483954119767
# 만큼 0.011963523497327969
# 말 0.020448967908239534
# 매시간 0.03052468333472338
# 머리 0.03528305966582183
# 머신 0.04621527491186447
# 면 0.03528305966582183
# 명시 0.042280422918735745
# 명언 0.034863377039944604
# 모아 0.042280422918735745
# 무례 0.034863377039944604
# 무엇 0.011963523497327969
# 문제 0.03874445114440933
# 물론 0.020029285282362308
# 뭐 0.04212329035497963
# 미디안 0.034863377039944604
# 미디안-5 0.042280422918735745
# 바 0.016621659888762196
# 바라 0.042280422918735745
# 바라면 0.042280422918735745
# 바탕 0.023107637455932237
# 박 0.03052468333472338
# 반정 0.034863377039944604
# 반정도로 0.042280422918735745
# 밥 0.042280422918735745
# 방식 0.014041096784993209
# 배 0.020029285282362308
# 번 0.028052816666794666
# 번째 0.018768943750711028
# 법 0.018768943750711028
# 별 0.01483409175758229
# 별개 0.025058575711702058
# 보기 0.03052468333472338
# 본인 0.01483409175758229
# 부분 0.026186869065319997
# 부분점수 0.03052468333472338
# 부실 0.025058575711702058
# 북 0.1754100299819144
# 분 0.028052816666794666
# 분류 0.034863377039944604
# 비율 0.03528305966582183
# 빡 0.023107637455932237
# 빡세요 0.03052468333472338
# 사람 0.009702403079771996
# 사실 0.027613842029913162
# 사진 0.027446331161153453
# 사항 0.03052468333472338
# 상당 0.023107637455932237
# 상위권 0.04291628532756871
# 상책 0.042280422918735745
# 샘플 0.034863377039944604
# 생각 0.023543160995594215
# 생각일지 0.042280422918735745
# 생략 0.027446331161153453
# 선택 0.021458142663784353
# 설명 0.026496203624808264
# 성의 0.042280422918735745
# 성적 0.014597760914249516
# 성희 0.03052468333472338
# 세상 0.034863377039944604
# 세요 0.018768943750711028
# 소리 0.016621659888762196
# 손 0.02966818351516458
# 손가락 0.034863377039944604
# 수 0.027705169562129376
# 수강 0.020448967908239534
# 수강신청 0.025058575711702058
# 수식 0.050117151423404116
# 수업 0.034280358014712776
# 수업내용 0.017641529832910913
# 수업시간 0.023927046994655938
# 수업중 0.04291628532756871
# 수정 0.025058575711702058
# 수준 0.0266056722553794
# 수학 0.052924589498732744
# 수학적 0.018768943750711028
# 숙제 0.037085229393955726
# 숙지 0.037537887501422056
# 순서 0.027446331161153453
# 스타일 0.03324331977752439
# 스펙 0.08456084583747149
# 스펙에 0.042280422918735745
# 슬라이드 0.020029285282362308
# 시간 0.031171161148680113
# 시고 0.03052468333472338
# 시사 0.042280422918735745
# 시험 0.03934851993128736
# 시험시간 0.06972675407988921
# 시험오픈북 0.042280422918735745
# 시험장 0.06104936666944676
# 신경 0.01483409175758229
# 신청 0.016621659888762196
# 실수 0.017641529832910913
# 쓰기 0.034863377039944604
# 아래 0.023107637455932237
# 아랫분 0.03052468333472338
# 안 0.026186869065319997
# 알고리즘 0.015690591577141096
# 앞 0.02966818351516458
# 양 0.023107637455932237
# 얘기 0.06932291236779671
# 어디 0.025058575711702058
# 언어 0.050448957614284654
# 언어선택 0.042280422918735745
# 언어이론 0.042280422918735745
# 여 0.015690591577141096
# 연산 0.027446331161153453
# 열 0.042280422918735745
# 열다섯배 0.042280422918735745
# 영상 0.027446331161153453
# 예 0.017641529832910913
# 예년 0.034863377039944604
# 예상 0.017641529832910913
# 예전 0.023107637455932237
# 오 0.04986497966628659
# 오랜만 0.042280422918735745
# 오타가 0.042280422918735745
# 오타도 0.034863377039944604
# 오타때문 0.042280422918735745
# 오토 0.24419746667778705
# 오토마 0.1045901311198338
# 오토마타 0.18314810000834028
# 오픈 0.21367278334306367
# 오픈북 0.2091802622396676
# 오피스 0.03052468333472338
# 올해 0.027446331161153453
# 외 0.016621659888762196
# 요 0.04291628532756871
# 운 0.034863377039944604
# 워 0.054892662322306905
# 워크 0.025058575711702058
# 위 0.017641529832910913
# 위권 0.03052468333472338
# 위주 0.017641529832910913
# 유감 0.034863377039944604
# 유리함 0.042280422918735745
# 유명 0.020029285282362308
# 유용 0.027446331161153453
# 유익 0.03324331977752439
# 은 0.016621659888762196
# 을 0.016621659888762196
# 이 0.010224483954119767
# 이거 0.052924589498732744
# 이것 0.021546699323490962
# 이것을 0.034863377039944604
# 이론 0.025058575711702058
# 이름 0.01483409175758229
# 이번 0.030673451862359303
# 이상 0.019404806159543993
# 이야기 0.03528305966582183
# 이외 0.027446331161153453
# 이중 0.03052468333472338
# 이하 0.025058575711702058
# 이해 0.04909242916689067
# 이해도 0.037537887501422056
# 이후 0.009204614009971055
# 인덱싱 0.042280422918735745
# 인성 0.034863377039944604
# 인풋 0.034863377039944604
# 일 0.023927046994655938
# 일지 0.042280422918735745
# 입력 0.06104936666944676
# 입력기 0.042280422918735745
# 자괴감 0.03052468333472338
# 자료 0.047854093989311876
# 자습 0.06437442799135305
# 자유 0.020029285282362308
# 자유로워 0.042280422918735745
# 자체 0.037085229393955726
# 자판 0.042280422918735745
# 작년 0.025058575711702058
# 장점 0.023107637455932237
# 재미 0.016621659888762196
# 저 0.047020371028010245
# 저것 0.034863377039944604
# 저번 0.034863377039944604
# 저번학기 0.042280422918735745
# 적용 0.037537887501422056
# 전 0.013248101812404132
# 전공 0.0133028361276897
# 전반적 0.0133028361276897
# 전산 0.026186869065319997
# 전산과로 0.034863377039944604
# 전산학부 0.018768943750711028
# 전체적 0.020029285282362308
# 전필 0.021458142663784353
# 절반 0.015690591577141096
# 점 0.023510185514005123
# 점도 0.034863377039944604
# 점수 0.03681845603988422
# 정도 0.027674607960292374
# 정리 0.017641529832910913
# 정신 0.017641529832910913
# 제가 0.02966818351516458
# 제공 0.021458142663784353
# 제작 0.06972675407988921
# 조교 0.007417045878791145
# 조금 0.012612239403571163
# 조심 0.025058575711702058
# 조합 0.03052468333472338
# 주 0.009702403079771996
# 주시 0.0133028361276897
# 주신 0.028082193569986418
# 주의 0.037537887501422056
# 주제 0.012612239403571163
# 준비 0.020448967908239534
# 줄 0.02966818351516458
# 중 0.023510185514005123
# 중간 0.004865920304749839
# 중간고사 0.005885790248898554
# 중간기 0.034863377039944604
# 중간기말 0.021458142663784353
# 중구난방 0.042280422918735745
# 중상 0.027446331161153453
# 중상위권 0.042280422918735745
# 중요 0.020448967908239534
# 증명 0.018768943750711028
# 지시 0.03052468333472338
# 지시사항 0.042280422918735745
# 지식 0.015690591577141096
# 지원 0.025058575711702058
# 진 0.023107637455932237
# 진도 0.06276236630856438
# 진행 0.010773349661745481
# 질 0.021458142663784353
# 집중 0.010224483954119767
# 짓 0.023107637455932237
# 차 0.018768943750711028
# 차례 0.042280422918735745
# 차이나 0.042280422918735745
# 채점 0.025224478807142327
# 채점방식 0.042280422918735745
# 책 0.025224478807142327
# 책상 0.042280422918735745
# 처음 0.019404806159543993
# 척 0.034863377039944604
# 천재 0.034863377039944604
# 철학 0.034863377039944604
# 첵 0.015690591577141096
# 초반 0.016621659888762196
# 촘스키 0.042280422918735745
# 최 0.21957064928922762
# 최광무 0.2536825375124145
# 최성희 0.03052468333472338
# 최소한 0.025058575711702058
# 최종 0.023107637455932237
# 최종성적표 0.042280422918735745
# 최종적 0.03052468333472338
# 추가 0.017641529832910913
# 추천 0.01106984318411695
# 출력 0.042280422918735745
# 출석 0.012612239403571163
# 출제 0.018768943750711028
# 친절 0.010773349661745481
# 칠판 0.023107637455932237
# 커버 0.020029285282362308
# 컨텐츠 0.027446331161153453
# 컴 0.03052468333472338
# 컴파일러 0.06972675407988921
# 컴퓨터 0.037537887501422056
# 케이스 0.020029285282362308
# 코 0.03052468333472338
# 코드 0.012612239403571163
# 코딩 0.021546699323490962
# 코딩량 0.042280422918735745
# 코바라 0.042280422918735745
# 키패드 0.042280422918735745
# 타 0.1848610996474579
# 타가 0.042280422918735745
# 타도 0.034863377039944604
# 타자기 0.042280422918735745
# 테스트 0.016621659888762196
# 퇴근 0.042280422918735745
# 튜 0.06104936666944676
# 튜링머신 0.08456084583747149
# 파이 0.017641529832910913
# 페이지 0.016621659888762196
# 편 0.023510185514005123
# 평가 0.01840922801994211
# 평균 0.03232004898523644
# 평균점수 0.042280422918735745
# 폰 0.034863377039944604
# 표 0.034863377039944604
# 표준 0.03052468333472338
# 표준점수 0.042280422918735745
# 풀이 0.021458142663784353
# 프로그래밍 0.010224483954119767
# 프로그램 0.018768943750711028
# 프로젝트 0.023543160995594215
# 프로젝트량 0.042280422918735745
# 프린트 0.042280422918735745
# 플젝 0.07541344763221837
# 플젝으로 0.042280422918735745
# 필 0.017641529832910913
# 필기 0.037537887501422056
# 필기숙제 0.03052468333472338
# 필요 0.020448967908239534
# 필자 0.027446331161153453
# 하면 0.020448967908239534
# 하위권 0.03052468333472338
# 하이 0.034863377039944604
# 하이레벨 0.042280422918735745
# 학 0.018768943750711028
# 학과 0.025058575711702058
# 학기 0.023543160995594215
# 학부 0.02966818351516458
# 학생 0.031171161148680113
# 학점 0.050011253803905066
# 학점도 0.042280422918735745
# 학점점수 0.042280422918735745
# 한 0.023107637455932237
# 한국어 0.028082193569986418
# 한국어강의여 0.042280422918735745
# 한글 0.10983414103998766
# 한글모아쓰기 0.042280422918735745
# 한글입력기 0.042280422918735745
# 한번 0.022703795743839763
# 했어도 0.03052468333472338
# 현업 0.027446331161153453
# 호불호 0.03052468333472338
# 혼자 0.018768943750711028
# 홈 0.025058575711702058
# 홈워크 0.025058575711702058
# 홈페이지 0.03052468333472338
# 효용 0.042280422918735745
# 후회 0.037537887501422056
# 휴대 0.042280422918735745
# 휴대폰 0.042280422918735745
# 힘 0.020029285282362308
