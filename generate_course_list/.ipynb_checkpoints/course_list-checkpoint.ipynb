# %%
import json
import numpy as np
from urllib.request import Request, urlopen
from bs4 import BeautifulSoup
import json
from pathlib import Path

# %%
REVIEWS = "cs_reviews"

f = open("../reviews_in_one_txt/" + REVIEWS + ".txt","r",encoding="utf-8").readlines()

# %%
available_years = {}
for i in range(2011,2019,1):
    available_years[str(i)] = 1

all_classes = {}
for i in range(len(f)):
    line = f[i]
    course = json.loads(line)
    this_course = {}
#     this_course["course_code"] = course["course_code"]
    this_course["course_name"] = course["course_name"]
    this_course["url_id"] = course["url_id"]
    all_classes[course["course_code"]] = this_course
    
with open("cs_classes_info.txt","w",encoding='utf-8') as out:
    json.dump(all_classes, out,ensure_ascii=False)

# %%
PRINT = 0
def ifprint(this_course, x):
    if PRINT:
        print("=>",x,this_course[x])
          
def parse(url_id, out):
    if url_id % 100 == 0:
        print(url_id)
#     "https://otl.kaist.ac.kr/review/result/course/2000/-1/"
    target_url = "https://otl.kaist.ac.kr/review/result/course/" + str(url_id)
    target_request = Request(target_url)
    try:
        response = urlopen(target_request)
    except:
        return
    print(url_id)
    this_course = {}

    response_text = response.read()
    soup = BeautifulSoup(response_text, "lxml")
    s = soup.select_one("""#contents > div > div > div > div.panel.panel-default.course > div >
    div > div.label-title.ellipsis-wrapper.col-xs-24.col-sm-12.col-md-13.col-lg-14 > h4""")
    print(s.text)
    course_code = s.text.split(":")[0].strip()
    this_course["course_name"] = " ".join(s.text.split(":")[1:]).strip()
    this_course["otl_link"] = target_url
    all_courses[course_code] = this_course
    return True

# %%
START_ID = 3000 #3
END_ID = 5000
TOTAL_REVIEWS = 2000
current_reviews = 0
current_id = START_ID
all_courses = {}
with open("course_2nd_crawling.txt","w",encoding="utf-8") as out:
    while current_reviews < TOTAL_REVIEWS and current_id < END_ID: # try different IDs
        result = parse(current_id, out)
        if result:
            current_reviews += 1
        current_id += 1
    json.dump(all_courses, out,ensure_ascii=False)
# Out:
# 3000
# 3007
# MAE752 : 구조음향학
# 3008
# MAE411 : 에너지플랜트 최적설계
# 3011
# MAE514 : 다상유동 1
# 3012
# MAE536 : 소성역학
# 3014
# MAE543 : 최적설계
# 3015
# MAE592 : 레이저의원리및응용
# 3017
# MAE616 : 자동차공학 및 환경
# 3019
# MAE623 : 회전유동
# 3021
# MAE633 : 고분자 및 복합재료의기계적성질
# 3024
# MAE655 : 고등로봇공학
# 3026
# MAE732 : 강도신뢰성 설계
# 3041
# IE538 : 유전 알고리즘 및 응용
# 3047
# MS524 : 재료의 상평형
# 3050
# MS635 : 반도체공정설계
# 3053
# CE333 : 지반 동역학
# 3064
# EE791 : 전력변환 회로 및 시스템
# 3067
# CS540 : 네트워크아키텍춰
# 3068
# CS576 : 컴퓨터비전
# 3069
# CS579 : 계산언어학
# 3070
# CS600 : 그래프이론
# 3071
# CS712 : 병렬처리특강
# 3100
# 3115
# CH782 : 생화학특강Ⅰ
# 3117
# MAE638 : 복합재료 공리설계
# 3119
# MAE515 : 저온공학
# 3122
# MAE711 : 복사열전달
# 3123
# MAE722 : 난류계산모형론
# 3135
# CBE471 : 환경공학개론
# 3136
# CBE501 : 생명화학공학실험및연구
# 3137
# CBE525 : 분자전자학
# 3138
# CBE531 : 다상반응기공학
# 3140
# CBE621 : 상평형과 물성론
# 3167
# MGT210 : 경영학원론
# 3197
# MGT652 : 컨설팅방법론
# 3200
# 3200
# PH451 : 실험물리학특론
# 3214
# CH607 : 표면화학
# 3215
# MAE545 : 유체윤활이론
# 3216
# MAE547 : 지식기반설계시스템
# 3217
# MAE553 : 로보트 동역학
# 3220
# MAE431 : 연속체역학개론
# 3221
# MAE632 : 점 탄성론
# 3223
# MAE771 : 소성가공공정 : 해석 및 설계
# 3227
# MAE642 : 생체역학
# 3228
# MAE683 : 인간 로봇 상호작용
# 3229
# MAE870 : 생산공학특론
# 3235
# NQE541 : 원자력 폐기물 관리
# 3237
# NQE653 : 핵연료공학
# 3238
# NQE675 : 원자력에너지정책특론
# 3241
# IE436 : 산업 및 시스템공학 사례연구
# 3242
# IE571 : 워 게임 모델링
# 3243
# IE635 : 조합최적화
# 3251
# CE532 : IT융합 암반공학
# 3253
# CBE511 : 반응시스템설계
# 3254
# CBE571 : 에너지공학
# 3255
# CBE611 : 촉매이론
# 3256
# CBE632 : 콜로이드와 계면화학
# 3257
# CBE680 : 막공학
# 3258
# CBE682 : 유기나노구조재료
# 3262
# BiS552 : Digital Biomedical Signal Processing
# 3264
# BiS672 : Nano Electro Mechanical Systems
# 3268
# CS760 : 데이타베이스특강
# 3271
# CS730 : 운영체제특강
# 3300
# 3321
# MAE647 : STEP과 전자거래
# 3323
# MAE810 : 열유체공학특론
# 3324
# MAE890 : 항공우주공학특론
# 3329
# NQE521 : 원자로열수력학
# 3334
# CE634 : 토목신호처리
# 3335
# CBE653 : 고분자의 기계적 물성
# 3336
# CBE761 : 생물공정해석및제어
# 3339
# BiS521 : Biology for Engineers
# 3345
# CS660 : 정보축적 및 검색
# 3346
# CS700 : 계산이론특강
# 3362
# MGT517 : 협상전략
# 3400
# 3400
# PH966 : 세미나(석사)
# 3401
# PH986 : 세미나(박사)
# 3404
# MAE593 : 공기열역학 및 연소
# 3405
# MAE596 : 고등선형안정 및 제어
# 3408
# MAE654 : 소음제어
# 3412
# NQE532 : 원자력 및 양자 계측시스템
# 3413
# NQE551 : 원자로 금속학
# 3423
# CE291 : 지리공간 분석 개론
# 3427
# CBE572 : 무기재료공정
# 3428
# CBE622 : 화공혼합공학
# 3438
# EE737 : 의료영상공학
# 3444
# BM525 : 암유전학
# 3465
# MGT594 : 글로벌 현장실습
# 3471
# BS543 : 고급신경생물학
# 3473
# BS433 : 분자생물학특론
# 3474
# BS465 : 나노바이오학
# 3476
# BS325 : 세포공학
# 3479
# MAE461 : 연료전지의 이해
# 3480
# MAE626 : 극음속 유동
# 3484
# NQE534 : 원자력 및 양자 제어시스템
# 3485
# NQE562 : 방사선 영상계측
# 3500
# 3512
# BiS772 : Nano-Micro-Machining Process Laboratory
# 3515
# EMB632 : 협상 및 갈등관리
# 3519
# BS322 : 생명공학
# 3524
# CH747 : 무기화학특강II
# 3525
# MAE549 : 마이크로 시스템 패키징의 신뢰성
# 3529
# MAE860 : 추진 및 연소 특론
# 3533
# NQE583 : 하전입자빔 공학
# 3534
# NQE527 : 가스냉각로와 수소
# 3537
# IE414 : 인지과학과 시스템
# 3538
# IE572 : 무기체계분석
# 3539
# MS542 : 나노표면분석
# 3544
# CBE362 : 생물정보학
# 3545
# CBE672 : 대기오염방지
# 3547
# CBE631 : 마이크로플루이딕스
# 3553
# CS542 : 인터넷 시스템 기술
# 3555
# CS790 : 전산학 논문작성법
# 3556
# CS684 : 인간과 컴퓨터 상호작용
# 3569
# SEP524 : 소프트웨어 품질 보증
# 3581
# MAE582 : 미세기전공정개론
# 3583
# MAE585 : 인체운동의 역학 및 제어
# 3584
# MAE432 : 재료의 변형 및 파괴와 강도
# 3589
# NQE552 : 원자로 구조재료 건전성
# 3593
# BiS554 : Neural Networks
# 3600
# 3618
# MGT606 : 지식재산경영
# 3624
# CH672 : 특성고분자화학
# 3628
# MAE587 : 광기전공학
# 3630
# MAE606 : 창의적지식창출과정과응용
# 3632
# MAE467 : 항공우주센서 및 구동기
# 3634
# BiS631 : Data Mining
# 3649
# MGT608 : 기업경영과 회사법
# 3650
# EMB543 : 기업의 사회책임경영
# 3654
# GCT503 : 문화기술 프로젝트1
# 3657
# GCT561 : 과학기술의 개념과 과학적 사고
# 3659
# GCT582 : 문화콘텐츠 산업론
# 3660
# GCT632 : 디지털 퍼포먼스
# 3664
# GCT653 : 가상현실 가상세계
# 3674
# IE570 : 군사 OR 이론과 응용
# 3678
# CBE342 : 화학 및 생물 제품디자인
# 3683
# MGT607 : 기업경영 기본법
# 3684
# GCT731 : 음악기술특강
# 3685
# GCT685 : 문화벤처창업론
# 3688
# GCT554 : 디지털 건축
# 3689
# GCT674 : 지식기반시스템디자인
# 3691
# GCT551 : 디지털 디자인
# 3694
# GCT511 : 디지털 미학
# 3700
# 3709
# FIN508 : 투자이론 및 분석
# 3710
# FIN604 : 금융기관 경영전략
# 3711
# FIN535 : 기초금융수학 ll
# 3712
# FIN502 : 금융기초통계학
# 3713
# FIN504 : 금융통계분석
# 3714
# FIN507 : 기업금융전략
# 3715
# FIN534 : 기초금융수학ㅣ
# 3716
# FIN505 : 재무회계 I
# 3717
# FIN506 : 재무회계 II
# 3718
# FIN501 : 기업가치분석
# 3719
# FIN641 : 선도, 선물과 스왑
# 3720
# FIN644 : 채권 분석
# 3722
# FIN642 : 옵션 이론과 실제
# 3726
# FIN631 : 국제재무론
# 3727
# FIN643 : 증권시장 분석
# 3730
# BS642 : 행동유전학
# 3733
# MAE483 : 통계열역학 개론
# 3736
# BiS510 : Technology Commercialization and Venture Business
# 3737
# BiS722 : Cell Signaling Nework
# 3738
# BiS410 : Bioengineering Senior Project
# 3739
# EE622 : 검출 및 추정
# 3741
# MGT604 : 인사관리시스템과 전략
# 3746
# GCT602 : 문화기술 프로젝트 II
# 3747
# GCT543 : 게임디자인
# 3748
# GCT641 : 게임학
# 3750
# GCT711 : 디지털 문화이론 특강
# 3751
# GCT741 : HCI 특강(인간과 컴퓨터 상호작용)
# 3752
# GCT781 : 문화경제정책 특강
# 3756
# STE605 : 메모리 및 SoC기술
# 3767
# FIN533 : 금융프로그래밍
# 3768
# FIN645 : 증권시장분석 및 거래전략
# 3769
# FIN663 : 금융연구방법 II
# 3770
# FIN515 : 화폐와 금융
# 3772
# FIN653 : 이자율 파생상품
# 3773
# FIN539 : 고급금융계량분석
# 3774
# FIN610 : 보험과 위험의 원리
# 3775
# FIN541 : 금융시계열 분석
# 3776
# FIN654 : 신용위험과 신용파생상품
# 3777
# FIN538 : 금융계량분석
# 3778
# FIN510 : 회사법
# 3780
# FIN648 : 고급채권론
# 3781
# FIN615 : 재무제표분석 I
# 3782
# FIN509 : 금융법
# 3783
# FIN723 : 자산운용 특강 II
# 3784
# FIN662 : 금융연구방법 I
# 3785
# FIN536 : 금융수학  I
# 3786
# FIN656 : 고급파생상품론
# 3788
# FIN537 : 금융수학 II
# 3791
# FIN616 : 재무제표분석 II
# 3792
# FIN612 : 투자은행
# 3793
# IM501 : 통계분석 및 응용
# 3796
# BS671 : 고급동물세포공학
# 3797
# MAS556 : 시계열분석
# 3798
# MAS671 : 금융수학의 계산적 방법론
# 3799
# MAS661 : 수리유체역학
# 3800
# 3800
# MAS622 : 심플렉틱기하학
# 3802
# MAS260 : 응용수학과모델링
# 3803
# MAS510 : 정수론
# 3805
# MAS343 : 상미분방정식과 동역학계
# 3807
# MAS502 : 공학자를 위한 함수해석학
# 3809
# MAE523 : 헬리콥터항공역학
# 3810
# MAE726 : 평형 극음속 공기열역학
# 3811
# MS545 : 헬스케어소재
# 3812
# CBE483 : 인체생리공학
# 3813
# CS496 : 세미나
# 3829
# GCT688 : 글로벌 문화마케팅 전략
# 3830
# GCT651 : 미디어 인터랙션 디자인
# 3831
# GCT752 : 디지털 콘텐츠 특강
# 3832
# GCT784 : 인터넷산업특강
# 3833
# GCT722 : 가상현실 특강
# 3841
# FIN627 : 기업인수와합병
# 3842
# FIN646 : 포트폴리오관리론
# 3843
# IM711 : 정보미디어경영 특수논제
# 3844
# IM555 : 유비쿼터스 경영
# 3845
# IM553 : 정보통신시스템
# 3846
# IM502 : 의사결정 모형 및 분석
# 3849
# MAS456 : 컴퓨터 통계방법론
# 3850
# MAE801 : 기계공학특론 I
# 3853
# EMB513 : 국제경영전략
# 3854
# FIN683 : 국제금융시장
# 3858
# IM554 : 인터넷기술개관
# 3862
# ED100 : 설계와 커뮤니케이션
# 3867
# MAE727 : 비평형 극음속 공기열역학
# 3870
# NQE542 : 액티나이드화학
# 3891
# FIN651 : 신용위험관리
# 3892
# FIN660 : 부동산투자론
# 3894
# FIN542 : 고급금융시계열분석
# 3895
# FIN600 : 금융 특수논제
# 3897
# FIN650 : 금융시장 위험관리
# 3899
# IM621 : 정보기술을 통한 가치혁신
# 3900
# 3900
# IM708 : IT 미디어기업 가치평가
# 3901
# IM512 : 조직과 리더십
# 3902
# IM601 : 정보통신 산업분석
# 3903
# IM665 : 미디어 개론
# 3905
# IM663 : 엔터테인먼트 마케팅
# 3908
# IMB591 : 글로벌리더십 개발
# 3910
# CH351 : 화학실험 II
# 3913
# MAS471 : 금융수학과 확률모형
# 3914
# MAS442 : 푸리에 해석과 응용
# 3915
# MAS504 : 공학자를 위한 행렬계산
# 3916
# MAS552 : 큐잉이론과 응용
# 3917
# MAS571 : 금융수학의 확률적 방법론
# 3919
# MAS651 : 확률과정론
# 3922
# ID312 : 디자인 인간요소
# 3926
# CBE872 : 생명화학공학의 최근동향 III
# 3927
# EE625 : 신호탐지 및 추정의 응용
# 3928
# EE567 : 태양광발전
# 3929
# CS451 : IT 서비스공학
# 3942
# GCT523 : 문화기술 컴퓨팅
# 3944
# GCT662 : 인간과 로봇 상호작용
# 3945
# GCT684 : 지역문화산업론
# 3952
# FIN603 : 금융마케팅 관리
# 3953
# FIN655 : 파생상품 거래전략
# 3955
# FIN626 : 사모투자
# 3956
# FIN665 : 위험관리 사례연구
# 3957
# FIN727 : 동북아금융특강 III
# 3959
# IM709 : 비즈니스 성장 전략
# 3960
# MSE602 : 최신임상의과학 세미나 I
# 3961
# MSE502 : 의생명분자생물학
# 3966
# INT493 : 국내인턴십 프로그램 I
# 3967
# INT494 : 국내인턴십 프로그램 II
# 3968
# INT495 : 국내인턴십 프로그램 III
# 3969
# INT498 : 해외인턴십 프로그램 I
# 3971
# MAS476 : 게임이론
# 3973
# FIN621 : 고급회계 II
# 3974
# FIN511 : 금융환경과 거시경제
# 3975
# FIN620 : 고급회계 I
# 3976
# BiS402 : Special Topics in Bio and Brain Engineering (2)
# 3977
# INT499 : 해외인턴십 프로그램 II
# 3979
# BS554 : 고급생명공학
# 3980
# CH251 : 화학실험 I
# 3983
# MAS765 : 유한요소법
# 3985
# MAS410 : 암호론
# 3988
# CBE443 : 화학 및 생물제품 디자인 실습
# 3989
# EE402 : 미래사회와 전자공학
# 3992
# CS493 : 전산학특강 I
# 3996
# BUS917 : Job Search English Skills
# 4000
# 4012
# PSE712 : 고분자재료 특강 II
# 4013
# MGT789 : 테크노경영 특수논제 II
# 4014
# MGT598 : 중국산업의 이해
# 4030
# FIN669 : 부동산 증권론
# 4034
# IMB540 : 기업경영과 사회
# 4036
# EMB641 : 전략적 고객관계관리
# 4041
# CH450 : 화학 원어논문 작성 및 발표
# 4042
# MAS548 : 기호동역학
# 4044
# NQE522 : 원자력발전소 설계프로젝트
# 4045
# MS698 : 신소재공학특론 Ⅲ
# 4049
# CE551 : 공학설계를 위한 소프트 컴퓨팅 기법
# 4050
# EE665 : CMOS프론트-앤드 공정기술
# 4051
# CC532 : 협력 시스템설계
# 4053
# HSS398 : English Conversation
# 4058
# SEP547 : IT 서비스 공학
# 4061
# GCT541 : 인간과 컴퓨터 상호작용
# 4065
# IM560 : IT 모델링
# 4066
# BiS400 : Special Topics in Bio and Brain Engineering
# 4077
# MAS582 : 수학특론 II
# 4081
# HSS194 : 리더십훈련
# 4083
# HSS198 : 커뮤니케이션 훈련
# 4084
# FIN625 : 벤처투자
# 4085
# FIN649 : 수치해법의 금융응용
# 4088
# BS723 : 세포신호전달 네트워크
# 4089
# CH107 : 대학화학
# 4093
# MAS105 : 대학수학
# 4095
# NQE529 : 원자력시스템설계
# 4096
# NQE221 : 원자력 열수력학 개론
# 4097
# IE565 : 정보보호 정책 및 경영
# 4098
# IE574 : 포트폴리오 관리 및 금융 최적화기법
# 4099
# ID810 : 디자인특강 III
# 4100
# 4100
# CE419 : 실험진동공학
# 4101
# CE548 : 교통정책 및 법체계
# 4104
# CBE505 : 화학 공정 및 제품 디자인
# 4105
# HSS254 : 특허출원 관련법
# 4107
# HSS044 : 건강관리
# 4109
# HSS134 : 인지과학입문
# 4110
# HSS232 : 과학기술사회학
# 4111
# HSS201 : Revolutions in Science and Technology
# 4112
# HSS230 : Science and Technology Policy
# 4113
# HSS233 : Science and Technology Related Laws
# 4115
# HSS292 : Business English Projects
# 4116
# HSS390 : Advanced English Conversation
# 4117
# HSS391 : Advanced English Writing
# 4118
# HSS278 : Modern Arts
# 4119
# HSS393 : English Presentation
# 4120
# HSS196 : 운동과 건강
# 4121
# HSS021 : Critical Thinking in English
# 4122
# HSS206 : 분석철학
# 4123
# HSS397 : Advanced English Reading
# 4125
# HSS003 : 실용적 글쓰기
# 4127
# HSS205 : Philosophy of Mind
# 4128
# HSS020 : English Communication
# 4130
# GCT673 : 소셜컴퓨팅
# 4131
# GCT633 : 오디오 및 멀티미디어 프로그래밍
# 4132
# GCT787 : 문화기획특강
# 4133
# FIN543 : 금융모형의 계량적 추정
# 4136
# FIN705 : 투자은행특강 II
# 4137
# IM666 : 미디어 산업분석
# 4139
# MSE722 : 세포신호전달 네트워크
# 4142
# STP604 : Environmentalism and Environmental Policy
# 4148
# NST631 : 바이오 이미징
# 4149
# NST717 : 나노과학기술 고등논제
# 4153
# OSE966 : 세미나(석사)
# 4181
# COM172 : 콜로키엄
# 4200
# 4206
# MBA532 : Entrepreneurship for IT Business
# 4211
# MBA530 : IT Economics and Policy
# 4212
# MBA504 : Management Information Systems
# 4213
# MBA531 : Strategic Management for IT Business
# 4223
# EEW504 : 고등양자역학
# 4224
# EEW502 : 화학결합의 특성
# 4231
# CS671 : 고급 기계학습
# 4232
# CS552 : 소프트웨어 시스템 모델링
# 4233
# CS554 : 소프트웨어 및 시스템 설계
# 4236
# BS307 : 생물리화학
# 4237
# BS467 : 생체재료학
# 4238
# MAE600 : 기계시스템디자인 프로젝트 1
# 4239
# MAE463 : 위성항법시스템
# 4240
# IE554 : 지식기반 설계 방법론 및 시스템
# 4241
# IE566 : 인간-컴퓨터 상호작용 : 이론과 설계
# 4242
# CE599 : U-Space 건설 IT설계 특수문제
# 4243
# CE445 : 환경친화형 건축설계
# 4244
# BM528 : 의생명분자생물학
# 4245
# MGT507 : 에너지환경경제학
# 4246
# MGT508 : 에너지환경정책
# 4247
# FIN500 : 금융윤리와 사회책임
# 4248
# FIN966 : 세미나(석사)
# 4253
# OSE621 : 부유체 동역학
# 4254
# OSE504 : 해양시스템역학
# 4255
# OSE530 : 고등구조해석
# 4256
# OSE541 : 구조물의 통계학적 해석방안
# 4257
# OSE542 : 해양구조물동역학
# 4258
# OSE801 : 엔지니어링 시스템 아이덴티피케이션
# 4259
# OSE986 : 세미나(박사)
# 4277
# MBA500 : Accounting for Managers
# 4278
# MBA503 : Organization and People Management
# 4279
# MBA501 : Finance for Managers
# 4283
# MBA606 : R&D and Innovation Management
# 4287
# ITP700 : 한국의 무선통신 기술
# 4288
# ITP702 : 한국의 소프트웨어 공학
# 4289
# EEW503 : 분자열역학 및 에너지시스템
# 4290
# EEW513 : 수처리와 담수화
# 4291
# MSB406 : 미시경제학
# 4292
# MSB403 : 혁신사례
# 4294
# MSB451 : 벤처창업기획과 실제
# 4295
# EE637 : 음성 및 오디오 부호화 이론
# 4297
# EE425 : 무선 통신망
# 4299
# EE739 : 인지정보처리
# 4300
# 4300
# EE311 : 전자공학을 위한 운영체제 및 시스템 프로그래밍
# 4301
# EE543 : 안테나 공학
# 4302
# EE613 : 분산컴퓨팅시스템
# 4303
# EE655 : 통신망 경제
# 4305
# KSE531 : 인간-컴퓨터 상호작용: 이론과 설계
# 4306
# KSE643 : 지식공학과 지적의사결정
# 4307
# KSE524 : 정보 검색과 관리
# 4309
# CS578 : 생체 공학적 인간-로봇 상호작용
# 4310
# CS612 : 사회적 관계 기반 유비쿼터스 컴퓨팅
# 4311
# MIP702 : 국제특허심사실무
# 4312
# MIP502 : 환경기술 ET
# 4313
# HSS257 : Biotech's Legal Issues & Regulations
# 4314
# HSS158 : Introduction to Business Management
# 4315
# HSS272 : 영미 드라마와 영화
# 4316
# HSS460 : Vision, Brain and Art
# 4320
# HSS394 : Internet English
# 4321
# HSS399 : Creative English Writing
# 4322
# HSS485 : 보고서 작성법
# 4323
# HSS141 : Power vs. Choice
# 4324
# HSS119 : Understanding German-Speaking Cultures
# 4325
# BA511 : 재무회계
# 4326
# BA733 : 자산가격이론
# 4327
# BA761 : 연구특수논제Ⅰ
# 4329
# SJ502 : 환경기술 ET
# 4330
# SJ501 : 정보기술 IT
# 4332
# OSE802 : 해양시스템 실습특론
# 4334
# ITM993 : 국내인턴쉽 II
# 4339
# MIP801 : 특강
# 4340
# MIP600 : 리더십&communication1
# 4343
# SJ603 : 리더십 & Communication 1
# 4344
# FIN999 : 국제경영실습 (해외인턴십)
# 4345
# FIN998 : 기업경영실습(국내인턴십)
# 4347
# PH650 : 고급연성물질물리학
# 4349
# MAS478 : 이산기하
# 4350
# NQE543 : 원전수화학
# 4351
# IE575 : 금융상품의 설계와 평가
# 4352
# ID510 : 기업 전략적 디자인 프로세스
# 4353
# MS658 : 이차전지 소재과학
# 4355
# CE596 : U-Space 구조공학 설계 특수문제
# 4358
# CBE461 : 생물 신연료 및 화학산업
# 4359
# MGT528 : 탄소시장과 기업전략
# 4362
# IM662 : 컨텐츠 개발전략
# 4363
# MAE300 : 항공우주신호처리론
# 4364
# MAE470 : 과학기술, 우주 그리고 사회
# 4365
# MAE601 : 기계시스템디자인 프로젝트 2
# 4366
# BiS208 : Biochemistry II
# 4371
# NST552 : 바이오광학
# 4372
# OSE553 : 항만공학
# 4373
# SPE520 : 위성공학개론
# 4375
# SEP503 : 소프트웨어 이론 개요
# 4380
# ITM630 : 아시아 이노베이션모형과 정책
# 4385
# ITP756 : IT Industury Research Design and Methods
# 4386
# EEW601 : EEWS 특강 Ⅰ (에너지 및 재료과학)
# 4388
# EEW522 : 나노소자 수송 및 광학 특성
# 4389
# EEW600 : 태양 에너지 시스템 디자인 및 분석
# 4391
# EEW800 : 고급 전자 현미경
# 4392
# EEW830 : 신에너지 재료 디자인 및 합성
# 4393
# MSB616 : 금융시장론
# 4394
# MSB443 : 협상의 기술과 갈등관리
# 4396
# MSB836 : 마케팅과학 세미나
# 4397
# MSB542 : 경영과학론
# 4398
# MSB552 : 기업전략적 디자인 프로세스
# 4400
# 4400
# MSB454 : 정보통신정책론
# 4401
# EE727 : 광대역네트워크 설계 및 분석
# 4403
# EE658 : 큐잉이론 및 응용
# 4404
# EE755 : 고급 부호이론
# 4405
# EE466 : 바이오 및 의용 전자 공학 개론
# 4406
# EE758 : 광 통신망
# 4407
# EE766 : 플라즈마 전자공학
# 4408
# EE774 : VLSI 설계 방법론
# 4409
# EE464 : 그린에너지 전자공학
# 4411
# EE626 : 고급통신이론
# 4413
# EE575 : 엔터테인먼트 프랫폼
# 4414
# KSE801 : 지식서비스공학의 특수논제 I
# 4415
# KSE622 : 지능시스템에서의 유연계산
# 4416
# KSE621 : 정보추출과 데이터마이닝
# 4417
# CS474 : 텍스트마이닝
# 4419
# CS443 : 분산 알고리즘 및 시스템
# 4420
# CS340 : 네트워크 과학의 융합적 접근
# 4421
# CS541 : 스마트 비지니스 응용 및 개발
# 4422
# MIP503 : 바이오기술 BT
# 4423
# HSS483 : 과학기술정책 사례연구
# 4426
# HSS253 : Corporation Laws
# 4427
# HSS286 : Environmental Law
# 4428
# HSS261 : 지식재산권 개요
# 4429
# BA523 : 법과 경제학
# 4430
# BA571 : 수리계획법
# 4431
# BA812 : 회계이론
# 4432
# BA661 : IT전략
# 4433
# BA512 : 회계정보와 자본시장
# 4434
# BA734 : 자산가격실증연구
# 4437
# BA881 : 통계와 금융의 고급계산 방법론
# 4438
# BA681 : 다변량 통계분석
# 4439
# FEP411 : 금융상품의 설계와 평가
# 4440
# SJ503 : 바이오기술 BT
# 4442
# FIN562 : 탄소금융상품 사례연구
# 4443
# FIN549 : 녹색기술 사업화와 녹색금융 I
# 4444
# FIN551 : 녹색기업의 가치평가
# 4445
# FIN550 : 녹색기술 사업화와 녹색금융 II
# 4446
# FIN555 : 녹색파생상품
# 4447
# FIN561 : 탄소금융상품 개론
# 4448
# FIN569 : 녹색금융 사례연구 I
# 4449
# FIN618 : 관리회계 Ⅰ
# 4450
# FIN619 : 관리회계Ⅱ
# 4451
# IE453 : 제품 개념 설계
# 4452
# ID420 : 디자인특강 II
# 4453
# CE541 : 지속가능 기반시설 시스템 공학
# 4454
# CE545 : 자료, 결정 및 시스템 분석
# 4455
# MGT713 : 전략적 지속가능경영 컨설팅
# 4456
# GCT575 : 사이버심리학
# 4457
# GCT686 : 전시컨텐츠 제작
# 4458
# MAE482 : 나노구동기 설계 및 구현
# 4459
# MAE558 : 항공우주 시스템의 다분야 최적 설계
# 4460
# MAE555 : 고급 우주추진시스템
# 4461
# MAE880 : 비행역학 및 제어특론
# 4462
# IMB592 : 이문화경영관리
# 4463
# BiS437 : Bio-Data Engineering
# 4464
# OSE505 : 해양공학진로설계
# 4465
# OSE503 : 조선해양공학개론
# 4466
# OSE572 : 해양지식설계시스템
# 4467
# MBA522 : IT and Business Transformation
# 4468
# EEW570 : 소재의 회절 분석
# 4469
# MSB638 : 기술혁신 전략경영 이론
# 4470
# EE756 : 고급 정보이론
# 4471
# KSE631 : 콘텐츠 네트워킹
# 4472
# KSE651 : 조직학습과 지식컨설팅
# 4474
# HSS453 : Behavioral Finance
# 4475
# HSS336 : The American Democratic Tradition
# 4476
# HSS268 : Chinese Conversation II
# 4477
# BA524 : 경영경제수학
# 4478
# BA531 : 금융수리분석 I
# 4479
# BA621 : 미시경제이론
# 4480
# BA762 : 연구특수논제Ⅱ
# 4481
# BA662 : 고급 eBusiness
# 4482
# BA742 : 고급조직론
# 4483
# BA743 : 고급경영전략
# 4484
# SJ504 : 나노기술 NT
# 4485
# FIN520 : 기업구조조정론
# 4486
# FIN570 : 녹색금융 사례연구 II
# 4487
# IP412 : 기업가적 사고
# 4488
# STP701 : 과학도시연구
# 4489
# STP514 : 과학정책의 철학
# 4490
# PD501 : 디지털 전장회로
# 4491
# STP141 : Power vs. Choice
# 4492
# STP483 : 과학기술정책 사례연구
# 4493
# WST500 : 웹사이언스공학 개론
# 4494
# WST520 : 웹소프트웨어 공학
# 4495
# OSE632 : 해양구조물시공
# 4496
# SEP603 : 소프트웨어 개발 스튜디오III
# 4497
# ITM640 : 통합적 관점의 신제품 개발
# 4499
# MIP601 : 리더십 & Communication 2
# 4500
# 4500
# MIP505 : 융합기술
# 4502
# SJ604 : 리더십 & Communication 2
# 4503
# SJ505 : 융합기술 Convergence Tech
# 4504
# BS456 : 행동생리학
# 4505
# BS588 : 세포신호전달
# 4506
# CBE683 : 고분자 전자재료 및 소자
# 4507
# MGT579 : 경영자를 위한 인문학
# 4508
# MGT509 : 에너지환경기술
# 4509
# MGT714 : 기후변화 R&D 전략
# 4510
# BM610 : 실험동물학기법
# 4511
# IM682 : 재무관리Ⅱ
# 4512
# MAE526 : 나노공정개론
# 4513
# MAE260 : 항공우주 역학을 위한 기초수학
# 4514
# MSE610 : 실험동물학기법
# 4515
# MSE604 : 세포치료학
# 4516
# IMB593 : 비지니스 프리젠테이션
# 4517
# BiS528 : Cognitive Design and Interface
# 4518
# BiS340 : 네트워크 과학의 융합적 접근
# 4519
# BiS536 : Proteome Bioinformatics
# 4520
# NST559 : 세포신호전달
# 4521
# NST555 : 이론 생물물리
# 4522
# NST621 : 생분자구조분석학
# 4523
# NST553 : 전기화학과 나노과학
# 4524
# OSE968 : 해양진로설계세미나
# 4525
# OSE643 : 해양로봇공학: 기법 및 응용
# 4526
# OSE622 : 스마트재료 및 적응구조물
# 4527
# OSE550 : 해양시스템공학
# 4528
# OSE555 : 해양 가상현실 시뮬레이션
# 4529
# SEP545 : 데이터베이스 설계
# 4530
# ITM637 : 영역적 관점에서 본 이노베이션 시스템
# 4531
# ITM505 : 기술경영을 위한 마케팅관리
# 4532
# ITM661 : 기업 전략적 신제품 디자인
# 4533
# EEW506 : 고분자 에너지 재료
# 4534
# EEW840 : 분자 수준의 나노 기계
# 4535
# MSB421 : 첨단기술 인적자원관리
# 4536
# MSB554 : 스마트 비즈니스 응용 및 개발
# 4537
# MSB813 : 정보통신경제론
# 4538
# EE643 : 밀리미터파 집적회로 설계
# 4539
# EE692 : 병렬분산 알고리즘
# 4540
# CS484 : 컴퓨터 비전 개론
# 4541
# CS646 : 디지털 콘텐츠 보안
# 4542
# MIP642 : IP 융합 프로젝트
# 4545
# MIP724 : 국제지식재산연수
# 4546
# HSS164 : 영화의 이해
# 4547
# HSS262 : Trademark Infringement Litigation
# 4548
# HSS263 : Patent Infringement Litigation
# 4549
# HSS243 : Humans, Machines, and Society
# 4550
# HSS420 : 과학 스토리텔링
# 4551
# BA763 : 소셜 네트워크 분석
# 4552
# BA862 : 연구방법론Ⅱ
# 4553
# BA835 : 행태재무 연구
# 4558
# FIN553 : 녹색회계
# 4559
# FIN560 : 기후변화와 금융산업
# 4560
# FIN563 : 에너지환경기술과 금융 I
# 4561
# FIN564 : 에너지환경기술과 금융 II
# 4562
# FIN554 : 녹색펀드 투자전략
# 4563
# IP411 : IP관련 법률분쟁과 그 해결
# 4564
# STP513 : 과학기술의 정치경제학
# 4565
# STP610 : 대학과 대학시스템 연구세미나
# 4566
# PD532 : 스마트 차량동역학
# 4567
# STP411 : 과학기술정책 연구방법론
# 4568
# STP412 : 미래사회와 과학기술
# 4569
# STP243 : 인간, 기계, 사회
# 4570
# IS522 : 시스템 보안 개론
# 4571
# IS537 : 보안을 위한 정보이론
# 4572
# IS681 : 콘텐츠 보안
# 4573
# WST650 : 웹 언어공학
# 4574
# WST621 : 외부메모리 자료구조
# 4575
# WST665 : 웹-스케일 이미지 및 비디오 검색
# 4576
# BS589 : 암유전학
# 4577
# MAS455 : 선형모형
# 4578
# MAS613 : 리대수
# 4579
# IE463 : 정보시스템 설계 및 관리
# 4580
# CBE612 : 촉매설계
# 4581
# MGT529 : 신사업개발과 프로젝트 관리
# 4582
# MGT716 : 국제협상학
# 4583
# GCT556 : 디지털 패션
# 4584
# GCT573 : 인지와 정서
# 4585
# GCT654 : 비쥬얼컴퓨팅
# 4587
# MSE607 : 임상 뇌영상학
# 4588
# NST635 : 종양생물학
# 4589
# NST560 : BioMEMS 개론
# 4590
# OSE623 : 선박과 해양시스템의 유체 시뮬레이션
# 4591
# OSE591 : 신재생 해양에너지 개론
# 4592
# ITM521 : 정보기술론
# 4593
# ITM522 : 통신기술론
# 4594
# MSB538 : 조직관리론
# 4595
# EE513 : 네트워크 시스템 및 보안
# 4596
# EE775 : 통신용 핵심 IP 설계
# 4597
# MIP603 : 미래전략과 IP
# 4598
# HSS308 : Environmental Ethics
# 4599
# HSS479 : English Debate
# 4600
# 4600
# HSS370 : 시각, 뇌, 예술
# 4601
# FIN591 : 동북아 금융특강Ⅲ
# 4602
# STP612 : 모빌리티 연구
# 4603
# STP515 : 하이테크산업정책
# 4604
# STP516 : 과학대중화
# 4605
# IS531 : 컴퓨터구조와 보안
# 4606
# IS532 : 정보보호 정책 및 경영
# 4607
# IS535 : 네트워크 시스템 및 보안
# 4608
# IS534 : 컴퓨터 보안을 위한 머신러닝
# 4609
# WST501 : 웹 스케일 자료 검색 기초 이론
# 4610
# WST510 : 웹 아키텍쳐
# 4611
# WST560 : 모바일 웹과 어플리케이션
# 4612
# WST630 : 고성능 컴퓨팅
# 4613
# WST640 : 웹 정보검색
# 4614
# IM664 : 소셜미디어와 인터액티브 경영
# 4615
# CTP302 : 문화콘텐츠론
# 4616
# SJ707 : 미래예측 및 기획
# 4617
# STP497 : 과학기술정책 인턴쉽 I
# 4618
# STP498 : 과학기술정책 인턴십 II
# 4619
# IM684 : 비즈니스 프리젠테이션 II
# 4620
# PH497 : 실험물리학세미나
# 4621
# NQE411 : 원자로 동력학
# 4622
# IE671 : 추계적 모델 II
# 4623
# MS431 : 나노바이오 소재
# 4624
# GCT700 : 프로젝트기획 특강
# 4625
# GCT606 : 디지털 퍼포먼스
# 4626
# GCT544 : 게임학
# 4627
# MAE728 : 재진입 공기열역학
# 4628
# BiS481 : Collective Intelligence in Biomedical Applications
# 4629
# NST831 : 고급유전학
# 4630
# OSE581 : 인류와 에너지: 바다에서의 도전
# 4631
# ICE552 : 공학도를 위한 컴퓨터과학
# 4632
# MSB456 : 지식 비즈니스
# 4633
# MSB730 : 고급관리회계
# 4634
# EE696 : 통신소프트웨어 설계
# 4635
# CS476 : 바이오의료응용 집단지성
# 4636
# CS688 : 대용량 이미지 및 비디오 검색
# 4637
# MIP723 : 국제지식재산협상
# 4638
# HSS156 : Understanding Law
# 4639
# HSS325 : Renaissance and Baroque Art
# 4640
# SJ712 : 사회인지 신경과학
# 4641
# FIN693 : 동아시아 경제발전과 개도국
# 4642
# FIN613 : 금융정책
# 4643
# FIN578 : 투자은행특강Ⅱ
# 4644
# FIN587 : 자산운용 특강Ⅱ
# 4645
# STP550 : 경제학적 정책분석
# 4646
# STP552 : 국가연구개발관리
# 4647
# PD652 : 전기자동차 파워트레인 공학
# 4648
# STP210 : Power vs. Choice
# 4649
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-61-55f9f8fe4563> in <module>()
#       7 with open("course_2nd_crawling.txt","w",encoding="utf-8") as out:
#       8     while current_reviews < TOTAL_REVIEWS and current_id < END_ID: # try different IDs
# ----> 9         result = parse(current_id, out)
#      10         if result:
#      11             current_reviews += 1
#
# <ipython-input-59-e15398d05fa7> in parse(url_id, out)
#      18
#      19     response_text = response.read()
# ---> 20     soup = BeautifulSoup(response_text, "lxml")
#      21     s = soup.select_one("""#contents > div > div > div > div.panel.panel-default.course > div >
#      22     div > div.label-title.ellipsis-wrapper.col-xs-24.col-sm-12.col-md-13.col-lg-14 > h4""")
#
# ~\Anaconda3\lib\site-packages\bs4\__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, **kwargs)
#     226             self.reset()
#     227             try:
# --> 228                 self._feed()
#     229                 break
#     230             except ParserRejectedMarkup:
#
# ~\Anaconda3\lib\site-packages\bs4\__init__.py in _feed(self)
#     287         self.builder.reset()
#     288
# --> 289         self.builder.feed(self.markup)
#     290         # Close out any unfinished strings and close all the open tags.
#     291         self.endData()
#
# ~\Anaconda3\lib\site-packages\bs4\builder\_lxml.py in feed(self, markup)
#     248         try:
#     249             self.parser = self.parser_for(encoding)
# --> 250             self.parser.feed(markup)
#     251             self.parser.close()
#     252         except (UnicodeDecodeError, LookupError, etree.ParserError) as e:
#
# src/lxml/parser.pxi in lxml.etree._FeedParser.feed()
#
# src/lxml/parser.pxi in lxml.etree._FeedParser.feed()
#
# src/lxml/parsertarget.pxi in lxml.etree._TargetParserContext._handleParseResult()
#
# src/lxml/parsertarget.pxi in lxml.etree._TargetParserContext._handleParseResult()
#
# src/lxml/etree.pyx in lxml.etree._ExceptionContext._raise_if_stored()
#
# src/lxml/saxparser.pxi in lxml.etree._handleSaxTargetStartNoNs()
#
# src/lxml/saxparser.pxi in lxml.etree._callTargetSaxStart()
#
# src/lxml/parsertarget.pxi in lxml.etree._PythonSaxParserTarget._handleSaxStart()
#
# ~\Anaconda3\lib\site-packages\bs4\builder\_lxml.py in start(self, name, attrs, nsmap)
#     143         self.nsmaps = [self.DEFAULT_NSMAPS]
#     144
# --> 145     def start(self, name, attrs, nsmap={}):
#     146         # Make sure attrs is a mutable dict--lxml may send an immutable dictproxy.
#     147         attrs = dict(attrs)
#
# KeyboardInterrupt:
